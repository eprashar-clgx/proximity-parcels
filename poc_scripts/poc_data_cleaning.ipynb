# %%
# Importing required libraries
import os
import subprocess
from datetime import datetime, timedelta
import time
import logging
from typing import Literal
from collections import defaultdict

import pandas as pd
import numpy as np
import geopandas as gpd
from shapely.geometry import Polygon
from shapely import wkt
from shapely.geometry import shape
from shapely.validation import explain_validity
import fiona

from google.cloud import bigquery
from pandas_gbq import to_gbq
from google.cloud import storage

# Import utility constants and functions
import utils

# %%
# Initialize global constants here
POC_FINALIZED_COUNTIES = [
    # urban
    '17031',
    '13121',
    '53033',
    # sub-urban
    '48491',
    '29181',
    '42011',
    # rural 
    '55107',
    '35051',
    '17127',
]

# %%
# Define constants
#POC_DATASET = 'encumbered_parcels'
#POC_TABLE = 'base_parcels_poc_counties_0419'
geo_crs = "EPSG:4326"
projected_crs = "EPSG:3857" 
ENCUMBRANCES = [
    'roadways',
    'railways',
    'protected_lands',
    'wetlands',
    'transmission_lines',
    ]
EncumbranceType = Literal[
    'roadways',
    'railways',
    'protected_lands',
    'wetlands',
    'transmission_lines',
]

LOCAL_DATA_FOLDER = r"C:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\jan_25_proj_infra_parcels\data"
COUNTY_DATA = r"counties\tl_2024_us_county\tl_2024_us_county.shp"
RAILWAYS_DATA = r"NTAD_North_American_Rail_Network_Lines\NARN.gdb" 
TRANSMISSION_LINES_DATA = r"transmission_lines\Transmission_Lines.shp"
ROADWAYS_DATA = r"NTAD_North_American_Roads\North_American_Roads.shp"
PROTECTED_LANDS = r"C:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\jan_25_proj_infra_parcels\data\Protected Lands"
WETLANDS = r"C:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\jan_25_proj_infra_parcels\data\Wetlands"
WETLAND_ATTRIBUTES = r"Wetlands\NWI-Code-Definitions\NWI-Code-Definitions\NWI_Code_Definitions.gdb"
PARQUET_INGESTION_PATH = r"C:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\jan_25_proj_infra_parcels\data\ingestion_parquets"

# %% [markdown]
# #### 1.1 Cleaning and saving source encumbrance data in parquet format

# %%
# Function to make valid geometries
def fix_invalid_geometries(gdf):
    # Iterate over each row and fix invalid geometries
    for idx, row in gdf.iterrows():
        geom = shape(row['geometry'])  # Convert WKT to Shapely geometry
        if not geom.is_valid:
            print(f"Fixing invalid geometry at index {idx}")
            gdf.at[idx, 'geometry'] = geom.buffer(0)  # Makes the geometry valid
        else:
            gdf.at[idx, 'geometry'] = geom
    return gdf

# %%
# Function to add wetland attributes
def add_wetland_attributes(gdf_wetland):
    """
    Load wetland attributes from a geodatabase and return as a GeoDataFrame.
    """
    # Read the geodatabase
    gdf_wetland_attributes = gpd.read_file(os.path.join(LOCAL_DATA_FOLDER, WETLAND_ATTRIBUTES))
    
    # Drop unnecessary columns
    columns_to_drop = [
        'SYSTEM', 'SYSTEM_NAME', 'SYSTEM_DEFINITION',
        'SUBSYSTEM', 'SUBSYSTEM_DEFINITION',
        'CLASS', 'CLASS_DEFINITION',
        'SUBCLASS', 'SUBCLASS_DEFINITION',
        'SPLIT_CLASS', 'SPLIT_CLASS_DEFINITION',
        'SPLIT_SUBCLASS', 'SPLIT_SUBCLASS_NAME', 'SPLIT_SUBCLASS_DEFINITION',
        'WATER_REGIME', 'WATER_REGIME_DEFINITION',
        'MODIFIER1', 'MODIFIER1_NAME', 'MODIFIER1_GROUP', 'MODIFIER1_SUBGROUP', 'MODIFIER1_DEFINITION',
        'MODIFIER2', 'MODIFIER2_NAME', 'MODIFIER2_GROUP', 'MODIFIER2_SUBGROUP', 'MODIFIER2_DEFINITION',
        'geometry'
    ]
    gdf_wetland_attributes = gdf_wetland_attributes.drop(
        columns=[col for col in columns_to_drop if col in gdf_wetland_attributes.columns])

    # Join datasets using the 'ATTRIBUTE' column
    wetlands_with_attributes = gdf_wetland.merge(
        gdf_wetland_attributes,
        how='left',
        on='ATTRIBUTE'
    )

    return wetlands_with_attributes

# %%
# Define global config variable to store dataset configurations
# Config includes paths, read arguments, and cleanup functions for each dataset
DATASET_CONFIG = {
    'transmission_lines': {
        'path': TRANSMISSION_LINES_DATA,
        'read_kwargs': {},
        'requires_state': False,
        'cleanup': lambda gdf: gdf
            .drop(columns=[
                'OBJECTID', 'SOURCE', 'SOURCEDATE', 'VAL_METHOD', 'VOLTAGE',
                'INFERRED', 'SUB_1', 'SUB_2'
            ])
            .assign(Shape__Len=gdf['Shape__Len'].round(2))
    },
    'railways': {
        'path': RAILWAYS_DATA,
        'read_kwargs': {'layer': 'North_American_Rail_Network_Lines'},
        'requires_state': False,
        'cleanup': lambda gdf: gdf
            .drop(columns=[
                'FRFRANODE', 'TOFRANODE', 'STFIPS', 'CNTYFIPS', 'STATEAB', 'COUNTRY',
                'FRADISTRCT', 'RROWNER1', 'RROWNER2', 'RROWNER3',
                'TRKRGHTS1', 'TRKRGHTS2', 'TRKRGHTS3', 'TRKRGHTS4', 'TRKRGHTS5',
                'TRKRGHTS6', 'TRKRGHTS7', 'TRKRGHTS8', 'TRKRGHTS9', 'DIVISION',
                'SUBDIV', 'BRANCH', 'YARDNAME', 'PASSNGR', 'STRACNET', 'TRACKS',
                'NET', 'MILES', 'TIMEZONE', 'SHAPE_Length'
            ], errors='ignore')
            .assign(KM=gdf['KM'].round(2))
    },
    'roadways': {
        'path': ROADWAYS_DATA,
        'read_kwargs': {},
        'requires_state': False,
        'cleanup': lambda gdf: gdf[gdf['COUNTRY'] == 2]
            .drop(columns=['DIR', 'LINKID', 'JURISCODE', 'ROADNUM', 'CLASS', 'NHS'], errors='ignore')
    },
    'wetlands': {
        'gdb_config': lambda state: {
            'folder': WETLANDS,
            'subfolder': f"{state}_geodatabase_wetlands",
            'gdb_name': f"{state}_geodatabase_wetlands.gdb"
        },
        'requires_state': True,
        'cleanup':  lambda gdf: gdf.drop(columns=['NWI_ID'], errors='ignore'),
        'postprocess': lambda gdf: add_wetland_attributes(gdf)
    },
    'protected_lands': {
        'gdb_config': lambda state: {
            'folder': PROTECTED_LANDS,
            'subfolder': f"PADUS4_1_State_{state}_GDB_KMZ",
            'gdb_name': f"PADUS4_1_State{state}.gdb"
        },
        'requires_state': True,
        'cleanup':  lambda gdf: gdf.drop(columns=[
                'FeatClass',
                'Category',
                'Own_Name',
                'Mang_Type',
                'Mang_Name',
                'Des_Tp',
                'Agg_Src',
                'GIS_Src',
                'Src_Date',
                'GIS_Acres',
                'Source_PAID',
                'Pub_Access',
                'Access_Src',
                'GAP_Sts',
                'IUCN_Cat',
                'Date_Est',
                'Comments',
                'Term',
                'Duration',
        ], errors='ignore'),
    }
}

# %%
# Function to clean and save dataset
def clean_and_save_dataset(
    dataset='railways',
    output_format='parquet',
    destination_path=PARQUET_INGESTION_PATH,
    state=None
):
    config = DATASET_CONFIG.get(dataset)
    if not config:
        raise ValueError(f"Unsupported dataset: {dataset}")

    if config.get('requires_state') and not state:
        raise ValueError(f"State must be provided for {dataset}")

    # Determine path
    if 'path' in config:
        full_path = os.path.join(LOCAL_DATA_FOLDER, config['path'])
        gdf = gpd.read_file(full_path, **config.get('read_kwargs', {}))
    else:
        # Handle GDB datasets
        gdb_info = config['gdb_config'](state)
        gdb_path = os.path.join(LOCAL_DATA_FOLDER, gdb_info['folder'], gdb_info['subfolder'], gdb_info['gdb_name'])

        # Find largest layer
        largest_layer = max(
            fiona.listlayers(gdb_path),
            key=lambda layer: len(fiona.open(gdb_path, layer=layer))
        )

        gdf = gpd.read_file(gdb_path, layer=largest_layer)
        print(f"Loaded {dataset} data from layer: {largest_layer} with {len(gdf)} features")

    # Optional post-processing
    if 'cleanup' in config:
        gdf = config['cleanup'](gdf)

    if 'postprocess' in config:
        gdf = config['postprocess'](gdf)
        print(f"Postprocessed {dataset} data")

    # Check that geometries are valid
    gdf = fix_invalid_geometries(gdf)

    # Set CRS
    gdf = gdf.to_crs(crs=geo_crs)
    print(f"CRS of data is {gdf.crs}")

    # Save output
    if output_format == 'parquet':
        filename = f"{state}_{dataset}.parquet" if state else f"{dataset}.parquet"
        filepath = os.path.join(destination_path, filename)
        gdf.to_parquet(filepath)
        print(f"{filename} data cleaned and saved successfully!")

# %%
# Upload local parquet file to GCS bucket
# First, define constants
BUCKET = 'geospatial-projects'
BUCKET_FOLDER = 'infra_parcels'
CREDENTIALS_PATH =  r"C:\Users\eprashar\AppData\Roaming\gcloud\application_default_credentials.json"
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = str(CREDENTIALS_PATH)

# Verify credentials
utils.check_and_authenticate(CREDENTIALS_PATH)
# Out:
# Credentials file is valid.

# %%
# Loop through all states and datasets to save cleaned parquet files
# List of states and datasets
states = ['PA', 'GA', 'MO', 'WI', 'NM', 'IL','WA','TX']
datasets = ['wetlands', 'protected_lands']

# Iterate through states and datasets
for state in states:
    for dataset in datasets:
        # Construct the filename
        filename = f"{state}_{dataset}.parquet" if state else f"{dataset}.parquet"
        destination_file = os.path.join(PARQUET_INGESTION_PATH, filename)

       # Check if the file already exists
        if not os.path.exists(destination_file):
            try:
                # Attempt to run the function
                clean_and_save_dataset(
                    dataset=dataset,
                    output_format='parquet',
                    destination_path=PARQUET_INGESTION_PATH,
                    state=state
                )
                print(f"File {filename} processed and saved.")
            except Exception as e:
                # Log the error and continue
                print(f"Failed to process {filename}: {e}")
        else:
            print(f"File {filename} already exists. Skipping.")
# Out:
# File PA_wetlands.parquet already exists. Skipping.
# File PA_protected_lands.parquet already exists. Skipping.
# Loaded wetlands data from layer: GA_Wetlands with 836046 features
# Postprocessed wetlands data
# Fixing invalid geometry at index 705
# Fixing invalid geometry at index 1555
# Fixing invalid geometry at index 7385
# Fixing invalid geometry at index 12620
# Fixing invalid geometry at index 19515
# Fixing invalid geometry at index 22327
# Fixing invalid geometry at index 30203
# Fixing invalid geometry at index 30785
# Fixing invalid geometry at index 38281
# Fixing invalid geometry at index 39885
# Fixing invalid geometry at index 41421
# Fixing invalid geometry at index 44453
# Fixing invalid geometry at index 44454
# Fixing invalid geometry at index 44542
# Fixing invalid geometry at index 44672
# Fixing invalid geometry at index 46600
# Fixing invalid geometry at index 46897
# Fixing invalid geometry at index 48446
# Fixing invalid geometry at index 48758
# Fixing invalid geometry at index 52366
# Fixing invalid geometry at index 57579
# Fixing invalid geometry at index 63484
# Fixing invalid geometry at index 63485
# Fixing invalid geometry at index 64291
# Fixing invalid geometry at index 64789
# Fixing invalid geometry at index 70508
# Fixing invalid geometry at index 86300
# Fixing invalid geometry at index 86302
# Fixing invalid geometry at index 91751
# Fixing invalid geometry at index 98517
# Fixing invalid geometry at index 103157
# Fixing invalid geometry at index 110998
# Fixing invalid geometry at index 112573
# Fixing invalid geometry at index 115997
# Fixing invalid geometry at index 123294
# Fixing invalid geometry at index 125030
# Fixing invalid geometry at index 126457
# Fixing invalid geometry at index 135514
# Fixing invalid geometry at index 136955
# Fixing invalid geometry at index 143216
# Fixing invalid geometry at index 143252
# Fixing invalid geometry at index 143321
# Fixing invalid geometry at index 146017
# Fixing invalid geometry at index 149202
# Fixing invalid geometry at index 155659
# Fixing invalid geometry at index 156433
# Fixing invalid geometry at index 156965
# Fixing invalid geometry at index 158510
# Fixing invalid geometry at index 165034
# Fixing invalid geometry at index 167190
# Fixing invalid geometry at index 167552
# Fixing invalid geometry at index 168283
# Fixing invalid geometry at index 177344
# Fixing invalid geometry at index 179072
# Fixing invalid geometry at index 185492
# Fixing invalid geometry at index 194705
# Fixing invalid geometry at index 195422
# Fixing invalid geometry at index 198221
# Fixing invalid geometry at index 203959
# Fixing invalid geometry at index 219842
# Fixing invalid geometry at index 229036
# Fixing invalid geometry at index 229161
# Fixing invalid geometry at index 238978
# Fixing invalid geometry at index 251737
# Fixing invalid geometry at index 257760
# Fixing invalid geometry at index 264384
# Fixing invalid geometry at index 273555
# Fixing invalid geometry at index 273582
# Fixing invalid geometry at index 275580
# Fixing invalid geometry at index 275788
# Fixing invalid geometry at index 286873
# Fixing invalid geometry at index 299923
# Fixing invalid geometry at index 301236
# Fixing invalid geometry at index 306868
# Fixing invalid geometry at index 307017
# Fixing invalid geometry at index 321020
# Fixing invalid geometry at index 321829
# Fixing invalid geometry at index 327231
# Fixing invalid geometry at index 344415
# Fixing invalid geometry at index 351979
# Fixing invalid geometry at index 357915
# Fixing invalid geometry at index 361430
# Fixing invalid geometry at index 362100
# Fixing invalid geometry at index 366523
# Fixing invalid geometry at index 366673
# Fixing invalid geometry at index 386309
# Fixing invalid geometry at index 392117
# Fixing invalid geometry at index 392284
# Fixing invalid geometry at index 397073
# Fixing invalid geometry at index 399901
# Fixing invalid geometry at index 406824
# Fixing invalid geometry at index 406827
# Fixing invalid geometry at index 407191
# Fixing invalid geometry at index 407508
# Fixing invalid geometry at index 407953
# Fixing invalid geometry at index 408057
# Fixing invalid geometry at index 409167
# Fixing invalid geometry at index 409810
# Fixing invalid geometry at index 409931
# Fixing invalid geometry at index 410432
# Fixing invalid geometry at index 414801
# Fixing invalid geometry at index 415865
# Fixing invalid geometry at index 415876
# Fixing invalid geometry at index 415909
# Fixing invalid geometry at index 415954
# Fixing invalid geometry at index 415972
# Fixing invalid geometry at index 416034
# Fixing invalid geometry at index 416050
# Fixing invalid geometry at index 416082
# Fixing invalid geometry at index 416162
# Fixing invalid geometry at index 416181
# Fixing invalid geometry at index 416246
# Fixing invalid geometry at index 416249
# Fixing invalid geometry at index 416255
# Fixing invalid geometry at index 416268
# Fixing invalid geometry at index 416885
# Fixing invalid geometry at index 417635
# Fixing invalid geometry at index 421927
# Fixing invalid geometry at index 428879
# Fixing invalid geometry at index 428917
# Fixing invalid geometry at index 433386
# Fixing invalid geometry at index 441364
# Fixing invalid geometry at index 448590
# Fixing invalid geometry at index 449171
# Fixing invalid geometry at index 450346
# Fixing invalid geometry at index 459484
# Fixing invalid geometry at index 460924
# Fixing invalid geometry at index 465283
# Fixing invalid geometry at index 473699
# Fixing invalid geometry at index 490569
# Fixing invalid geometry at index 498796
# Fixing invalid geometry at index 498896
# Fixing invalid geometry at index 499197
# Fixing invalid geometry at index 499399
# Fixing invalid geometry at index 507659
# Fixing invalid geometry at index 507718
# Fixing invalid geometry at index 507787
# Fixing invalid geometry at index 507900
# Fixing invalid geometry at index 507933
# Fixing invalid geometry at index 507994
# Fixing invalid geometry at index 508114
# Fixing invalid geometry at index 527880
# Fixing invalid geometry at index 528506
# Fixing invalid geometry at index 528706
# Fixing invalid geometry at index 529003
# Fixing invalid geometry at index 548454
# Fixing invalid geometry at index 548893
# Fixing invalid geometry at index 557060
# Fixing invalid geometry at index 562683
# Fixing invalid geometry at index 563045
# Fixing invalid geometry at index 566737
# Fixing invalid geometry at index 566967
# Fixing invalid geometry at index 567218
# Fixing invalid geometry at index 570555
# Fixing invalid geometry at index 586758
# Fixing invalid geometry at index 595938
# Fixing invalid geometry at index 595998
# Fixing invalid geometry at index 598572
# Fixing invalid geometry at index 598595
# Fixing invalid geometry at index 598602
# Fixing invalid geometry at index 599076
# Fixing invalid geometry at index 611778
# Fixing invalid geometry at index 613921
# Fixing invalid geometry at index 616164
# Fixing invalid geometry at index 617560
# Fixing invalid geometry at index 623013
# Fixing invalid geometry at index 623736
# Fixing invalid geometry at index 625111
# Fixing invalid geometry at index 625121
# Fixing invalid geometry at index 627127
# Fixing invalid geometry at index 633184
# Fixing invalid geometry at index 633228
# Fixing invalid geometry at index 635229
# Fixing invalid geometry at index 635235
# Fixing invalid geometry at index 640818
# Fixing invalid geometry at index 650378
# Fixing invalid geometry at index 650422
# Fixing invalid geometry at index 665247
# Fixing invalid geometry at index 665432
# Fixing invalid geometry at index 679785
# Fixing invalid geometry at index 679873
# Fixing invalid geometry at index 679905
# Fixing invalid geometry at index 679926
# Fixing invalid geometry at index 690105
# Fixing invalid geometry at index 697078
# Fixing invalid geometry at index 697112
# Fixing invalid geometry at index 697167
# Fixing invalid geometry at index 697224
# Fixing invalid geometry at index 698643
# Fixing invalid geometry at index 699625
# Fixing invalid geometry at index 700352
# Fixing invalid geometry at index 700833
# Fixing invalid geometry at index 701928
# Fixing invalid geometry at index 702603
# Fixing invalid geometry at index 703049
# Fixing invalid geometry at index 708029
# Fixing invalid geometry at index 708263
# Fixing invalid geometry at index 710847
# Fixing invalid geometry at index 711887
# Fixing invalid geometry at index 715365
# Fixing invalid geometry at index 722343
# Fixing invalid geometry at index 723679
# Fixing invalid geometry at index 738128
# Fixing invalid geometry at index 791506
# Fixing invalid geometry at index 791687
# Fixing invalid geometry at index 798926
# Fixing invalid geometry at index 806479
# Fixing invalid geometry at index 813994
# Fixing invalid geometry at index 815359
# Fixing invalid geometry at index 828503
# Fixing invalid geometry at index 834544
# Fixing invalid geometry at index 834547
# Fixing invalid geometry at index 834797
# Fixing invalid geometry at index 836037
# CRS of data is EPSG:4326
# GA_wetlands.parquet data cleaned and saved successfully!
# File GA_wetlands.parquet processed and saved.
# Loaded protected_lands data from layer: PADUS4_1Comb_DOD_Trib_NGP_Fee_Desig_Ease_State_GA with 7429 features
# Fixing invalid geometry at index 57
# Fixing invalid geometry at index 60
# Fixing invalid geometry at index 61
# Fixing invalid geometry at index 69
# Fixing invalid geometry at index 72
# Fixing invalid geometry at index 73
# Fixing invalid geometry at index 3384
# Fixing invalid geometry at index 3385
# Fixing invalid geometry at index 3386
# Fixing invalid geometry at index 3882
# Fixing invalid geometry at index 4082
# Fixing invalid geometry at index 4260
# Fixing invalid geometry at index 4337
# Fixing invalid geometry at index 4341
# CRS of data is EPSG:4326
# GA_protected_lands.parquet data cleaned and saved successfully!
# File GA_protected_lands.parquet processed and saved.
# Loaded wetlands data from layer: MO_Wetlands with 1257669 features
# Postprocessed wetlands data
# Fixing invalid geometry at index 1956
# Fixing invalid geometry at index 2001
# Fixing invalid geometry at index 2531
# Fixing invalid geometry at index 2590
# Fixing invalid geometry at index 10776
# Fixing invalid geometry at index 10786
# Fixing invalid geometry at index 10824
# Fixing invalid geometry at index 10858
# Fixing invalid geometry at index 13689
# Fixing invalid geometry at index 13889
# Fixing invalid geometry at index 14461
# Fixing invalid geometry at index 21643
# Fixing invalid geometry at index 21719
# Fixing invalid geometry at index 21751
# Fixing invalid geometry at index 44166
# Fixing invalid geometry at index 66722
# Fixing invalid geometry at index 96353
# Fixing invalid geometry at index 96363
# Fixing invalid geometry at index 100140
# Fixing invalid geometry at index 106507
# Fixing invalid geometry at index 106587
# Fixing invalid geometry at index 110188
# Fixing invalid geometry at index 117333
# Fixing invalid geometry at index 117363
# Fixing invalid geometry at index 117383
# Fixing invalid geometry at index 121046
# Fixing invalid geometry at index 132522
# Fixing invalid geometry at index 139999
# Fixing invalid geometry at index 140037
# Fixing invalid geometry at index 141392
# Fixing invalid geometry at index 150259
# Fixing invalid geometry at index 153630
# Fixing invalid geometry at index 160467
# Fixing invalid geometry at index 160473
# Fixing invalid geometry at index 160507
# Fixing invalid geometry at index 162921
# Fixing invalid geometry at index 168913
# Fixing invalid geometry at index 169362
# Fixing invalid geometry at index 180900
# Fixing invalid geometry at index 180913
# Fixing invalid geometry at index 180981
# Fixing invalid geometry at index 181031
# Fixing invalid geometry at index 195274
# Fixing invalid geometry at index 195283
# Fixing invalid geometry at index 206745
# Fixing invalid geometry at index 206807
# Fixing invalid geometry at index 206832
# Fixing invalid geometry at index 217929
# Fixing invalid geometry at index 218589
# Fixing invalid geometry at index 230291
# Fixing invalid geometry at index 230312
# Fixing invalid geometry at index 234089
# Fixing invalid geometry at index 234214
# Fixing invalid geometry at index 235545
# Fixing invalid geometry at index 240608
# Fixing invalid geometry at index 242589
# Fixing invalid geometry at index 242607
# Fixing invalid geometry at index 242642
# Fixing invalid geometry at index 243834
# Fixing invalid geometry at index 245659
# Fixing invalid geometry at index 245823
# Fixing invalid geometry at index 245973
# Fixing invalid geometry at index 246093
# Fixing invalid geometry at index 246221
# Fixing invalid geometry at index 247089
# Fixing invalid geometry at index 247453
# Fixing invalid geometry at index 256492
# Fixing invalid geometry at index 264690
# Fixing invalid geometry at index 264946
# Fixing invalid geometry at index 267323
# Fixing invalid geometry at index 276679
# Fixing invalid geometry at index 280406
# Fixing invalid geometry at index 291495
# Fixing invalid geometry at index 298726
# Fixing invalid geometry at index 303009
# Fixing invalid geometry at index 303321
# Fixing invalid geometry at index 303393
# Fixing invalid geometry at index 310319
# Fixing invalid geometry at index 322428
# Fixing invalid geometry at index 322466
# Fixing invalid geometry at index 336541
# Fixing invalid geometry at index 352728
# Fixing invalid geometry at index 353325
# Fixing invalid geometry at index 354119
# Fixing invalid geometry at index 363779
# Fixing invalid geometry at index 363811
# Fixing invalid geometry at index 363863
# Fixing invalid geometry at index 373694
# Fixing invalid geometry at index 417694
# Fixing invalid geometry at index 453636
# Fixing invalid geometry at index 471243
# Fixing invalid geometry at index 510966
# Fixing invalid geometry at index 510973
# Fixing invalid geometry at index 513734
# Fixing invalid geometry at index 530993
# Fixing invalid geometry at index 567289
# Fixing invalid geometry at index 567373
# Fixing invalid geometry at index 578082
# Fixing invalid geometry at index 618696
# Fixing invalid geometry at index 620518
# Fixing invalid geometry at index 621317
# Fixing invalid geometry at index 621561
# Fixing invalid geometry at index 621772
# Fixing invalid geometry at index 622779
# Fixing invalid geometry at index 623058
# Fixing invalid geometry at index 623111
# Fixing invalid geometry at index 635479
# Fixing invalid geometry at index 649108
# Fixing invalid geometry at index 649628
# Fixing invalid geometry at index 649731
# Fixing invalid geometry at index 649818
# Fixing invalid geometry at index 655955
# Fixing invalid geometry at index 656355
# Fixing invalid geometry at index 659107
# Fixing invalid geometry at index 659267
# Fixing invalid geometry at index 659904
# Fixing invalid geometry at index 661476
# Fixing invalid geometry at index 661500
# Fixing invalid geometry at index 664751
# Fixing invalid geometry at index 664836
# Fixing invalid geometry at index 664903
# Fixing invalid geometry at index 669611
# Fixing invalid geometry at index 670489
# Fixing invalid geometry at index 670516
# Fixing invalid geometry at index 671033
# Fixing invalid geometry at index 672432
# Fixing invalid geometry at index 672607
# Fixing invalid geometry at index 678033
# Fixing invalid geometry at index 678320
# Fixing invalid geometry at index 680556
# Fixing invalid geometry at index 683622
# Fixing invalid geometry at index 683789
# Fixing invalid geometry at index 683870
# Fixing invalid geometry at index 684085
# Fixing invalid geometry at index 693982
# Fixing invalid geometry at index 700896
# Fixing invalid geometry at index 700937
# Fixing invalid geometry at index 700972
# Fixing invalid geometry at index 714667
# Fixing invalid geometry at index 714693
# Fixing invalid geometry at index 714703
# Fixing invalid geometry at index 723583
# Fixing invalid geometry at index 738395
# Fixing invalid geometry at index 739899
# Fixing invalid geometry at index 748167
# Fixing invalid geometry at index 760039
# Fixing invalid geometry at index 780629
# Fixing invalid geometry at index 786576
# Fixing invalid geometry at index 786857
# Fixing invalid geometry at index 800510
# Fixing invalid geometry at index 809102
# Fixing invalid geometry at index 828201
# Fixing invalid geometry at index 832977
# Fixing invalid geometry at index 847591
# Fixing invalid geometry at index 878597
# Fixing invalid geometry at index 893598
# Fixing invalid geometry at index 901288
# Fixing invalid geometry at index 936064
# Fixing invalid geometry at index 949289
# Fixing invalid geometry at index 961535
# Fixing invalid geometry at index 1009764
# Fixing invalid geometry at index 1047646
# Fixing invalid geometry at index 1048295
# Fixing invalid geometry at index 1049110
# Fixing invalid geometry at index 1049871
# Fixing invalid geometry at index 1068592
# Fixing invalid geometry at index 1069202
# Fixing invalid geometry at index 1079467
# Fixing invalid geometry at index 1104759
# Fixing invalid geometry at index 1120103
# Fixing invalid geometry at index 1121573
# Fixing invalid geometry at index 1121695
# Fixing invalid geometry at index 1135871
# Fixing invalid geometry at index 1136626
# Fixing invalid geometry at index 1192581
# Fixing invalid geometry at index 1222711
# Fixing invalid geometry at index 1233443
# CRS of data is EPSG:4326
# MO_wetlands.parquet data cleaned and saved successfully!
# File MO_wetlands.parquet processed and saved.
# Loaded protected_lands data from layer: PADUS4_1Comb_DOD_Trib_NGP_Fee_Desig_Ease_State_MO with 5778 features
# Fixing invalid geometry at index 2593
# Fixing invalid geometry at index 2844
# Fixing invalid geometry at index 2903
# Fixing invalid geometry at index 2947
# Fixing invalid geometry at index 3088
# Fixing invalid geometry at index 3093
# Fixing invalid geometry at index 3185
# Fixing invalid geometry at index 3350
# Fixing invalid geometry at index 3407
# CRS of data is EPSG:4326
# MO_protected_lands.parquet data cleaned and saved successfully!
# File MO_protected_lands.parquet processed and saved.
# Loaded wetlands data from layer: WI_Wetlands with 1759154 features
# Postprocessed wetlands data
# Fixing invalid geometry at index 4022
# Fixing invalid geometry at index 5239
# Fixing invalid geometry at index 11684
# Fixing invalid geometry at index 38941
# Fixing invalid geometry at index 44216
# Fixing invalid geometry at index 46478
# Fixing invalid geometry at index 63520
# Fixing invalid geometry at index 70399
# Fixing invalid geometry at index 76301
# Fixing invalid geometry at index 108100
# Fixing invalid geometry at index 108982
# Fixing invalid geometry at index 109219
# Fixing invalid geometry at index 134596
# Fixing invalid geometry at index 164109
# Fixing invalid geometry at index 167107
# Fixing invalid geometry at index 168696
# Fixing invalid geometry at index 172459
# Fixing invalid geometry at index 192342
# Fixing invalid geometry at index 192556
# Fixing invalid geometry at index 201202
# Fixing invalid geometry at index 252786
# Fixing invalid geometry at index 256499
# Fixing invalid geometry at index 258103
# Fixing invalid geometry at index 258176
# Fixing invalid geometry at index 278740
# Fixing invalid geometry at index 278747
# Fixing invalid geometry at index 278839
# Fixing invalid geometry at index 301315
# Fixing invalid geometry at index 312452
# Fixing invalid geometry at index 312485
# Fixing invalid geometry at index 312670
# Fixing invalid geometry at index 350500
# Fixing invalid geometry at index 354943
# Fixing invalid geometry at index 355046
# Fixing invalid geometry at index 355120
# Fixing invalid geometry at index 377533
# Fixing invalid geometry at index 438060
# Fixing invalid geometry at index 450821
# Fixing invalid geometry at index 552148
# Fixing invalid geometry at index 568522
# Fixing invalid geometry at index 597821
# Fixing invalid geometry at index 691517
# Fixing invalid geometry at index 705046
# Fixing invalid geometry at index 749664
# Fixing invalid geometry at index 755676
# Fixing invalid geometry at index 766918
# Fixing invalid geometry at index 819985
# Fixing invalid geometry at index 825454
# Fixing invalid geometry at index 832978
# Fixing invalid geometry at index 833093
# Fixing invalid geometry at index 840037
# Fixing invalid geometry at index 853264
# Fixing invalid geometry at index 853341
# Fixing invalid geometry at index 858862
# Fixing invalid geometry at index 858874
# Fixing invalid geometry at index 865077
# Fixing invalid geometry at index 869498
# Fixing invalid geometry at index 869620
# Fixing invalid geometry at index 873788
# Fixing invalid geometry at index 873822
# Fixing invalid geometry at index 875615
# Fixing invalid geometry at index 875632
# Fixing invalid geometry at index 879384
# Fixing invalid geometry at index 888564
# Fixing invalid geometry at index 897088
# Fixing invalid geometry at index 918593
# Fixing invalid geometry at index 944825
# Fixing invalid geometry at index 946189
# Fixing invalid geometry at index 958814
# Fixing invalid geometry at index 958842
# Fixing invalid geometry at index 958990
# Fixing invalid geometry at index 973491
# Fixing invalid geometry at index 981472
# Fixing invalid geometry at index 986836
# Fixing invalid geometry at index 996662
# Fixing invalid geometry at index 998958
# Fixing invalid geometry at index 1002767
# Fixing invalid geometry at index 1009241
# Fixing invalid geometry at index 1012706
# Fixing invalid geometry at index 1013390
# Fixing invalid geometry at index 1020350
# Fixing invalid geometry at index 1020367
# Fixing invalid geometry at index 1026524
# Fixing invalid geometry at index 1080471
# Fixing invalid geometry at index 1087715
# Fixing invalid geometry at index 1094760
# Fixing invalid geometry at index 1094795
# Fixing invalid geometry at index 1102504
# Fixing invalid geometry at index 1109084
# Fixing invalid geometry at index 1109903
# Fixing invalid geometry at index 1109944
# Fixing invalid geometry at index 1112509
# Fixing invalid geometry at index 1114368
# Fixing invalid geometry at index 1123558
# Fixing invalid geometry at index 1123669
# Fixing invalid geometry at index 1125944
# Fixing invalid geometry at index 1130549
# Fixing invalid geometry at index 1130631
# Fixing invalid geometry at index 1130963
# Fixing invalid geometry at index 1135362
# Fixing invalid geometry at index 1139319
# Fixing invalid geometry at index 1139329
# Fixing invalid geometry at index 1139439
# Fixing invalid geometry at index 1140387
# Fixing invalid geometry at index 1140617
# Fixing invalid geometry at index 1145221
# Fixing invalid geometry at index 1153591
# Fixing invalid geometry at index 1160675
# Fixing invalid geometry at index 1166843
# Fixing invalid geometry at index 1168034
# Fixing invalid geometry at index 1170860
# Fixing invalid geometry at index 1182469
# Fixing invalid geometry at index 1195392
# Fixing invalid geometry at index 1200595
# Fixing invalid geometry at index 1218236
# Fixing invalid geometry at index 1218757
# Fixing invalid geometry at index 1222976
# Fixing invalid geometry at index 1223308
# Fixing invalid geometry at index 1223770
# Fixing invalid geometry at index 1223799
# Fixing invalid geometry at index 1225186
# Fixing invalid geometry at index 1229586
# Fixing invalid geometry at index 1229657
# Fixing invalid geometry at index 1240967
# Fixing invalid geometry at index 1241019
# Fixing invalid geometry at index 1241073
# Fixing invalid geometry at index 1250430
# Fixing invalid geometry at index 1250676
# Fixing invalid geometry at index 1259717
# Fixing invalid geometry at index 1259724
# Fixing invalid geometry at index 1259788
# Fixing invalid geometry at index 1270963
# Fixing invalid geometry at index 1272187
# Fixing invalid geometry at index 1273600
# Fixing invalid geometry at index 1275359
# Fixing invalid geometry at index 1275613
# Fixing invalid geometry at index 1280281
# Fixing invalid geometry at index 1280492
# Fixing invalid geometry at index 1283957
# Fixing invalid geometry at index 1285689
# Fixing invalid geometry at index 1291547
# Fixing invalid geometry at index 1292249
# Fixing invalid geometry at index 1298802
# Fixing invalid geometry at index 1301098
# Fixing invalid geometry at index 1306890
# Fixing invalid geometry at index 1307229
# Fixing invalid geometry at index 1308615
# Fixing invalid geometry at index 1309874
# Fixing invalid geometry at index 1313672
# Fixing invalid geometry at index 1313679
# Fixing invalid geometry at index 1329302
# Fixing invalid geometry at index 1329372
# Fixing invalid geometry at index 1334004
# Fixing invalid geometry at index 1334007
# Fixing invalid geometry at index 1427585
# Fixing invalid geometry at index 1448887
# Fixing invalid geometry at index 1476928
# Fixing invalid geometry at index 1490731
# Fixing invalid geometry at index 1497879
# Fixing invalid geometry at index 1518033
# Fixing invalid geometry at index 1530068
# Fixing invalid geometry at index 1536276
# Fixing invalid geometry at index 1555282
# Fixing invalid geometry at index 1555396
# Fixing invalid geometry at index 1576335
# Fixing invalid geometry at index 1579606
# Fixing invalid geometry at index 1579661
# Fixing invalid geometry at index 1581450
# Fixing invalid geometry at index 1583107
# Fixing invalid geometry at index 1583139
# Fixing invalid geometry at index 1607861
# Fixing invalid geometry at index 1611485
# Fixing invalid geometry at index 1612548
# Fixing invalid geometry at index 1625802
# Fixing invalid geometry at index 1628707
# Fixing invalid geometry at index 1638793
# Fixing invalid geometry at index 1639563
# Fixing invalid geometry at index 1641136
# Fixing invalid geometry at index 1644824
# Fixing invalid geometry at index 1644835
# Fixing invalid geometry at index 1664987
# Fixing invalid geometry at index 1666169
# Fixing invalid geometry at index 1673667
# Fixing invalid geometry at index 1680169
# Fixing invalid geometry at index 1738440
# CRS of data is EPSG:4326
# WI_wetlands.parquet data cleaned and saved successfully!
# File WI_wetlands.parquet processed and saved.
# Loaded protected_lands data from layer: PADUS4_1Comb_DOD_Trib_NGP_Fee_Desig_Ease_State_WI with 21614 features
# Fixing invalid geometry at index 31
# Fixing invalid geometry at index 44
# Fixing invalid geometry at index 58
# Fixing invalid geometry at index 59
# Fixing invalid geometry at index 66
# Fixing invalid geometry at index 67
# Fixing invalid geometry at index 73
# Fixing invalid geometry at index 87
# Fixing invalid geometry at index 88
# Fixing invalid geometry at index 97
# Fixing invalid geometry at index 98
# Fixing invalid geometry at index 186
# Fixing invalid geometry at index 188
# Fixing invalid geometry at index 193
# Fixing invalid geometry at index 194
# Fixing invalid geometry at index 204
# Fixing invalid geometry at index 205
# Fixing invalid geometry at index 206
# Fixing invalid geometry at index 207
# Fixing invalid geometry at index 209
# Fixing invalid geometry at index 211
# Fixing invalid geometry at index 222
# Fixing invalid geometry at index 223
# Fixing invalid geometry at index 236
# Fixing invalid geometry at index 240
# Fixing invalid geometry at index 241
# Fixing invalid geometry at index 250
# Fixing invalid geometry at index 251
# Fixing invalid geometry at index 255
# Fixing invalid geometry at index 257
# Fixing invalid geometry at index 266
# Fixing invalid geometry at index 267
# Fixing invalid geometry at index 335
# Fixing invalid geometry at index 338
# Fixing invalid geometry at index 398
# Fixing invalid geometry at index 401
# Fixing invalid geometry at index 469
# Fixing invalid geometry at index 578
# Fixing invalid geometry at index 594
# Fixing invalid geometry at index 598
# Fixing invalid geometry at index 599
# Fixing invalid geometry at index 600
# Fixing invalid geometry at index 761
# Fixing invalid geometry at index 4465
# Fixing invalid geometry at index 4635
# Fixing invalid geometry at index 5054
# Fixing invalid geometry at index 5055
# Fixing invalid geometry at index 5064
# Fixing invalid geometry at index 5065
# Fixing invalid geometry at index 5074
# Fixing invalid geometry at index 5117
# Fixing invalid geometry at index 5119
# Fixing invalid geometry at index 5121
# Fixing invalid geometry at index 5155
# Fixing invalid geometry at index 5174
# Fixing invalid geometry at index 5197
# Fixing invalid geometry at index 5199
# Fixing invalid geometry at index 5201
# Fixing invalid geometry at index 5202
# Fixing invalid geometry at index 5203
# Fixing invalid geometry at index 5204
# Fixing invalid geometry at index 5206
# Fixing invalid geometry at index 5211
# Fixing invalid geometry at index 5217
# Fixing invalid geometry at index 5226
# Fixing invalid geometry at index 5227
# Fixing invalid geometry at index 5232
# Fixing invalid geometry at index 5243
# Fixing invalid geometry at index 5254
# Fixing invalid geometry at index 5258
# Fixing invalid geometry at index 5262
# Fixing invalid geometry at index 5263
# Fixing invalid geometry at index 5267
# Fixing invalid geometry at index 5273
# Fixing invalid geometry at index 5275
# Fixing invalid geometry at index 5278
# Fixing invalid geometry at index 5279
# Fixing invalid geometry at index 5280
# Fixing invalid geometry at index 5297
# Fixing invalid geometry at index 5321
# Fixing invalid geometry at index 5323
# Fixing invalid geometry at index 5324
# Fixing invalid geometry at index 5342
# Fixing invalid geometry at index 5385
# Fixing invalid geometry at index 5400
# Fixing invalid geometry at index 5415
# Fixing invalid geometry at index 5416
# Fixing invalid geometry at index 5427
# Fixing invalid geometry at index 5459
# Fixing invalid geometry at index 5464
# Fixing invalid geometry at index 5505
# Fixing invalid geometry at index 5513
# Fixing invalid geometry at index 5553
# Fixing invalid geometry at index 5574
# Fixing invalid geometry at index 5575
# Fixing invalid geometry at index 5577
# Fixing invalid geometry at index 5589
# Fixing invalid geometry at index 5597
# Fixing invalid geometry at index 5603
# Fixing invalid geometry at index 5624
# Fixing invalid geometry at index 5629
# Fixing invalid geometry at index 5636
# Fixing invalid geometry at index 5639
# Fixing invalid geometry at index 5655
# Fixing invalid geometry at index 5657
# Fixing invalid geometry at index 5661
# Fixing invalid geometry at index 5662
# Fixing invalid geometry at index 5768
# Fixing invalid geometry at index 5806
# Fixing invalid geometry at index 5808
# Fixing invalid geometry at index 5818
# Fixing invalid geometry at index 5826
# Fixing invalid geometry at index 5843
# Fixing invalid geometry at index 5861
# Fixing invalid geometry at index 5865
# Fixing invalid geometry at index 5894
# Fixing invalid geometry at index 5895
# Fixing invalid geometry at index 5896
# Fixing invalid geometry at index 5904
# Fixing invalid geometry at index 5907
# Fixing invalid geometry at index 5909
# Fixing invalid geometry at index 5910
# Fixing invalid geometry at index 5915
# Fixing invalid geometry at index 5916
# Fixing invalid geometry at index 5917
# Fixing invalid geometry at index 5934
# Fixing invalid geometry at index 5937
# Fixing invalid geometry at index 5939
# Fixing invalid geometry at index 5940
# Fixing invalid geometry at index 5944
# Fixing invalid geometry at index 5945
# Fixing invalid geometry at index 5947
# Fixing invalid geometry at index 5948
# Fixing invalid geometry at index 5959
# Fixing invalid geometry at index 5961
# Fixing invalid geometry at index 5962
# Fixing invalid geometry at index 5965
# Fixing invalid geometry at index 6100
# CRS of data is EPSG:4326
# WI_protected_lands.parquet data cleaned and saved successfully!
# File WI_protected_lands.parquet processed and saved.
# Loaded wetlands data from layer: NM_Wetlands with 502621 features
# Postprocessed wetlands data
# Fixing invalid geometry at index 31308
# Fixing invalid geometry at index 46010
# Fixing invalid geometry at index 46274
# Fixing invalid geometry at index 54714
# Fixing invalid geometry at index 57632
# Fixing invalid geometry at index 57940
# Fixing invalid geometry at index 85826
# Fixing invalid geometry at index 102924
# Fixing invalid geometry at index 110296
# Fixing invalid geometry at index 112749
# Fixing invalid geometry at index 123529
# Fixing invalid geometry at index 124863
# Fixing invalid geometry at index 131118
# Fixing invalid geometry at index 137438
# Fixing invalid geometry at index 138661
# Fixing invalid geometry at index 173619
# Fixing invalid geometry at index 184179
# Fixing invalid geometry at index 206196
# Fixing invalid geometry at index 220355
# Fixing invalid geometry at index 220442
# Fixing invalid geometry at index 221008
# Fixing invalid geometry at index 227192
# Fixing invalid geometry at index 227257
# Fixing invalid geometry at index 233390
# Fixing invalid geometry at index 240395
# Fixing invalid geometry at index 242480
# Fixing invalid geometry at index 248528
# Fixing invalid geometry at index 250244
# Fixing invalid geometry at index 255921
# Fixing invalid geometry at index 256308
# Fixing invalid geometry at index 261356
# Fixing invalid geometry at index 262380
# Fixing invalid geometry at index 267119
# Fixing invalid geometry at index 275072
# Fixing invalid geometry at index 292703
# Fixing invalid geometry at index 294205
# Fixing invalid geometry at index 297390
# Fixing invalid geometry at index 323239
# Fixing invalid geometry at index 325092
# Fixing invalid geometry at index 335360
# Fixing invalid geometry at index 347839
# Fixing invalid geometry at index 348078
# Fixing invalid geometry at index 360089
# Fixing invalid geometry at index 367383
# Fixing invalid geometry at index 370041
# Fixing invalid geometry at index 384220
# Fixing invalid geometry at index 385523
# Fixing invalid geometry at index 389066
# Fixing invalid geometry at index 391081
# Fixing invalid geometry at index 397606
# Fixing invalid geometry at index 401652
# Fixing invalid geometry at index 401892
# Fixing invalid geometry at index 406129
# Fixing invalid geometry at index 435553
# Fixing invalid geometry at index 447987
# Fixing invalid geometry at index 451552
# Fixing invalid geometry at index 454462
# Fixing invalid geometry at index 456082
# Fixing invalid geometry at index 456109
# Fixing invalid geometry at index 457391
# Fixing invalid geometry at index 488925
# CRS of data is EPSG:4326
# NM_wetlands.parquet data cleaned and saved successfully!
# File NM_wetlands.parquet processed and saved.
# Loaded protected_lands data from layer: PADUS4_1Comb_DOD_Trib_NGP_Fee_Desig_Ease_State_NM with 2352 features
# Fixing invalid geometry at index 52
# Fixing invalid geometry at index 58
# Fixing invalid geometry at index 59
# Fixing invalid geometry at index 61
# Fixing invalid geometry at index 63
# Fixing invalid geometry at index 64
# Fixing invalid geometry at index 65
# Fixing invalid geometry at index 66
# Fixing invalid geometry at index 95
# Fixing invalid geometry at index 108
# Fixing invalid geometry at index 109
# Fixing invalid geometry at index 120
# Fixing invalid geometry at index 242
# Fixing invalid geometry at index 246
# Fixing invalid geometry at index 259
# Fixing invalid geometry at index 279
# Fixing invalid geometry at index 290
# Fixing invalid geometry at index 297
# Fixing invalid geometry at index 311
# Fixing invalid geometry at index 315
# Fixing invalid geometry at index 320
# Fixing invalid geometry at index 324
# Fixing invalid geometry at index 329
# Fixing invalid geometry at index 352
# Fixing invalid geometry at index 902
# Fixing invalid geometry at index 984
# Fixing invalid geometry at index 1407
# Fixing invalid geometry at index 1410
# Fixing invalid geometry at index 1417
# Fixing invalid geometry at index 1434
# Fixing invalid geometry at index 1450
# Fixing invalid geometry at index 1478
# Fixing invalid geometry at index 1491
# Fixing invalid geometry at index 1503
# Fixing invalid geometry at index 1506
# Fixing invalid geometry at index 1646
# Fixing invalid geometry at index 1649
# Fixing invalid geometry at index 1654
# Fixing invalid geometry at index 1661
# Fixing invalid geometry at index 1664
# Fixing invalid geometry at index 1670
# Fixing invalid geometry at index 1671
# Fixing invalid geometry at index 1681
# Fixing invalid geometry at index 1686
# Fixing invalid geometry at index 1749
# Fixing invalid geometry at index 1752
# Fixing invalid geometry at index 1791
# CRS of data is EPSG:4326
# NM_protected_lands.parquet data cleaned and saved successfully!
# File NM_protected_lands.parquet processed and saved.
# Loaded wetlands data from layer: IL_Wetlands with 538229 features
# Postprocessed wetlands data
# Fixing invalid geometry at index 155
# Fixing invalid geometry at index 9547
# Fixing invalid geometry at index 10668
# Fixing invalid geometry at index 11763
# Fixing invalid geometry at index 14610
# Fixing invalid geometry at index 15956
# Fixing invalid geometry at index 17485
# Fixing invalid geometry at index 17815
# Fixing invalid geometry at index 21798
# Fixing invalid geometry at index 21838
# Fixing invalid geometry at index 21901
# Fixing invalid geometry at index 31029
# Fixing invalid geometry at index 36631
# Fixing invalid geometry at index 36685
# Fixing invalid geometry at index 38972
# Fixing invalid geometry at index 46652
# Fixing invalid geometry at index 50940
# Fixing invalid geometry at index 55428
# Fixing invalid geometry at index 59550
# Fixing invalid geometry at index 60108
# Fixing invalid geometry at index 64143
# Fixing invalid geometry at index 64151
# Fixing invalid geometry at index 67396
# Fixing invalid geometry at index 67759
# Fixing invalid geometry at index 86462
# Fixing invalid geometry at index 91225
# Fixing invalid geometry at index 91994
# Fixing invalid geometry at index 94779
# Fixing invalid geometry at index 96852
# Fixing invalid geometry at index 105601
# Fixing invalid geometry at index 105802
# Fixing invalid geometry at index 111074
# Fixing invalid geometry at index 111333
# Fixing invalid geometry at index 112245
# Fixing invalid geometry at index 127859
# Fixing invalid geometry at index 135016
# Fixing invalid geometry at index 135024
# Fixing invalid geometry at index 135037
# Fixing invalid geometry at index 135056
# Fixing invalid geometry at index 138165
# Fixing invalid geometry at index 139462
# Fixing invalid geometry at index 144309
# Fixing invalid geometry at index 144376
# Fixing invalid geometry at index 144381
# Fixing invalid geometry at index 144396
# Fixing invalid geometry at index 144397
# Fixing invalid geometry at index 144409
# Fixing invalid geometry at index 144411
# Fixing invalid geometry at index 144419
# Fixing invalid geometry at index 144558
# Fixing invalid geometry at index 144760
# Fixing invalid geometry at index 144769
# Fixing invalid geometry at index 152900
# Fixing invalid geometry at index 154410
# Fixing invalid geometry at index 159844
# Fixing invalid geometry at index 159879
# Fixing invalid geometry at index 159899
# Fixing invalid geometry at index 160230
# Fixing invalid geometry at index 162738
# Fixing invalid geometry at index 181676
# Fixing invalid geometry at index 185120
# Fixing invalid geometry at index 192274
# Fixing invalid geometry at index 201997
# Fixing invalid geometry at index 204272
# Fixing invalid geometry at index 206170
# Fixing invalid geometry at index 217082
# Fixing invalid geometry at index 224236
# Fixing invalid geometry at index 229783
# Fixing invalid geometry at index 240957
# Fixing invalid geometry at index 247669
# Fixing invalid geometry at index 247688
# Fixing invalid geometry at index 247694
# Fixing invalid geometry at index 247721
# Fixing invalid geometry at index 247729
# Fixing invalid geometry at index 247734
# Fixing invalid geometry at index 247768
# Fixing invalid geometry at index 247819
# Fixing invalid geometry at index 249120
# Fixing invalid geometry at index 250567
# Fixing invalid geometry at index 250865
# Fixing invalid geometry at index 256488
# Fixing invalid geometry at index 257280
# Fixing invalid geometry at index 258050
# Fixing invalid geometry at index 259972
# Fixing invalid geometry at index 265876
# Fixing invalid geometry at index 265945
# Fixing invalid geometry at index 267038
# Fixing invalid geometry at index 273821
# Fixing invalid geometry at index 274008
# Fixing invalid geometry at index 276187
# Fixing invalid geometry at index 276664
# Fixing invalid geometry at index 276985
# Fixing invalid geometry at index 284768
# Fixing invalid geometry at index 284932
# Fixing invalid geometry at index 284957
# Fixing invalid geometry at index 284960
# Fixing invalid geometry at index 285080
# Fixing invalid geometry at index 285775
# Fixing invalid geometry at index 287385
# Fixing invalid geometry at index 288056
# Fixing invalid geometry at index 288100
# Fixing invalid geometry at index 288622
# Fixing invalid geometry at index 295421
# Fixing invalid geometry at index 295424
# Fixing invalid geometry at index 295553
# Fixing invalid geometry at index 295583
# Fixing invalid geometry at index 297815
# Fixing invalid geometry at index 308477
# Fixing invalid geometry at index 308575
# Fixing invalid geometry at index 308812
# Fixing invalid geometry at index 308988
# Fixing invalid geometry at index 319245
# Fixing invalid geometry at index 319353
# Fixing invalid geometry at index 319354
# Fixing invalid geometry at index 320830
# Fixing invalid geometry at index 321078
# Fixing invalid geometry at index 331196
# Fixing invalid geometry at index 332349
# Fixing invalid geometry at index 340174
# Fixing invalid geometry at index 341314
# Fixing invalid geometry at index 347693
# Fixing invalid geometry at index 348930
# Fixing invalid geometry at index 349983
# Fixing invalid geometry at index 350087
# Fixing invalid geometry at index 350128
# Fixing invalid geometry at index 350132
# Fixing invalid geometry at index 350468
# Fixing invalid geometry at index 350632
# Fixing invalid geometry at index 355627
# Fixing invalid geometry at index 359035
# Fixing invalid geometry at index 362050
# Fixing invalid geometry at index 362669
# Fixing invalid geometry at index 362677
# Fixing invalid geometry at index 362849
# Fixing invalid geometry at index 373270
# Fixing invalid geometry at index 374235
# Fixing invalid geometry at index 374593
# Fixing invalid geometry at index 375964
# Fixing invalid geometry at index 376114
# Fixing invalid geometry at index 376407
# Fixing invalid geometry at index 385785
# Fixing invalid geometry at index 390211
# Fixing invalid geometry at index 400989
# Fixing invalid geometry at index 406524
# Fixing invalid geometry at index 409526
# Fixing invalid geometry at index 409751
# Fixing invalid geometry at index 409758
# Fixing invalid geometry at index 412914
# Fixing invalid geometry at index 413195
# Fixing invalid geometry at index 413235
# Fixing invalid geometry at index 420467
# Fixing invalid geometry at index 420708
# Fixing invalid geometry at index 423822
# Fixing invalid geometry at index 424499
# Fixing invalid geometry at index 424596
# Fixing invalid geometry at index 428416
# Fixing invalid geometry at index 428610
# Fixing invalid geometry at index 453404
# Fixing invalid geometry at index 462260
# Fixing invalid geometry at index 462384
# Fixing invalid geometry at index 467620
# Fixing invalid geometry at index 469785
# Fixing invalid geometry at index 469806
# Fixing invalid geometry at index 469867
# Fixing invalid geometry at index 469924
# Fixing invalid geometry at index 472137
# Fixing invalid geometry at index 472208
# Fixing invalid geometry at index 472408
# Fixing invalid geometry at index 472725
# Fixing invalid geometry at index 479411
# Fixing invalid geometry at index 479444
# Fixing invalid geometry at index 479458
# Fixing invalid geometry at index 480743
# Fixing invalid geometry at index 480942
# Fixing invalid geometry at index 481026
# Fixing invalid geometry at index 489169
# Fixing invalid geometry at index 493448
# Fixing invalid geometry at index 494132
# Fixing invalid geometry at index 495224
# Fixing invalid geometry at index 503779
# Fixing invalid geometry at index 504603
# Fixing invalid geometry at index 505647
# Fixing invalid geometry at index 505707
# Fixing invalid geometry at index 506377
# Fixing invalid geometry at index 519408
# Fixing invalid geometry at index 522385
# Fixing invalid geometry at index 527532
# Fixing invalid geometry at index 529717
# Fixing invalid geometry at index 535292
# Fixing invalid geometry at index 535594
# Fixing invalid geometry at index 535614
# Fixing invalid geometry at index 535623
# CRS of data is EPSG:4326
# IL_wetlands.parquet data cleaned and saved successfully!
# File IL_wetlands.parquet processed and saved.
# Loaded protected_lands data from layer: PADUS4_1Comb_DOD_Trib_NGP_Fee_Desig_Ease_State_IL with 14768 features
# Fixing invalid geometry at index 33
# Fixing invalid geometry at index 34
# Fixing invalid geometry at index 35
# Fixing invalid geometry at index 45
# Fixing invalid geometry at index 48
# Fixing invalid geometry at index 49
# Fixing invalid geometry at index 59
# Fixing invalid geometry at index 215
# Fixing invalid geometry at index 2250
# Fixing invalid geometry at index 2665
# Fixing invalid geometry at index 2743
# Fixing invalid geometry at index 2744
# Fixing invalid geometry at index 2761
# Fixing invalid geometry at index 2895
# Fixing invalid geometry at index 3343
# Fixing invalid geometry at index 10585
# Fixing invalid geometry at index 10643
# Fixing invalid geometry at index 10647
# Fixing invalid geometry at index 10753
# Fixing invalid geometry at index 10997
# CRS of data is EPSG:4326
# IL_protected_lands.parquet data cleaned and saved successfully!
# File IL_protected_lands.parquet processed and saved.
# Loaded wetlands data from layer: WA_Wetlands with 611428 features
# Postprocessed wetlands data
# Fixing invalid geometry at index 5976
# Fixing invalid geometry at index 6490
# Fixing invalid geometry at index 11231
# Fixing invalid geometry at index 12889
# Fixing invalid geometry at index 13375
# Fixing invalid geometry at index 16486
# Fixing invalid geometry at index 20751
# Fixing invalid geometry at index 20792
# Fixing invalid geometry at index 20842
# Fixing invalid geometry at index 21966
# Fixing invalid geometry at index 22290
# Fixing invalid geometry at index 26902
# Fixing invalid geometry at index 26903
# Fixing invalid geometry at index 26911
# Fixing invalid geometry at index 26939
# Fixing invalid geometry at index 26942
# Fixing invalid geometry at index 27006
# Fixing invalid geometry at index 27393
# Fixing invalid geometry at index 27724
# Fixing invalid geometry at index 32496
# Fixing invalid geometry at index 44551
# Fixing invalid geometry at index 45517
# Fixing invalid geometry at index 45526
# Fixing invalid geometry at index 45921
# Fixing invalid geometry at index 46359
# Fixing invalid geometry at index 46906
# Fixing invalid geometry at index 50009
# Fixing invalid geometry at index 50017
# Fixing invalid geometry at index 51389
# Fixing invalid geometry at index 51438
# Fixing invalid geometry at index 51445
# Fixing invalid geometry at index 51749
# Fixing invalid geometry at index 51963
# Fixing invalid geometry at index 52103
# Fixing invalid geometry at index 52467
# Fixing invalid geometry at index 52558
# Fixing invalid geometry at index 52653
# Fixing invalid geometry at index 56663
# Fixing invalid geometry at index 56685
# Fixing invalid geometry at index 57655
# Fixing invalid geometry at index 60276
# Fixing invalid geometry at index 60956
# Fixing invalid geometry at index 67326
# Fixing invalid geometry at index 67408
# Fixing invalid geometry at index 67476
# Fixing invalid geometry at index 67484
# Fixing invalid geometry at index 68928
# Fixing invalid geometry at index 72048
# Fixing invalid geometry at index 73297
# Fixing invalid geometry at index 73390
# Fixing invalid geometry at index 77458
# Fixing invalid geometry at index 77933
# Fixing invalid geometry at index 81797
# Fixing invalid geometry at index 81811
# Fixing invalid geometry at index 87670
# Fixing invalid geometry at index 87691
# Fixing invalid geometry at index 90827
# Fixing invalid geometry at index 90852
# Fixing invalid geometry at index 91290
# Fixing invalid geometry at index 96048
# Fixing invalid geometry at index 97140
# Fixing invalid geometry at index 98578
# Fixing invalid geometry at index 101691
# Fixing invalid geometry at index 101735
# Fixing invalid geometry at index 101746
# Fixing invalid geometry at index 101804
# Fixing invalid geometry at index 106064
# Fixing invalid geometry at index 117486
# Fixing invalid geometry at index 122784
# Fixing invalid geometry at index 123048
# Fixing invalid geometry at index 123407
# Fixing invalid geometry at index 123579
# Fixing invalid geometry at index 126572
# Fixing invalid geometry at index 127652
# Fixing invalid geometry at index 134450
# Fixing invalid geometry at index 134617
# Fixing invalid geometry at index 134717
# Fixing invalid geometry at index 135070
# Fixing invalid geometry at index 142312
# Fixing invalid geometry at index 142343
# Fixing invalid geometry at index 143599
# Fixing invalid geometry at index 144526
# Fixing invalid geometry at index 146506
# Fixing invalid geometry at index 149469
# Fixing invalid geometry at index 149476
# Fixing invalid geometry at index 149483
# Fixing invalid geometry at index 149484
# Fixing invalid geometry at index 149530
# Fixing invalid geometry at index 149539
# Fixing invalid geometry at index 149542
# Fixing invalid geometry at index 156077
# Fixing invalid geometry at index 166581
# Fixing invalid geometry at index 172080
# ...
# Fixing invalid geometry at index 422666
# Fixing invalid geometry at index 425308
# Fixing invalid geometry at index 430793
# Fixing invalid geometry at index 434889
# Fixing invalid geometry at index 449302
# Fixing invalid geometry at index 452296
# Fixing invalid geometry at index 457542
# Fixing invalid geometry at index 458612
# Fixing invalid geometry at index 464613
# Fixing invalid geometry at index 464630
# Fixing invalid geometry at index 465109
# Fixing invalid geometry at index 477273
# Fixing invalid geometry at index 477719
# Fixing invalid geometry at index 478265
# Fixing invalid geometry at index 485387
# Fixing invalid geometry at index 485656
# Fixing invalid geometry at index 492336
# Fixing invalid geometry at index 495649
# Fixing invalid geometry at index 496518
# Fixing invalid geometry at index 504000
# Fixing invalid geometry at index 504099
# Fixing invalid geometry at index 504162
# Fixing invalid geometry at index 509671
# Fixing invalid geometry at index 510652
# Fixing invalid geometry at index 510653
# Fixing invalid geometry at index 518054
# Fixing invalid geometry at index 534515
# Fixing invalid geometry at index 543372
# Fixing invalid geometry at index 543492
# Fixing invalid geometry at index 544365
# Fixing invalid geometry at index 546372
# Fixing invalid geometry at index 547596
# Fixing invalid geometry at index 549858
# Fixing invalid geometry at index 569661
# Fixing invalid geometry at index 575051
# Fixing invalid geometry at index 586761
# Fixing invalid geometry at index 588658
# Fixing invalid geometry at index 603177
# Fixing invalid geometry at index 603424
# Fixing invalid geometry at index 615762
# Fixing invalid geometry at index 624567
# Fixing invalid geometry at index 625165
# Fixing invalid geometry at index 625543
# Fixing invalid geometry at index 633933
# Fixing invalid geometry at index 644458
# Fixing invalid geometry at index 644640
# Fixing invalid geometry at index 654062
# Fixing invalid geometry at index 673418
# Fixing invalid geometry at index 673693
# Fixing invalid geometry at index 673909
# Fixing invalid geometry at index 682410
# Fixing invalid geometry at index 682418
# Fixing invalid geometry at index 682448
# Fixing invalid geometry at index 682722
# Fixing invalid geometry at index 690690
# Fixing invalid geometry at index 690952
# Fixing invalid geometry at index 691370
# Fixing invalid geometry at index 691376
# Fixing invalid geometry at index 692728
# Fixing invalid geometry at index 699634
# Fixing invalid geometry at index 700295
# Fixing invalid geometry at index 702051
# Fixing invalid geometry at index 710517
# Fixing invalid geometry at index 715525
# Fixing invalid geometry at index 715539
# Fixing invalid geometry at index 715556
# Fixing invalid geometry at index 715570
# Fixing invalid geometry at index 715573
# Fixing invalid geometry at index 715595
# Fixing invalid geometry at index 724956
# Fixing invalid geometry at index 726384
# Fixing invalid geometry at index 738747
# Fixing invalid geometry at index 756114
# Fixing invalid geometry at index 756277
# Fixing invalid geometry at index 756289
# Fixing invalid geometry at index 757492
# Fixing invalid geometry at index 757899
# Fixing invalid geometry at index 761062
# Fixing invalid geometry at index 761402
# Fixing invalid geometry at index 761500
# Fixing invalid geometry at index 761586
# Fixing invalid geometry at index 761627
# Fixing invalid geometry at index 761631
# Fixing invalid geometry at index 761655
# Fixing invalid geometry at index 761660
# Fixing invalid geometry at index 761676
# Fixing invalid geometry at index 762427
# Fixing invalid geometry at index 763043
# Fixing invalid geometry at index 763801
# Fixing invalid geometry at index 764341
# Fixing invalid geometry at index 764401
# Fixing invalid geometry at index 764597
# Fixing invalid geometry at index 765014
# Fixing invalid geometry at index 765878
# Fixing invalid geometry at index 770442
# Fixing invalid geometry at index 770521
# Fixing invalid geometry at index 770524
# Fixing invalid geometry at index 770612
# Fixing invalid geometry at index 770637
# Fixing invalid geometry at index 771119
# Fixing invalid geometry at index 771252
# Fixing invalid geometry at index 771656
# Fixing invalid geometry at index 771898
# Fixing invalid geometry at index 771912
# Fixing invalid geometry at index 771926
# Fixing invalid geometry at index 771986
# Fixing invalid geometry at index 772008
# Fixing invalid geometry at index 772139
# Fixing invalid geometry at index 772343
# Fixing invalid geometry at index 777416
# Fixing invalid geometry at index 784421
# Fixing invalid geometry at index 784466
# Fixing invalid geometry at index 784472
# Fixing invalid geometry at index 784747
# Fixing invalid geometry at index 805029
# Fixing invalid geometry at index 817529
# Fixing invalid geometry at index 819638
# Fixing invalid geometry at index 820377
# Fixing invalid geometry at index 821535
# Fixing invalid geometry at index 829699
# Fixing invalid geometry at index 831316
# Fixing invalid geometry at index 834444
# Fixing invalid geometry at index 844141
# Fixing invalid geometry at index 844856
# Fixing invalid geometry at index 844859
# Fixing invalid geometry at index 844887
# Fixing invalid geometry at index 845840
# Fixing invalid geometry at index 849228
# Fixing invalid geometry at index 857004
# Fixing invalid geometry at index 857039
# Fixing invalid geometry at index 857062
# Fixing invalid geometry at index 860194
# Fixing invalid geometry at index 860474
# Fixing invalid geometry at index 881769
# Fixing invalid geometry at index 881781
# Fixing invalid geometry at index 882073
# Fixing invalid geometry at index 892688
# Fixing invalid geometry at index 904137
# Fixing invalid geometry at index 956833
# Fixing invalid geometry at index 1023770
# Fixing invalid geometry at index 1077414
# Fixing invalid geometry at index 1099143
# Fixing invalid geometry at index 1108570
# Fixing invalid geometry at index 1161492
# Fixing invalid geometry at index 1161494
# Fixing invalid geometry at index 1161556
# Fixing invalid geometry at index 1231823
# Fixing invalid geometry at index 1263943
# Fixing invalid geometry at index 1270500
# Fixing invalid geometry at index 1280622
# Fixing invalid geometry at index 1284075
# Fixing invalid geometry at index 1314892
# Fixing invalid geometry at index 1316304
# Fixing invalid geometry at index 1322803
# Fixing invalid geometry at index 1322869
# Fixing invalid geometry at index 1323579
# Fixing invalid geometry at index 1324565
# Fixing invalid geometry at index 1324641
# Fixing invalid geometry at index 1325185
# Fixing invalid geometry at index 1325188
# Fixing invalid geometry at index 1325210
# Fixing invalid geometry at index 1325218
# Fixing invalid geometry at index 1325233
# Fixing invalid geometry at index 1325263
# Fixing invalid geometry at index 1325326
# Fixing invalid geometry at index 1325335
# Fixing invalid geometry at index 1325337
# Fixing invalid geometry at index 1325400
# Fixing invalid geometry at index 1325802
# Fixing invalid geometry at index 1325913
# Fixing invalid geometry at index 1325943
# Fixing invalid geometry at index 1325953
# Fixing invalid geometry at index 1326232
# Fixing invalid geometry at index 1326251
# Fixing invalid geometry at index 1327090
# Fixing invalid geometry at index 1327108
# Fixing invalid geometry at index 1327129
# Fixing invalid geometry at index 1327142
# Fixing invalid geometry at index 1328015
# Fixing invalid geometry at index 1328156
# Fixing invalid geometry at index 1329890
# Fixing invalid geometry at index 1329898
# Fixing invalid geometry at index 1329910
# Fixing invalid geometry at index 1329919
# Fixing invalid geometry at index 1329923
# Fixing invalid geometry at index 1330006
# Fixing invalid geometry at index 1330027
# Fixing invalid geometry at index 1330036
# Fixing invalid geometry at index 1331555
# Fixing invalid geometry at index 1332013
# Fixing invalid geometry at index 1332101
# Fixing invalid geometry at index 1332767
# Fixing invalid geometry at index 1332809
# Fixing invalid geometry at index 1333835
# Fixing invalid geometry at index 1334118
# Fixing invalid geometry at index 1334208
# Fixing invalid geometry at index 1334428
# Fixing invalid geometry at index 1334687
# Fixing invalid geometry at index 1334710
# Fixing invalid geometry at index 1334743
# Fixing invalid geometry at index 1334775
# Fixing invalid geometry at index 1334785
# Fixing invalid geometry at index 1336476
# Fixing invalid geometry at index 1337110
# Fixing invalid geometry at index 1337302
# Fixing invalid geometry at index 1337697
# Fixing invalid geometry at index 1338314
# Fixing invalid geometry at index 1338888
# Fixing invalid geometry at index 1339024
# Fixing invalid geometry at index 1339607
# Fixing invalid geometry at index 1339617
# Fixing invalid geometry at index 1339705
# Fixing invalid geometry at index 1339909
# Fixing invalid geometry at index 1340356
# Fixing invalid geometry at index 1340749
# Fixing invalid geometry at index 1341625
# Fixing invalid geometry at index 1342182
# Fixing invalid geometry at index 1342220
# Fixing invalid geometry at index 1342237
# Fixing invalid geometry at index 1342292
# Fixing invalid geometry at index 1342422
# Fixing invalid geometry at index 1343429
# Fixing invalid geometry at index 1343435
# Fixing invalid geometry at index 1343437
# Fixing invalid geometry at index 1343438
# Fixing invalid geometry at index 1343583
# Fixing invalid geometry at index 1343614
# Fixing invalid geometry at index 1343674
# Fixing invalid geometry at index 1343706
# Fixing invalid geometry at index 1343708
# Fixing invalid geometry at index 1343715
# Fixing invalid geometry at index 1343733
# Fixing invalid geometry at index 1343760
# Fixing invalid geometry at index 1343798
# Fixing invalid geometry at index 1343808
# Fixing invalid geometry at index 1343842
# Fixing invalid geometry at index 1343845
# Fixing invalid geometry at index 1343866
# Fixing invalid geometry at index 1343872
# Fixing invalid geometry at index 1343891
# Fixing invalid geometry at index 1344730
# Fixing invalid geometry at index 1345198
# Fixing invalid geometry at index 1345296
# Fixing invalid geometry at index 1345308
# Fixing invalid geometry at index 1345327
# Fixing invalid geometry at index 1345339
# Fixing invalid geometry at index 1345375
# Fixing invalid geometry at index 1345393
# Fixing invalid geometry at index 1345408
# Fixing invalid geometry at index 1345847
# Fixing invalid geometry at index 1345894
# Fixing invalid geometry at index 1347014
# Fixing invalid geometry at index 1347309
# Fixing invalid geometry at index 1347378
# Fixing invalid geometry at index 1347699
# Fixing invalid geometry at index 1350150
# Fixing invalid geometry at index 1350250
# Fixing invalid geometry at index 1351554
# Fixing invalid geometry at index 1351561
# Fixing invalid geometry at index 1370909
# Fixing invalid geometry at index 1422610
# Fixing invalid geometry at index 1438074
# Fixing invalid geometry at index 1438168
# Fixing invalid geometry at index 1438668
# Fixing invalid geometry at index 1440060
# Fixing invalid geometry at index 1456881
# Fixing invalid geometry at index 1464637
# Fixing invalid geometry at index 1480688
# Fixing invalid geometry at index 1497578
# Fixing invalid geometry at index 1503677
# Fixing invalid geometry at index 1507182
# Fixing invalid geometry at index 1508164
# Fixing invalid geometry at index 1510730
# Fixing invalid geometry at index 1510991
# Fixing invalid geometry at index 1515601
# Fixing invalid geometry at index 1517904
# Fixing invalid geometry at index 1525940
# Fixing invalid geometry at index 1541135
# Fixing invalid geometry at index 1542165
# Fixing invalid geometry at index 1543394
# Fixing invalid geometry at index 1543399
# Fixing invalid geometry at index 1567982
# Fixing invalid geometry at index 1598174
# Fixing invalid geometry at index 1602304
# Fixing invalid geometry at index 1604701
# Fixing invalid geometry at index 1614397
# Fixing invalid geometry at index 1619148
# Fixing invalid geometry at index 1634169
# Fixing invalid geometry at index 1649016
# Fixing invalid geometry at index 1653441
# Fixing invalid geometry at index 1659885
# Fixing invalid geometry at index 1678190
# Fixing invalid geometry at index 1719496
# Fixing invalid geometry at index 1770603
# Fixing invalid geometry at index 1776887
# Fixing invalid geometry at index 1777043
# Fixing invalid geometry at index 1800522
# Fixing invalid geometry at index 1803820
# Fixing invalid geometry at index 1804033
# Fixing invalid geometry at index 1912563
# Fixing invalid geometry at index 1922995
# Fixing invalid geometry at index 1922999
# Fixing invalid geometry at index 1923079
# Fixing invalid geometry at index 1926579
# Fixing invalid geometry at index 1932522
# Fixing invalid geometry at index 1932629
# Fixing invalid geometry at index 1932633
# Fixing invalid geometry at index 1933160
# Fixing invalid geometry at index 1934961
# Fixing invalid geometry at index 1935003
# Fixing invalid geometry at index 1935749
# Fixing invalid geometry at index 1940121
# Fixing invalid geometry at index 1940970
# Fixing invalid geometry at index 1955115
# Fixing invalid geometry at index 1955117
# Fixing invalid geometry at index 1977750
# Fixing invalid geometry at index 1996805
# Fixing invalid geometry at index 1998154
# Fixing invalid geometry at index 2004483
# Fixing invalid geometry at index 2005126
# Fixing invalid geometry at index 2016433
# Fixing invalid geometry at index 2016447
# Fixing invalid geometry at index 2016466
# Fixing invalid geometry at index 2029695
# Fixing invalid geometry at index 2045699
# Fixing invalid geometry at index 2056636
# Fixing invalid geometry at index 2056855
# Fixing invalid geometry at index 2056903
# Fixing invalid geometry at index 2056924
# Fixing invalid geometry at index 2057012
# Fixing invalid geometry at index 2057059
# Fixing invalid geometry at index 2085771
# Fixing invalid geometry at index 2126650
# Fixing invalid geometry at index 2126687
# Fixing invalid geometry at index 2137630
# Fixing invalid geometry at index 2137698
# Fixing invalid geometry at index 2145000
# Fixing invalid geometry at index 2146161
# Fixing invalid geometry at index 2149652
# Fixing invalid geometry at index 2186709
# Fixing invalid geometry at index 2190885
# Fixing invalid geometry at index 2201700
# Fixing invalid geometry at index 2206954
# Fixing invalid geometry at index 2224737
# Fixing invalid geometry at index 2226069
# Fixing invalid geometry at index 2226180
# Fixing invalid geometry at index 2227530
# Fixing invalid geometry at index 2227532
# Fixing invalid geometry at index 2227939
# Fixing invalid geometry at index 2229345
# Fixing invalid geometry at index 2229391
# Fixing invalid geometry at index 2231224
# Fixing invalid geometry at index 2231272
# Fixing invalid geometry at index 2233157
# Fixing invalid geometry at index 2233158
# CRS of data is EPSG:4326
# TX_wetlands.parquet data cleaned and saved successfully!
# File TX_wetlands.parquet processed and saved.
# Loaded protected_lands data from layer: PADUS4_1Comb_DOD_Trib_NGP_Fee_Desig_Ease_State_TX with 24831 features
# Fixing invalid geometry at index 102
# Fixing invalid geometry at index 107
# Fixing invalid geometry at index 113
# Fixing invalid geometry at index 114
# Fixing invalid geometry at index 117
# Fixing invalid geometry at index 120
# Fixing invalid geometry at index 126
# Fixing invalid geometry at index 129
# Fixing invalid geometry at index 134
# Fixing invalid geometry at index 141
# Fixing invalid geometry at index 142
# Fixing invalid geometry at index 143
# Fixing invalid geometry at index 146
# Fixing invalid geometry at index 148
# Fixing invalid geometry at index 153
# Fixing invalid geometry at index 4227
# Fixing invalid geometry at index 4334
# Fixing invalid geometry at index 4564
# Fixing invalid geometry at index 4781
# Fixing invalid geometry at index 4885
# Fixing invalid geometry at index 5972
# Fixing invalid geometry at index 10085
# Fixing invalid geometry at index 10134
# Fixing invalid geometry at index 10138
# Fixing invalid geometry at index 10194
# Fixing invalid geometry at index 11456
# Fixing invalid geometry at index 11457
# Fixing invalid geometry at index 11470
# Fixing invalid geometry at index 11794
# Fixing invalid geometry at index 11812
# Fixing invalid geometry at index 11867
# CRS of data is EPSG:4326
# TX_protected_lands.parquet data cleaned and saved successfully!
# File TX_protected_lands.parquet processed and saved.

# %% [markdown]
# #### 1.2 Uploading source encumbrance data to BQ

# %%
# Function to upload locally saved parquet to GCS
def upload_parquet_to_gcs(
        bucket_name,
        bucket_folder,
        dataset,
        local_ingestion_path = PARQUET_INGESTION_PATH,
        state=None):
    """
    Uploads a local Parquet file to a GCS bucket using config structure.

    Args:
        bucket_name (str): Target GCS bucket.
        dataset (str): One of the encumbrances in EncumbranceType
        local_file_path (str): Local parquet file path.
        state (str, optional): State name for datasets that include it.
    """
    gcs_folder = f'{bucket_folder}/{dataset}'
    filename = f"{state}_{dataset}.parquet" if state else f"{dataset}.parquet"
    local_file_path = os.path.join(local_ingestion_path, filename)
    if not os.path.exists(local_file_path):
        raise FileNotFoundError(f"File {local_file_path} does not exist.")
    destination_blob_path = f"{gcs_folder}/{filename}"

    # GCS client upload
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(destination_blob_path)
    blob.upload_from_filename(local_file_path)

    print(f"Uploaded {filename} to gs://{bucket_name}/{destination_blob_path}")

# %%
# Loop over states and encumbrances to upload to GCS
# List of states and datasets
states = [
    #'PA',
    'GA',
    'MO',
    'WI',
    'NM',
    'IL',
    'WA', 
    'TX'
    ]
datasets = ['wetlands','protected_lands'] # To re-run, replace this with ENCUMBRANCES

for dataset in datasets:
    if dataset in ['wetlands', 'protected_lands']:
        for state in states:
            try:
                upload_parquet_to_gcs(
                    bucket_name=BUCKET,
                    bucket_folder=BUCKET_FOLDER, 
                    dataset=dataset, 
                    local_ingestion_path=PARQUET_INGESTION_PATH, 
                    state=state
                )
            except Exception as e:
                print(f"Failed to upload {dataset} for {state}: {e}")
    else:
        try:
            upload_parquet_to_gcs(
                bucket_name=BUCKET,
                bucket_folder=BUCKET_FOLDER,
                dataset=dataset, 
                local_ingestion_path=PARQUET_INGESTION_PATH
                # No state needed
            )
        except Exception as e:
            print(f"Failed to upload {dataset}: {e}")

# %% [markdown]
# #### 2. Convert county boundaries to geographic projection and upload to BQ

# %%
# Upload local parquet file to GCS bucket
# First, define constants
GIS_PROJECT = 'clgx-gis-app-dev-06e3'
POC_DATASET = 'encumbered_parcels'
CREDENTIALS_PATH =  r"C:\Users\eprashar\AppData\Roaming\gcloud\application_default_credentials.json"
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = str(CREDENTIALS_PATH)

# Verify credentials
utils.check_and_authenticate(CREDENTIALS_PATH)
# Out:
# Credentials file is valid.

# %%
# Upload county data in GCS bucket after converting CRS to EPSG:4326
def convert_upload_parquet_to_gcs_and_bigquery(
    source_folder,
    output_name,
    bucket_name,
    gcs_blob,
    project_id,
    dataset_id,
    table_name
):
    """
    Converts a Parquet file with EPSG:4269 geometries to EPSG:4326,
    uploads it to GCS, then loads it into BigQuery.

    Args:
    """
    # Load and convert CRS
    input_path = os.path.join(LOCAL_DATA_FOLDER, source_folder)
    gdf = gpd.read_file(input_path)
    print(f"Loaded {len(gdf)} features from {input_path}")

    if gdf.crs is None or gdf.crs.to_epsg() != geo_crs:
        gdf = gdf.to_crs(geo_crs)
        print("CRS converted to EPSG:4326")
    else:
        print("CRS already in EPSG:4326")

    # Save converted file locally
    output_path = os.path.join(PARQUET_INGESTION_PATH, f'{output_name}')
    gdf.to_parquet(output_path)
    print(f"Saved converted file to {output_path}")

    # Upload to GCS
    gcs_blob_path = f'{gcs_blob}/{output_name}'
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(gcs_blob_path)
    blob.upload_from_filename(output_path)
    print(f"Uploaded to GCS: gs://{bucket_name}/{gcs_blob_path}")

    # Load into BigQuery
    client = bigquery.Client()
    table_id = f"{project_id}.{dataset_id}.{table_name}"

    job_config = bigquery.LoadJobConfig(
        source_format=bigquery.SourceFormat.PARQUET,
        autodetect=True,
        write_disposition=bigquery.WriteDisposition.WRITE_TRUNCATE
    )

    uri = f"gs://{bucket_name}/{gcs_blob_path}"
    load_job = client.load_table_from_uri(uri, table_id, job_config=job_config)
    load_job.result()  # Wait for job to complete

    print(f"Loaded data into BigQuery table: {table_id}")

# %%
# Executing the county data upload
convert_upload_parquet_to_gcs_and_bigquery(
    source_folder=COUNTY_DATA,
    output_name='county_bounds.parquet',
    bucket_name=BUCKET,
    gcs_blob= f'{BUCKET_FOLDER}/county_bounds',
    project_id=GIS_PROJECT,
    dataset_id=POC_DATASET,
    table_name="county_boundaries"
)
# Out:
# Loaded 3235 features from C:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\jan_25_proj_infra_parcels\data\counties\tl_2024_us_county\tl_2024_us_county.shp
# CRS converted to EPSG:4326
# Saved converted file to C:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\jan_25_proj_infra_parcels\data\ingestion_parquets\county_bounds.parquet
# Uploaded to GCS: gs://geospatial-projects/infra_parcels/county_bounds/county_bounds.parquet
# Loaded data into BigQuery table: clgx-gis-app-dev-06e3.encumbered_parcels.county_boundaries

# %% [markdown]
# #### 3.1 [Relevant for local development in python]: Get county-level encumbrance parquet files

# %%
# Function to load county boundary
def get_county_boundary(fips_code):
    """
    Load county boundary from shapefile and filter by FIPS code.
    """
    # Read the shapefile
    gdf_county = gpd.read_file(os.path.join(LOCAL_DATA_FOLDER, COUNTY_DATA))
    
    # Filter by FIPS code
    gdf_county = gdf_county[gdf_county['GEOID'] == fips_code]
    
    # Convert to EPSG:4326
    gdf_county = gdf_county.to_crs(geo_crs)
    
    return gdf_county

# %%
# Filter encumbrance data for county
def filter_gdf_using_boundary(gdf_encumbrance, county_boundary):
    """
    Load wetland attributes from a geodatabase and join them to the wetlands GeoDataFrame
    using the 'ATTRIBUTE' field as a key.

    Parameters:

    Returns:
        GeoDataFrame: 
    """

    # Convert both dataframes to the same projection system
    gdf_encumbrance = gdf_encumbrance.to_crs(county_boundary.crs)

    # Perform a spatial join
    filtered_encumbrance = gpd.sjoin(gdf_encumbrance, county_boundary, predicate='within')

    # Drop unnecessary columns from county database
    filtered_encumbrance.drop(columns=[
        'index_right',
        'STATEFP',
        'COUNTYFP',
        'COUNTYNS',
        'GEOID',
        'GEOIDFQ',
        'LSAD',
        'CLASSFP',
        'MTFCC',
        'CSAFP',
        'CBSAFP',
        'METDIVFP',
        'FUNCSTAT',
        'ALAND',
        'AWATER',
        'INTPTLAT',
        'INTPTLON'], inplace=True)

    # Convert epsg for filtered gdf to 4326
    filtered_encumbrance = filtered_encumbrance.set_geometry('geometry').to_crs(geo_crs)
    print(f'CRS of the filtered dataframe is {filtered_encumbrance.crs}')
    return filtered_encumbrance

# %%
# Load data for encumbrance type
def load_encumbrance_for_county(
        encumbrance_type: EncumbranceType,
        fips,
        state=None) -> gpd.GeoDataFrame:
    '''
    Load encumbrance data from <source> and return as GeoDataFrame.
    '''
    # Flag error if chosen encumbrance is not defined
    if encumbrance_type not in ENCUMBRANCES:
        raise ValueError(
            f"Invalid encumbrance type '{encumbrance_type}'. "
            f"Valid options are: {', '.join(ENCUMBRANCES)}."
        )
    # Obtain county boundary
    county_boundary = get_county_boundary(fips)

    # Read the parquet file for the encumbrance type
    try:
        file_path = os.path.join(PARQUET_INGESTION_PATH, f'{state}_{encumbrance_type}.parquet' if state else f'{encumbrance_type}.parquet')
        gdf = gpd.read_parquet(file_path)
    except Exception as e:
        raise FileNotFoundError(f"File {file_path} not found. Error: {e}")

    # Use spatial join to get encumbrance data for county
    county_gdf = filter_gdf_using_boundary(gdf, county_boundary)

    # save county_gdf as parquet file
    print(f"{encumbrance_type} data loaded for FIPS code: {fips}")
    
    # Convert to EPSG:4326
    county_gdf = county_gdf.to_crs(geo_crs)
    county_gdf.to_parquet(os.path.join(PARQUET_INGESTION_PATH,f'{fips}_{encumbrance_type}.parquet'))
    print(f'{encumbrance_type} parquet created for {fips}!')

# %%
# Mapping of county FIPS to state abbreviations
FIPS_TO_STATE = {
    '17031': 'IL',  # Cook County, IL
    '13121': 'GA',  # Fulton County, GA
    '53033': 'WA',  # King County, WA
    '48491': 'TX',  # Williamson County, TX
    '29181': 'MO',  # Warren County, MO
    '42011': 'PA',  # Berks County, PA
    '55107': 'WI',  # Rusk County, WI
    '35051': 'NM',  # Sierra County, NM
    '17127': 'IL',  # Massac County, IL
}

poc_fips = POC_FINALIZED_COUNTIES
encumbrances = ENCUMBRANCES

# Encumbrances that require state information
STATE_REQUIRED_TYPES = {'wetlands', 'protected_lands'}

for fips in poc_fips:
    for encumbrance in encumbrances:
        filename = f"{fips}_{encumbrance}.parquet"
        destination_file = os.path.join(PARQUET_INGESTION_PATH, filename)

        if not os.path.exists(destination_file):
            try:
                state = FIPS_TO_STATE.get(fips) if encumbrance in STATE_REQUIRED_TYPES else None

                load_encumbrance_for_county(
                    encumbrance_type=encumbrance,
                    fips=fips,
                    state=state
                )
                print(f"File {filename} processed and saved.")
            except Exception as e:
                print(f"Failed to process {filename}: {e}")
        else:
            print(f"File {filename} already exists. Skipping.")
# Out:
# File 17031_roadways.parquet already exists. Skipping.
# File 17031_railways.parquet already exists. Skipping.
# File 17031_protected_lands.parquet already exists. Skipping.
# File 17031_wetlands.parquet already exists. Skipping.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# transmission_lines data loaded for FIPS code: 17031
# transmission_lines parquet created for 17031!
# File 17031_transmission_lines.parquet processed and saved.
# File 13121_roadways.parquet already exists. Skipping.
# File 13121_railways.parquet already exists. Skipping.
# File 13121_protected_lands.parquet already exists. Skipping.
# File 13121_wetlands.parquet already exists. Skipping.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# transmission_lines data loaded for FIPS code: 13121
# transmission_lines parquet created for 13121!
# File 13121_transmission_lines.parquet processed and saved.
# File 53033_roadways.parquet already exists. Skipping.
# File 53033_railways.parquet already exists. Skipping.
# File 53033_protected_lands.parquet already exists. Skipping.
# File 53033_wetlands.parquet already exists. Skipping.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# transmission_lines data loaded for FIPS code: 53033
# transmission_lines parquet created for 53033!
# File 53033_transmission_lines.parquet processed and saved.
# File 48491_roadways.parquet already exists. Skipping.
# File 48491_railways.parquet already exists. Skipping.
# File 48491_protected_lands.parquet already exists. Skipping.
# File 48491_wetlands.parquet already exists. Skipping.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# transmission_lines data loaded for FIPS code: 48491
# transmission_lines parquet created for 48491!
# File 48491_transmission_lines.parquet processed and saved.
# File 29181_roadways.parquet already exists. Skipping.
# File 29181_railways.parquet already exists. Skipping.
# File 29181_protected_lands.parquet already exists. Skipping.
# File 29181_wetlands.parquet already exists. Skipping.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# transmission_lines data loaded for FIPS code: 29181
# transmission_lines parquet created for 29181!
# File 29181_transmission_lines.parquet processed and saved.
# File 42011_roadways.parquet already exists. Skipping.
# File 42011_railways.parquet already exists. Skipping.
# File 42011_protected_lands.parquet already exists. Skipping.
# File 42011_wetlands.parquet already exists. Skipping.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# transmission_lines data loaded for FIPS code: 42011
# transmission_lines parquet created for 42011!
# File 42011_transmission_lines.parquet processed and saved.
# File 55107_roadways.parquet already exists. Skipping.
# File 55107_railways.parquet already exists. Skipping.
# File 55107_protected_lands.parquet already exists. Skipping.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# wetlands data loaded for FIPS code: 55107
# wetlands parquet created for 55107!
# File 55107_wetlands.parquet processed and saved.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# transmission_lines data loaded for FIPS code: 55107
# transmission_lines parquet created for 55107!
# File 55107_transmission_lines.parquet processed and saved.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# roadways data loaded for FIPS code: 35051
# roadways parquet created for 35051!
# File 35051_roadways.parquet processed and saved.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# railways data loaded for FIPS code: 35051
# railways parquet created for 35051!
# File 35051_railways.parquet processed and saved.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# protected_lands data loaded for FIPS code: 35051
# protected_lands parquet created for 35051!
# File 35051_protected_lands.parquet processed and saved.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# wetlands data loaded for FIPS code: 35051
# wetlands parquet created for 35051!
# File 35051_wetlands.parquet processed and saved.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# transmission_lines data loaded for FIPS code: 35051
# transmission_lines parquet created for 35051!
# File 35051_transmission_lines.parquet processed and saved.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# roadways data loaded for FIPS code: 17127
# roadways parquet created for 17127!
# File 17127_roadways.parquet processed and saved.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# railways data loaded for FIPS code: 17127
# railways parquet created for 17127!
# File 17127_railways.parquet processed and saved.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# protected_lands data loaded for FIPS code: 17127
# protected_lands parquet created for 17127!
# File 17127_protected_lands.parquet processed and saved.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# wetlands data loaded for FIPS code: 17127
# wetlands parquet created for 17127!
# File 17127_wetlands.parquet processed and saved.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# transmission_lines data loaded for FIPS code: 17127
# transmission_lines parquet created for 17127!
# File 17127_transmission_lines.parquet processed and saved.

# %% [markdown]
# #### 3.2 [Relevant for local development in python]: Parcel data for POC counties from BigQ in parquet

# %%
# Define constants here
PROJECT = 'clgx-gis-app-dev-06e3'
DATASET = 'property'
POC_DATASET = 'encumbered_parcels'
POC_TABLE = 'base_parcels_poc_counties_0419'
CREDENTIALS_PATH =  r"C:\Users\eprashar\AppData\Roaming\gcloud\application_default_credentials.json"
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = str(CREDENTIALS_PATH)

# Credentials verification
utils.check_and_authenticate(CREDENTIALS_PATH)
# Out:
# Credentials file is valid.

# %%
# Define function to get parcel data for the defined county
def fetch_and_save_county_parcels(fips_code: str) -> gpd.GeoDataFrame:
    """
    Load parcel data from BigQuery and filter by FIPS code.
    """
    # Define the SQL query to filter by FIPS code
    # TO-DO: Create a table in BQ with processed data
    query = f"""
        SELECT * 
        FROM `{PROJECT}.{POC_DATASET}.{POC_TABLE}`
        WHERE fips_code = '{fips_code}'
    """
    # Read the data into a GeoDataFrame
    gdf_parcel = utils.read_bigquery_to_gdf(project=PROJECT, dataset=POC_DATASET, table=POC_TABLE, query=query, output='gpd', geometry_col='geometry')
    
    # Convert to EPSG:4326
    gdf_parcel = gdf_parcel.to_crs(geo_crs)
    print(f'CRS of the parcel dataframe is {gdf_parcel.crs}')
    gdf_parcel.to_parquet(os.path.join(PARQUET_INGESTION_PATH,f'{fips_code}_parcels.parquet'))
    print(f'parcel parquet created for {fips_code}!')

# %%
# Save parcel parquets for all POC counties
for county_fips in POC_FINALIZED_COUNTIES:
    fetch_and_save_county_parcels(fips_code=county_fips)
