# %%
# Importing required libraries
import os
import subprocess
from datetime import datetime, timedelta
import time
import logging
from typing import Literal

import pandas as pd
import numpy as np
import geopandas as gpd
import json
from shapely.geometry import mapping
from shapely.validation import explain_validity, make_valid
import fiona

from google.cloud import bigquery
from google.cloud import storage

# Import utility constants and functions
import utils

# %%
# Initialize global constants here
POC_FINALIZED_COUNTIES = [
    # urban
    '17031',
    '13121',
    '53033',
    # sub-urban
    '48491',
    '29181',
    '42011',
    # rural 
    '55107',
    '35051',
    '17127',
]

# %%
# Define constants
#POC_DATASET = 'encumbered_parcels'
#POC_TABLE = 'parcels'
geo_crs = "EPSG:4326"
projected_crs = "EPSG:3857" 
ENCUMBRANCES = [
    'roadways',
    'railways',
    'protected_lands',
    'wetlands',
    'transmission_lines',
    ]
EncumbranceType = Literal[
    'roadways',
    'railways',
    'protected_lands',
    'wetlands',
    'transmission_lines',
]

LOCAL_DATA_FOLDER = r"C:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\jan_25_proj_infra_parcels\data"
COUNTY_DATA = r"counties\tl_2024_us_county\tl_2024_us_county.shp"
RAILWAYS_DATA = r"NTAD_North_American_Rail_Network_Lines\NARN.gdb" 
TRANSMISSION_LINES_DATA = r"transmission_lines\Transmission_Lines.shp"
ROADWAYS_DATA = r"NTAD_North_American_Roads\North_American_Roads.shp"
PROTECTED_LANDS = r"C:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\jan_25_proj_infra_parcels\data\Protected Lands"
PROTECTED_LANDS_NATIONAL = r"protected_lands_national\PADUS4_1VectorAnalysis_PADUS_Only\PADUS4_1VectorAnalysis_PADUS_Only.gdb"
WETLANDS = r"C:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\jan_25_proj_infra_parcels\data\Wetlands"
WETLAND_ATTRIBUTES = r"Wetlands\NWI-Code-Definitions\NWI-Code-Definitions\NWI_Code_Definitions.gdb"
PARQUET_INGESTION_PATH = r"C:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\jan_25_proj_infra_parcels\data\ingestion_parquets"

# %% [markdown]
# #### 1.1 Cleaning and saving source encumbrance data in parquet format

# %%
# Function to make valid geometries
def validate_and_fix_geometries(
        gdf,
        dataset,
        state=None):
    
    """
    """
    # Initialize summary stats for logging
    fixed_make_valid = 0
    fixed_buffer_count = 0
    dropped_count = 0

    # Ensure CRS is 4326 (WGS84)
    if gdf.crs is None:
        print(f"CRS is undefined; assigning EPSG:4326 directly.")
        gdf.set_crs(geo_crs, inplace=True)
    elif gdf.crs != geo_crs:
        print(f"CRS is {gdf.crs}, transforming to {geo_crs}")
        gdf = gdf.to_crs(geo_crs)

    # Assigning crs to a variable to save in the log file
    original_crs = gdf.crs.to_string()
    
    # Loop over rows
    for idx, row in gdf.iterrows():
        geom = row['geometry']
        if not geom.is_valid:
            print(f"Invalid geometry at index {idx}: {explain_validity(geom)}")
            try:
                # Attempt to fix with make_valid
                fixed = make_valid(geom)
                if fixed.is_valid and not fixed.is_empty:
                    gdf.at[idx, 'geometry'] = fixed
                    fixed_make_valid += 1
                else:
                    print(f"make_valid failed to fix geometry at index {idx}, falling back to buffer(0)")
                    fixed_w_buffer = geom.buffer(0)
                    if fixed_w_buffer.is_valid and not fixed_w_buffer.is_empty:
                        gdf.at[idx, 'geometry'] = fixed_w_buffer
                        fixed_buffer_count += 1
                    else:
                        print(f"Geometry at index {idx} is still invalid or empty after fixing. Dropping.")
                        gdf.at[idx, 'geometry'] = None
            except Exception as e:
                print(f"Exception while fixing geometry at index {idx}: {e}. Dropping.")
                gdf.at[idx, 'geometry'] = None
        else:
            gdf.at[idx, 'geometry'] = geom
    
    # Drop invalid geometries
    initial_len = len(gdf)
    gdf = gdf[gdf['geometry'].notnull()]
    dropped_count = initial_len - len(gdf) # gdf with dropped geometries

    # Convert all remaining geometries to GeoJSON strings
    gdf['geometry_geojson'] = gdf['geometry'].apply(lambda g: json.dumps(mapping(g)) if g is not None else None)
    gdf = gdf.drop(columns='geometry')
    gdf = gdf.rename(columns={'geometry_geojson': 'geometry'})
    print(f"Converted geometries to GeoJSON strings.")
    
    # Log summary
    os.makedirs('logs', exist_ok=True)
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S_%f").replace('.', '_')
    log_filename = os.path.join('logs', f"{state or 'no_state'}_{dataset}_geo_clean_log_{timestamp}.txt")
    print(f'Writing to log file {log_filename}...')

    with open(log_filename, "w") as log_file:
        log_file.write(f"Dataset: {dataset}\n")
        log_file.write(f"State: {state}\n")
        log_file.write(f"Timestamp: {timestamp}\n")
        log_file.write(f"Original CRS: {original_crs}\n")
        log_file.write(f"Initial length of dataframe: {initial_len}\n")
        log_file.write(f"Geometries fixed using make_valid: {fixed_make_valid}\n")
        log_file.write(f"Geometries fixed using buffer(0): {fixed_buffer_count}\n")
        log_file.write(f"Geometries dropped after failed fix: {dropped_count}\n")

    return gdf

# %%
# Function to add wetland attributes
def add_wetland_attributes(gdf_wetland):
    """
    Load wetland attributes from a geodatabase and return as a GeoDataFrame.
    """
    # Read the geodatabase
    gdf_wetland_attributes = gpd.read_file(os.path.join(LOCAL_DATA_FOLDER, WETLAND_ATTRIBUTES))
    
    # Drop unnecessary columns
    columns_to_drop = [
        'SYSTEM', 'SYSTEM_NAME', 'SYSTEM_DEFINITION',
        'SUBSYSTEM', 'SUBSYSTEM_DEFINITION',
        'CLASS', 'CLASS_DEFINITION',
        'SUBCLASS', 'SUBCLASS_DEFINITION',
        'SPLIT_CLASS', 'SPLIT_CLASS_DEFINITION',
        'SPLIT_SUBCLASS', 'SPLIT_SUBCLASS_NAME', 'SPLIT_SUBCLASS_DEFINITION',
        'WATER_REGIME', 'WATER_REGIME_DEFINITION',
        'MODIFIER1', 'MODIFIER1_NAME', 'MODIFIER1_GROUP', 'MODIFIER1_SUBGROUP', 'MODIFIER1_DEFINITION',
        'MODIFIER2', 'MODIFIER2_NAME', 'MODIFIER2_GROUP', 'MODIFIER2_SUBGROUP', 'MODIFIER2_DEFINITION',
        'geometry'
    ]
    gdf_wetland_attributes = gdf_wetland_attributes.drop(
        columns=[col for col in columns_to_drop if col in gdf_wetland_attributes.columns])

    # Join datasets using the 'ATTRIBUTE' column
    wetlands_with_attributes = gdf_wetland.merge(
        gdf_wetland_attributes,
        how='left',
        on='ATTRIBUTE'
    )

    return wetlands_with_attributes

# %%
# Define global config variable to store dataset configurations
# Config includes paths, read arguments, and cleanup functions for each dataset
DATASET_CONFIG = {
    'transmission_lines': {
        'path': TRANSMISSION_LINES_DATA,
        'read_kwargs': {},
        'requires_state': False,
        'cleanup': lambda gdf: gdf
            .drop(columns=[
                'OBJECTID', 'SOURCE', 'SOURCEDATE', 'VAL_METHOD', 'VOLTAGE',
                'INFERRED', 'SUB_1', 'SUB_2'
            ])
            .assign(Shape__Len=gdf['Shape__Len'].round(2))
    },
    'railways': {
        'path': RAILWAYS_DATA,
        'read_kwargs': {'layer': 'North_American_Rail_Network_Lines'},
        'requires_state': False,
        'cleanup': lambda gdf: gdf
            .drop(columns=[
                'FRFRANODE', 'TOFRANODE', 'STFIPS', 'CNTYFIPS', 'STATEAB', 'COUNTRY',
                'FRADISTRCT', 'RROWNER1', 'RROWNER2', 'RROWNER3',
                'TRKRGHTS1', 'TRKRGHTS2', 'TRKRGHTS3', 'TRKRGHTS4', 'TRKRGHTS5',
                'TRKRGHTS6', 'TRKRGHTS7', 'TRKRGHTS8', 'TRKRGHTS9', 'DIVISION',
                'SUBDIV', 'BRANCH', 'YARDNAME', 'PASSNGR', 'STRACNET', 'TRACKS',
                'NET', 'MILES', 'TIMEZONE', 'SHAPE_Length'
            ], errors='ignore')
            .assign(KM=gdf['KM'].round(2))
    },
    'roadways': {
        'path': ROADWAYS_DATA,
        'read_kwargs': {},
        'requires_state': False,
        'cleanup': lambda gdf: gdf[gdf['COUNTRY'] == 2]
            .drop(columns=['DIR', 'LINKID', 'JURISCODE', 'ROADNUM', 'CLASS', 'NHS'], errors='ignore')
    },
    'wetlands': {
        'gdb_config': lambda state: {
            'folder': WETLANDS,
            'subfolder': f"{state}_geodatabase_wetlands",
            'gdb_name': f"{state}_geodatabase_wetlands.gdb"
        },
        'requires_state': True,
        'postprocess': lambda gdf: add_wetland_attributes(gdf)
    },
    'protected_lands': {
        'gdb_config': lambda state: {
            'folder': PROTECTED_LANDS,
            'subfolder': f"PADUS4_1_State_{state}_GDB_KMZ",
            'gdb_name': f"PADUS4_1_State{state}.gdb"
        },
        'requires_state': True,
        'cleanup':  lambda gdf: gdf.drop(columns=[
                'FeatClass',
                'Category',
                'Own_Name',
                'Mang_Type',
                'Mang_Name',
                'Des_Tp',
                'Agg_Src',
                'GIS_Src',
                'Src_Date',
                'GIS_Acres',
                'Source_PAID',
                'Pub_Access',
                'Access_Src',
                'GAP_Sts',
                'IUCN_Cat',
                'Date_Est',
                'Comments',
                'Term',
                'Duration',
        ], errors='ignore'),
    },
    'protected_lands_national': {
        'path': PROTECTED_LANDS_NATIONAL,
        'read_kwargs': {'layer':'PADUS4_1VectorAnalysis_PADUS_Only_Simp_SingP'},
        'requires_state': False,
        'cleanup': lambda gdf: gdf
            .drop(columns=[ 
                'FID_GAP_Sts14_13_12_12_11',
                'Agg_Src',
                'ShL_ShA',
                'DupShL_ShA',
                'RevOID',
                'Shp_AreaDup',
                'GIS_Acres',
                'BndryName',
                'BndryExten',
                'BndryID',
                'GIS_AcrsDb',
                'InPoly_FID',
                'SimPgnFlag',
                'MaxSimpTol',
                'MinSimpTol',
                'Shape_Length',
            ], errors='ignore')
            .assign(area=gdf['Shape_Area'].round(2))

    }
}

# %%
# Function to clean and save dataset
def clean_and_save_dataset(
    dataset='railways',
    output_format='parquet',
    destination_path=PARQUET_INGESTION_PATH,
    state=None
):
    config = DATASET_CONFIG.get(dataset)
    if not config:
        raise ValueError(f"Unsupported dataset: {dataset}")

    if config.get('requires_state') and not state:
        raise ValueError(f"State must be provided for {dataset}")

    # Determine path
    if 'path' in config:
        full_path = os.path.join(LOCAL_DATA_FOLDER, config['path'])
        gdf = gpd.read_file(full_path, **config.get('read_kwargs', {}))
    else:
        # Handle GDB datasets
        gdb_info = config['gdb_config'](state)
        gdb_path = os.path.join(LOCAL_DATA_FOLDER, gdb_info['folder'], gdb_info['subfolder'], gdb_info['gdb_name'])

        # Find largest layer
        largest_layer = max(
            fiona.listlayers(gdb_path),
            key=lambda layer: len(fiona.open(gdb_path, layer=layer))
        )

        gdf = gpd.read_file(gdb_path, layer=largest_layer)
        print(f"Loaded {dataset} data from layer: {largest_layer} with {len(gdf)} features")

    # Optional post-processing
    if 'cleanup' in config:
        gdf = config['cleanup'](gdf)

    if 'postprocess' in config:
        gdf = config['postprocess'](gdf)
        print(f"Postprocessed {dataset} data")

    # Check that geometries are valid
    print(f'State name is {state}')
    gdf = validate_and_fix_geometries(
        gdf,
        dataset,
        state=state)

    # Save output
    if output_format == 'parquet':
        filename = f"{state}_{dataset}.parquet" if state else f"{dataset}.parquet"
        filepath = os.path.join(destination_path, filename)
        gdf.to_parquet(filepath)
        print(f"{filename} data cleaned and saved successfully!")

# %%
# Upload local parquet file to GCS bucket
# First, define constants
BUCKET = 'geospatial-projects'
BUCKET_FOLDER = 'infra_parcels'
CREDENTIALS_PATH =  r"C:\Users\eprashar\AppData\Roaming\gcloud\application_default_credentials.json"
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = str(CREDENTIALS_PATH)

# Verify credentials
utils.check_and_authenticate(CREDENTIALS_PATH)
# Out:
# Credentials file is valid.

# %%
# Loop through all states and datasets to save cleaned parquet files
# List of states and datasets
OVERWRITE_EXISTING = True
states = [
    #'PA',
    #'GA',
    #'MO',
    #'WI',
    #'NM',
    #'IL',
    #'WA',
    'TX'
    ]
datasets = [ 
    #'protected_lands'
    'wetlands',
    #'protected_lands_national'
    ]

# Iterate through states and datasets
for state in states:
    for dataset in datasets:
        # Construct the filename
        filename = f"{state}_{dataset}.parquet" if state else f"{dataset}.parquet"
        destination_file = os.path.join(PARQUET_INGESTION_PATH, filename)

       # Check if the file already exists
        if OVERWRITE_EXISTING or not os.path.exists(destination_file):
            try:
                # Attempt to run the function
                # Print the reason for running the function
                print(f'Running the function because over-write status: {OVERWRITE_EXISTING} and file existence status: {os.path.exists(destination_file)}...') 
                clean_and_save_dataset(
                    dataset=dataset,
                    output_format='parquet',
                    destination_path=PARQUET_INGESTION_PATH,
                    state=state
                )
                print(f"File {filename} processed and saved.")
            except Exception as e:
                # Log the error and continue
                print(f"Failed to process {filename}: {e}")
        else:
            print(f"File {filename} already exists. Skipping.")
# Out:
# Running the function because over-write status: True and file existence status: True...
# Loaded wetlands data from layer: TX_Wetlands with 2233522 features
# Postprocessed wetlands data
# State name is TX
# CRS is PROJCS["NAD_1983_Albers",GEOGCS["NAD83",DATUM["North_American_Datum_1983",SPHEROID["GRS 1980",6378137,298.257222101,AUTHORITY["EPSG","7019"]],AUTHORITY["EPSG","6269"]],PRIMEM["Greenwich",0],UNIT["Degree",0.0174532925199433]],PROJECTION["Albers_Conic_Equal_Area"],PARAMETER["latitude_of_center",23],PARAMETER["longitude_of_center",-96],PARAMETER["standard_parallel_1",29.5],PARAMETER["standard_parallel_2",45.5],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]], transforming to EPSG:4326
# Invalid geometry at index 2609: Ring Self-intersection[-94.3377197927491 33.5673279553757]
# Invalid geometry at index 3298: Ring Self-intersection[-94.2274018054282 33.2438849075009]
# Invalid geometry at index 4212: Ring Self-intersection[-94.1822452164228 33.4477918396963]
# Invalid geometry at index 5393: Ring Self-intersection[-94.358969160461 33.4774896855161]
# Invalid geometry at index 5445: Ring Self-intersection[-94.4842711205157 33.4952131677898]
# Invalid geometry at index 14026: Ring Self-intersection[-94.3635581046781 33.3793557026078]
# Invalid geometry at index 24760: Ring Self-intersection[-94.0128950017362 32.9861366592363]
# Invalid geometry at index 24814: Ring Self-intersection[-94.0040082600283 32.9615924450355]
# Invalid geometry at index 33982: Ring Self-intersection[-94.7037649096556 33.173741764612]
# Invalid geometry at index 43464: Ring Self-intersection[-95.0226555340691 33.3894742167018]
# Invalid geometry at index 43948: Ring Self-intersection[-95.1125200950896 33.4154907599074]
# Invalid geometry at index 44947: Ring Self-intersection[-94.9970321747204 33.13994035012]
# Invalid geometry at index 55027: Ring Self-intersection[-94.8013240673073 32.9776949857386]
# Invalid geometry at index 55767: Ring Self-intersection[-95.3444731460043 33.3186807642623]
# Invalid geometry at index 66671: Ring Self-intersection[-94.981214724908 33.0772473971965]
# Invalid geometry at index 66865: Ring Self-intersection[-94.9298304046595 32.9093362156378]
# Invalid geometry at index 79830: Ring Self-intersection[-95.4807088720893 33.7062011506138]
# Invalid geometry at index 89257: Ring Self-intersection[-95.737279018915 33.8582023670764]
# Invalid geometry at index 96621: Ring Self-intersection[-95.7278758056202 33.4695254105512]
# Invalid geometry at index 107233: Ring Self-intersection[-95.897331202165 33.4544802526047]
# Invalid geometry at index 141800: Ring Self-intersection[-96.552620330523 33.844963374004]
# Invalid geometry at index 154109: Ring Self-intersection[-97.8204496174592 33.8863064626673]
# Invalid geometry at index 163132: Ring Self-intersection[-95.762716552427 32.7554542770637]
# Invalid geometry at index 183756: Ring Self-intersection[-95.5238009700329 32.6481027677369]
# Invalid geometry at index 196892: Ring Self-intersection[-96.2314093900168 32.8132395909906]
# Invalid geometry at index 197496: Ring Self-intersection[-96.2225092308073 32.9290272961995]
# Invalid geometry at index 212187: Ring Self-intersection[-96.5225845160712 32.7135917567409]
# Invalid geometry at index 221605: Ring Self-intersection[-97.0045890640707 32.770491489704]
# Invalid geometry at index 221927: Ring Self-intersection[-96.9476769297875 32.7601030202164]
# Invalid geometry at index 222287: Ring Self-intersection[-97.1988258850092 33.0191996572763]
# Invalid geometry at index 287296: Ring Self-intersection[-97.3057374691166 33.6745249615306]
# Invalid geometry at index 289619: Ring Self-intersection[-97.0150925446072 33.1375899209189]
# Invalid geometry at index 318057: Ring Self-intersection[-97.9498935272931 33.9676986348053]
# Invalid geometry at index 331162: Ring Self-intersection[-97.968312208345 33.829178481469]
# Invalid geometry at index 346058: Ring Self-intersection[-98.3069308503769 33.8925639372544]
# Invalid geometry at index 355287: Ring Self-intersection[-97.9706541671768 33.1277582295473]
# Invalid geometry at index 369610: Ring Self-intersection[-98.371553266138 33.6463174986922]
# Invalid geometry at index 388900: Ring Self-intersection[-98.5939257997696 33.4358931885434]
# Invalid geometry at index 397458: Ring Self-intersection[-94.239367562626 32.852871065185]
# Invalid geometry at index 412329: Ring Self-intersection[-94.6993397199982 32.8530482418368]
# Invalid geometry at index 419470: Ring Self-intersection[-94.2829145076352 32.6659289037049]
# Invalid geometry at index 422666: Ring Self-intersection[-94.0444695329265 32.326080204507]
# Invalid geometry at index 425308: Ring Self-intersection[-94.0550776136426 32.24188175573]
# Invalid geometry at index 430793: Ring Self-intersection[-94.1961464421816 32.1287392415227]
# Invalid geometry at index 434889: Ring Self-intersection[-94.194349113569 32.2206674055194]
# Invalid geometry at index 449302: Ring Self-intersection[-94.2207601695791 31.7666219446851]
# Invalid geometry at index 452296: Ring Self-intersection[-94.2259945718752 31.6444113228844]
# Invalid geometry at index 457542: Ring Self-intersection[-93.7812242456963 31.608543290136]
# Invalid geometry at index 458612: Ring Self-intersection[-94.3601224433224 31.6162064420088]
# Invalid geometry at index 464613: Ring Self-intersection[-93.8780453241262 31.8677827827588]
# Invalid geometry at index 464630: Ring Self-intersection[-93.7862391696873 31.5192577710999]
# Invalid geometry at index 465109: Ring Self-intersection[-93.9377284286381 31.4627452496801]
# Invalid geometry at index 477273: Ring Self-intersection[-93.5056318795881 31.0231015723733]
# Invalid geometry at index 477719: Ring Self-intersection[-93.5669444128973 30.9922157731873]
# Invalid geometry at index 478265: Ring Self-intersection[-93.5515014008264 30.7992056158916]
# Invalid geometry at index 485387: Ring Self-intersection[-94.1147839711515 31.2662285494708]
# Invalid geometry at index 485656: Ring Self-intersection[-94.1556861916773 30.9978841646509]
# Invalid geometry at index 492336: Ring Self-intersection[-94.4546034993016 31.0440737889815]
# Invalid geometry at index 495649: Ring Self-intersection[-94.5263343494064 31.397686026267]
# Invalid geometry at index 496518: Ring Self-intersection[-94.8973673115537 31.5450764256851]
# Invalid geometry at index 504000: Ring Self-intersection[-94.8287425813901 31.487149362365]
# Invalid geometry at index 504099: Ring Self-intersection[-95.00118524484 31.4310295655568]
# Invalid geometry at index 504162: Ring Self-intersection[-94.6960942568715 31.4615698206028]
# Invalid geometry at index 509671: Ring Self-intersection[-94.8387317607449 31.2059401099238]
# Invalid geometry at index 510652: Ring Self-intersection[-94.752023912308 31.1251866199909]
# Invalid geometry at index 510653: Ring Self-intersection[-94.7742863291473 31.1287878096751]
# Invalid geometry at index 518054: Ring Self-intersection[-95.0974532044477 31.2394900828592]
# Invalid geometry at index 534515: Ring Self-intersection[-95.4262397109263 30.8900963137946]
# Invalid geometry at index 543372: Ring Self-intersection[-93.7083085471674 30.5348451825429]
# Invalid geometry at index 543492: Ring Self-intersection[-93.7071595646749 30.3236377959505]
# Invalid geometry at index 544365: Ring Self-intersection[-93.7412298374141 30.3443298870903]
# Invalid geometry at index 546372: Ring Self-intersection[-93.7710509809247 30.2733429264447]
# Invalid geometry at index 547596: Ring Self-intersection[-93.5841091020795 30.7688986271584]
# Invalid geometry at index 549858: Ring Self-intersection[-94.0459625969023 30.6994839875529]
# Invalid geometry at index 569661: Ring Self-intersection[-94.2596160040476 30.5512149449603]
# Invalid geometry at index 575051: Ring Self-intersection[-94.3662808473205 30.3438318612099]
# Invalid geometry at index 586761: Ring Self-intersection[-94.8758613058577 30.4236981998095]
# Invalid geometry at index 588658: Ring Self-intersection[-94.7535717184155 30.2751241898528]
# Invalid geometry at index 603177: Ring Self-intersection[-95.4457137024255 30.2367847557256]
# Invalid geometry at index 603424: Ring Self-intersection[-95.4617418773523 30.2571034087221]
# Invalid geometry at index 615762: Ring Self-intersection[-94.7395798507682 30.0216516168979]
# Invalid geometry at index 624567: Ring Self-intersection[-94.9416342292513 32.8040779347533]
# Invalid geometry at index 625165: Ring Self-intersection[-94.8727770661786 32.6660522233021]
# Invalid geometry at index 625543: Ring Self-intersection[-94.7422438426763 32.6691551031172]
# Invalid geometry at index 633933: Ring Self-intersection[-95.2775997615752 32.7643767479844]
# Invalid geometry at index 644458: Ring Self-intersection[-94.7242114656096 32.4134367747651]
# Invalid geometry at index 644640: Ring Self-intersection[-94.7901264359724 32.4751850708576]
# Invalid geometry at index 654062: Ring Self-intersection[-94.9852668776491 32.1155459042909]
# Invalid geometry at index 673418: Ring Self-intersection[-95.1533393922645 31.9610085127253]
# Invalid geometry at index 673693: Ring Self-intersection[-95.1735935466589 32.1344511583359]
# Invalid geometry at index 673909: Ring Self-intersection[-95.3157829966631 32.4704572125404]
# Invalid geometry at index 682410: Ring Self-intersection[-95.041259798449 31.8797836281464]
# Invalid geometry at index 682418: Ring Self-intersection[-95.0869351984354 31.890512711232]
# Invalid geometry at index 682448: Ring Self-intersection[-95.1484179742816 31.5530080990083]
# Invalid geometry at index 682722: Ring Self-intersection[-95.0069785339622 31.8511220287591]
# Invalid geometry at index 690690: Ring Self-intersection[-95.4378057660516 32.1755272942242]
# Invalid geometry at index 690952: Ring Self-intersection[-95.4153159295592 31.8953056555616]
# Invalid geometry at index 691370: Ring Self-intersection[-95.2808806365054 31.6859204314073]
# Invalid geometry at index 691376: Ring Self-intersection[-95.3196201384376 31.7071765802624]
# Invalid geometry at index 692728: Ring Self-intersection[-95.6531505496786 32.2108866595288]
# Invalid geometry at index 699634: Ring Self-intersection[-95.4252707234161 31.8505177104101]
# Invalid geometry at index 700295: Ring Self-intersection[-95.4142922269453 31.9330090814965]
# Invalid geometry at index 702051: Ring Self-intersection[-95.291436638657 32.1801066603365]
# Invalid geometry at index 710517: Ring Self-intersection[-94.0571837976507 29.8774107317766]
# Invalid geometry at index 715525: Ring Self-intersection[-93.8849818089374 29.8025455367083]
# Invalid geometry at index 715539: Ring Self-intersection[-93.8039080908795 29.8001168769793]
# Invalid geometry at index 715556: Ring Self-intersection[-93.8233570934823 29.7085516855208]
# Invalid geometry at index 715570: Ring Self-intersection[-93.8334135872081 29.7716596947568]
# Invalid geometry at index 715573: Ring Self-intersection[-93.8921601476947 29.7950854978229]
# Invalid geometry at index 715595: Ring Self-intersection[-93.8384064582474 29.7441347133]
# Invalid geometry at index 724956: Ring Self-intersection[-94.3219388673268 29.6884576132483]
# Invalid geometry at index 726384: Ring Self-intersection[-94.3210976220068 29.7727703219487]
# Invalid geometry at index 738747: Ring Self-intersection[-94.1092631518572 29.7239109276781]
# Invalid geometry at index 755419: Self-intersection[-94.4749232369655 29.5316525546919]
# Invalid geometry at index 756114: Ring Self-intersection[-94.8866003185365 29.2616256656076]
# Invalid geometry at index 756277: Ring Self-intersection[-94.8924266240459 29.2628607115877]
# Invalid geometry at index 756289: Ring Self-intersection[-94.8812587197367 29.2711210346563]
# Invalid geometry at index 757492: Ring Self-intersection[-94.9190210633643 29.3434527504972]
# Invalid geometry at index 757899: Ring Self-intersection[-95.0265557178298 29.1593978235716]
# Invalid geometry at index 761062: Ring Self-intersection[-94.9655382545871 29.2112323559797]
# Invalid geometry at index 761402: Ring Self-intersection[-95.0261451985203 29.2378473117228]
# Invalid geometry at index 761500: Ring Self-intersection[-95.0397740240392 29.2667920174874]
# Invalid geometry at index 761586: Ring Self-intersection[-95.0457727156796 29.2765891007329]
# Invalid geometry at index 761627: Ring Self-intersection[-95.0052813410923 29.2530763514213]
# Invalid geometry at index 761631: Ring Self-intersection[-94.9830773922102 29.2807646674714]
# Invalid geometry at index 761655: Ring Self-intersection[-94.9986429418727 29.2884004388436]
# Invalid geometry at index 761660: Ring Self-intersection[-94.9978005587843 29.2905966015585]
# Invalid geometry at index 761676: Ring Self-intersection[-94.9714321457746 29.2960230519263]
# Invalid geometry at index 762427: Ring Self-intersection[-94.9133661156596 29.2401494423151]
# Invalid geometry at index 763043: Ring Self-intersection[-95.0079479187018 29.2510603423086]
# Invalid geometry at index 763801: Ring Self-intersection[-95.0335576993894 29.279211665812]
# Invalid geometry at index 764341: Ring Self-intersection[-94.8965731220485 29.234397460719]
# Invalid geometry at index 764401: Ring Self-intersection[-94.8759585770432 29.246869432651]
# Invalid geometry at index 764597: Ring Self-intersection[-94.9981458359652 29.316775118979]
# Invalid geometry at index 765014: Ring Self-intersection[-94.9163734337117 29.2281780096735]
# Invalid geometry at index 765878: Ring Self-intersection[-95.0105073127835 29.4207798328787]
# Invalid geometry at index 770442: Ring Self-intersection[-95.109342534275 29.1984859736853]
# Invalid geometry at index 770521: Ring Self-intersection[-95.0643865327062 29.2019299623083]
# Invalid geometry at index 770524: Ring Self-intersection[-95.1271761882456 29.2125672940711]
# Invalid geometry at index 770612: Ring Self-intersection[-95.1081309150709 29.2005802654757]
# Invalid geometry at index 770637: Ring Self-intersection[-95.1167704261252 29.2186691054028]
# Invalid geometry at index 771119: Ring Self-intersection[-95.1072073552137 29.2187659308369]
# Invalid geometry at index 771252: Ring Self-intersection[-95.1110862181297 29.2213393644401]
# Invalid geometry at index 771656: Ring Self-intersection[-95.0882632287577 29.1223595469608]
# Invalid geometry at index 771898: Ring Self-intersection[-95.0047314269985 29.1767973713718]
# Invalid geometry at index 771912: Ring Self-intersection[-95.005963016124 29.1788000687768]
# Invalid geometry at index 771926: Ring Self-intersection[-94.9929973800663 29.1835412243214]
# Invalid geometry at index 771986: Ring Self-intersection[-95.0927107034589 29.1146571119396]
# Invalid geometry at index 772008: Ring Self-intersection[-95.0789551968093 29.1254997646013]
# Invalid geometry at index 772139: Ring Self-intersection[-95.0460406619951 29.2481909066282]
# Invalid geometry at index 772343: Ring Self-intersection[-95.058410854553 29.2483799417269]
# Invalid geometry at index 777416: Ring Self-intersection[-95.5752005803342 30.4352068983024]
# Invalid geometry at index 784421: Ring Self-intersection[-95.0976229094862 29.1167276564753]
# Invalid geometry at index 784466: Ring Self-intersection[-95.1031939860054 29.1037020661717]
# Invalid geometry at index 784472: Ring Self-intersection[-95.1020007547005 29.1096936830318]
# Invalid geometry at index 784747: Ring Self-intersection[-95.4916396589694 28.8682641922819]
# Invalid geometry at index 805029: Ring Self-intersection[-95.9262998377801 30.2140757883196]
# Invalid geometry at index 817529: Ring Self-intersection[-95.9454298530213 29.9923237715443]
# Invalid geometry at index 819638: Ring Self-intersection[-95.6479615786828 29.4332544414235]
# Invalid geometry at index 820377: Ring Self-intersection[-95.6201484909265 29.8067535617505]
# Invalid geometry at index 821535: Ring Self-intersection[-95.7495661239002 29.9633837349932]
# Invalid geometry at index 829699: Ring Self-intersection[-95.6686950482336 29.4035196774429]
# Invalid geometry at index 831316: Ring Self-intersection[-95.9610890043466 29.5679555133967]
# Invalid geometry at index 834444: Ring Self-intersection[-95.661804404367 29.2653443849173]
# Invalid geometry at index 844141: Ring Self-intersection[-95.5945378705812 28.9105873554112]
# Invalid geometry at index 844856: Ring Self-intersection[-95.5621008164523 28.9051019132738]
# Invalid geometry at index 844859: Ring Self-intersection[-95.543595655355 28.8166913056208]
# Invalid geometry at index 844887: Ring Self-intersection[-95.5151853429739 28.8307119231824]
# Invalid geometry at index 845840: Ring Self-intersection[-95.6815399676381 29.0059625917223]
# Invalid geometry at index 849228: Ring Self-intersection[-95.8438296021554 29.0234072818571]
# Invalid geometry at index 857004: Ring Self-intersection[-95.7792314740316 28.8752544405189]
# Invalid geometry at index 857039: Ring Self-intersection[-95.8363569783639 28.761988891374]
# Invalid geometry at index 857062: Ring Self-intersection[-95.9124818874504 28.6286618596058]
# Invalid geometry at index 860194: Ring Self-intersection[-96.0231842963625 29.0796231186861]
# Invalid geometry at index 860474: Ring Self-intersection[-95.638680559692 32.0291078975443]
# Invalid geometry at index 881769: Ring Self-intersection[-95.4410880534566 31.9047937412963]
# Invalid geometry at index 881781: Ring Self-intersection[-95.4434774532859 31.9004061041805]
# Invalid geometry at index 882073: Ring Self-intersection[-95.8272940632993 31.7330245346572]
# Invalid geometry at index 892688: Ring Self-intersection[-96.1677973773895 31.9690976290601]
# Invalid geometry at index 904137: Ring Self-intersection[-95.9813172264873 31.8111599307764]
# Invalid geometry at index 956833: Ring Self-intersection[-95.9399025329033 31.2884684064521]
# Invalid geometry at index 1023770: Ring Self-intersection[-96.8752640854095 31.3507989193706]
# Invalid geometry at index 1077414: Ring Self-intersection[-96.0321823521011 29.8120914138037]
# Invalid geometry at index 1099143: Ring Self-intersection[-96.4294602111126 29.8639524096066]
# Invalid geometry at index 1108570: Ring Self-intersection[-97.3825496541598 32.8896825431583]
# Invalid geometry at index 1161492: Ring Self-intersection[-97.8087192823347 32.3289442638194]
# Invalid geometry at index 1161494: Ring Self-intersection[-97.8381736649286 32.5781440917044]
# Invalid geometry at index 1161556: Ring Self-intersection[-97.7864712200533 32.4617998378743]
# Invalid geometry at index 1231823: Ring Self-intersection[-98.2716127591834 30.4688513869379]
# Invalid geometry at index 1263943: Ring Self-intersection[-98.7628942443095 30.7445540663089]
# Invalid geometry at index 1270500: Ring Self-intersection[-96.2552099997505 29.375242459923]
# Invalid geometry at index 1280622: Ring Self-intersection[-96.5290024512098 29.6638924616046]
# Invalid geometry at index 1284075: Ring Self-intersection[-96.3351568090373 29.1402559045406]
# Invalid geometry at index 1314892: Ring Self-intersection[-96.4102522292227 28.4382203209473]
# Invalid geometry at index 1316304: Ring Self-intersection[-96.5657648778585 28.8340455909408]
# Invalid geometry at index 1322803: Ring Self-intersection[-96.4049589539266 28.4359722854623]
# Invalid geometry at index 1322869: Ring Self-intersection[-96.4507315855156 28.7544826564869]
# Invalid geometry at index 1323579: Ring Self-intersection[-96.4126892123452 28.3825126129881]
# Invalid geometry at index 1324565: Ring Self-intersection[-96.4481827888627 28.4644328089135]
# Invalid geometry at index 1324641: Ring Self-intersection[-96.4374946405452 28.4559407698146]
# Invalid geometry at index 1325185: Ring Self-intersection[-96.4696740765813 28.4086642365201]
# Invalid geometry at index 1325188: Ring Self-intersection[-96.4807809410795 28.5061264523789]
# Invalid geometry at index 1325210: Ring Self-intersection[-96.412599491924 28.4105503868824]
# Invalid geometry at index 1325218: Ring Self-intersection[-96.4113097667546 28.4140713857529]
# Invalid geometry at index 1325233: Ring Self-intersection[-96.4579133937283 28.5831154712875]
# Invalid geometry at index 1325263: Ring Self-intersection[-96.4549329732779 28.5837902068734]
# Invalid geometry at index 1325326: Ring Self-intersection[-96.431340290842 28.4525136680896]
# Invalid geometry at index 1325335: Ring Self-intersection[-96.4536666670517 28.4413766465084]
# Invalid geometry at index 1325337: Ring Self-intersection[-96.4414728732585 28.4492854530319]
# Invalid geometry at index 1325400: Ring Self-intersection[-96.3795445566955 28.3987402604693]
# Invalid geometry at index 1325802: Ring Self-intersection[-96.4214369147524 28.3675399880527]
# Invalid geometry at index 1325913: Ring Self-intersection[-96.430939081041 28.3495044358055]
# Invalid geometry at index 1325943: Ring Self-intersection[-96.4346774126927 28.3602837750127]
# Invalid geometry at index 1325953: Ring Self-intersection[-96.4317828878141 28.358930109193]
# Invalid geometry at index 1326232: Ring Self-intersection[-96.5631112231428 28.5988595800815]
# Invalid geometry at index 1326251: Ring Self-intersection[-96.6072840519028 28.5844079647423]
# Invalid geometry at index 1327090: Ring Self-intersection[-96.4622500062844 28.4742953760484]
# Invalid geometry at index 1327108: Ring Self-intersection[-96.4893458651515 28.4855978636267]
# Invalid geometry at index 1327129: Ring Self-intersection[-96.4722197917138 28.4890965760915]
# Invalid geometry at index 1327142: Ring Self-intersection[-96.4593226952432 28.4907956946918]
# Invalid geometry at index 1328015: Ring Self-intersection[-96.4379916765809 28.3709107089265]
# Invalid geometry at index 1328156: Ring Self-intersection[-96.4775447305396 28.4930142656767]
# Invalid geometry at index 1329890: Ring Self-intersection[-96.5521060330964 28.3801095618072]
# Invalid geometry at index 1329898: Ring Self-intersection[-96.5536992961337 28.4731842104609]
# Invalid geometry at index 1329910: Ring Self-intersection[-96.5578361238398 28.4633521179507]
# Invalid geometry at index 1329919: Ring Self-intersection[-96.5251408168026 28.3925238442379]
# Invalid geometry at index 1329923: Ring Self-intersection[-96.5486939165006 28.3825381430882]
# Invalid geometry at index 1330006: Ring Self-intersection[-96.5516261918275 28.3943288251972]
# Invalid geometry at index 1330027: Ring Self-intersection[-96.5474747989453 28.4349984212032]
# Invalid geometry at index 1330036: Ring Self-intersection[-96.5749117507307 28.4591014770025]
# Invalid geometry at index 1331555: Ring Self-intersection[-96.6551176042224 28.4063307296273]
# Invalid geometry at index 1332013: Ring Self-intersection[-96.5982284771281 28.4302557618903]
# Invalid geometry at index 1332101: Ring Self-intersection[-96.6284766431072 28.4501031676767]
# Invalid geometry at index 1332767: Ring Self-intersection[-96.5802688009791 28.3919535920219]
# Invalid geometry at index 1332809: Ring Self-intersection[-96.5666815381519 28.3980812621129]
# Invalid geometry at index 1333835: Ring Self-intersection[-96.6335406972076 28.3265736860052]
# Invalid geometry at index 1334118: Ring Self-intersection[-96.6628717099147 28.3291365829539]
# Invalid geometry at index 1334208: Ring Self-intersection[-96.609634398089 28.3532153463968]
# Invalid geometry at index 1334428: Ring Self-intersection[-96.6358324822221 28.3483218208723]
# Invalid geometry at index 1334687: Ring Self-intersection[-96.6758502249884 28.3376773280018]
# Invalid geometry at index 1334710: Ring Self-intersection[-96.6470430866382 28.3426781137596]
# Invalid geometry at index 1334743: Ring Self-intersection[-96.6311688586273 28.3475280850748]
# Invalid geometry at index 1334775: Ring Self-intersection[-96.6558312151646 28.3604417177535]
# Invalid geometry at index 1334785: Ring Self-intersection[-96.6555482815302 28.3658865313154]
# Invalid geometry at index 1336476: Ring Self-intersection[-96.7923843838112 28.4400857317577]
# Invalid geometry at index 1337110: Ring Self-intersection[-96.7789891191815 28.4553240520859]
# Invalid geometry at index 1337302: Ring Self-intersection[-96.8269433162493 28.4892857540253]
# Invalid geometry at index 1337697: Ring Self-intersection[-96.8042330806814 28.4979888127434]
# Invalid geometry at index 1338314: Ring Self-intersection[-96.78916907849 28.4322195825527]
# Invalid geometry at index 1338888: Ring Self-intersection[-96.8428006712766 28.4457490007997]
# Invalid geometry at index 1339024: Ring Self-intersection[-96.8471947783934 28.4319318949212]
# Invalid geometry at index 1339607: Ring Self-intersection[-96.816795831822 28.3059530373917]
# Invalid geometry at index 1339617: Ring Self-intersection[-96.8260225509072 28.3089697476335]
# Invalid geometry at index 1339705: Ring Self-intersection[-96.8469406098362 28.4762046730563]
# Invalid geometry at index 1339909: Ring Self-intersection[-96.8215052028414 28.314988389774]
# Invalid geometry at index 1340356: Ring Self-intersection[-96.8780509931318 28.6059687474907]
# Invalid geometry at index 1340749: Ring Self-intersection[-96.8104059170617 28.4527746963957]
# Invalid geometry at index 1341625: Ring Self-intersection[-96.7427479685579 28.1820976257459]
# Invalid geometry at index 1342182: Ring Self-intersection[-96.8072262295039 28.2435842096995]
# Invalid geometry at index 1342220: Ring Self-intersection[-96.8049231154659 28.2585168500766]
# Invalid geometry at index 1342237: Ring Self-intersection[-96.8082052818275 28.2754069803955]
# Invalid geometry at index 1342292: Ring Self-intersection[-96.8504914718058 28.2856980930108]
# Invalid geometry at index 1342422: Ring Self-intersection[-96.8119017416683 28.302978188589]
# Invalid geometry at index 1343429: Ring Self-intersection[-96.8205739730721 28.271917420083]
# Invalid geometry at index 1343435: Ring Self-intersection[-96.8882063546597 28.2615170854237]
# Invalid geometry at index 1343437: Ring Self-intersection[-96.875789080088 28.268913323079]
# Invalid geometry at index 1343438: Ring Self-intersection[-96.8789903963193 28.2673207975903]
# Invalid geometry at index 1343583: Ring Self-intersection[-96.8774814803418 28.2724858697987]
# Invalid geometry at index 1343614: Ring Self-intersection[-96.8419078133733 28.2968418791652]
# Invalid geometry at index 1343674: Ring Self-intersection[-96.8591777390799 28.2576092589857]
# Invalid geometry at index 1343706: Ring Self-intersection[-96.8553096375829 28.2640003478978]
# Invalid geometry at index 1343708: Ring Self-intersection[-96.8643860260632 28.2606414509521]
# Invalid geometry at index 1343715: Ring Self-intersection[-96.8575901748226 28.2615727358219]
# Invalid geometry at index 1343733: Ring Self-intersection[-96.8453058713328 28.2622638164212]
# Invalid geometry at index 1343760: Ring Self-intersection[-96.8632938333795 28.2663452469938]
# Invalid geometry at index 1343798: Ring Self-intersection[-96.8636258764209 28.2706456060713]
# Invalid geometry at index 1343808: Ring Self-intersection[-96.833600283728 28.2560059448641]
# Invalid geometry at index 1343842: Ring Self-intersection[-96.8501989221431 28.2748924772008]
# Invalid geometry at index 1343845: Ring Self-intersection[-96.8350211957736 28.2678851786475]
# Invalid geometry at index 1343866: Ring Self-intersection[-96.8585927545402 28.2700434235237]
# Invalid geometry at index 1343872: Ring Self-intersection[-96.828985934425 28.2770112302932]
# Invalid geometry at index 1343891: Ring Self-intersection[-96.8242691498869 28.2824042863596]
# Invalid geometry at index 1344730: Ring Self-intersection[-96.8492688533647 28.1937661484362]
# Invalid geometry at index 1345198: Ring Self-intersection[-96.8842773887914 28.2679712785707]
# Invalid geometry at index 1345296: Ring Self-intersection[-96.8689625487996 28.2267936180999]
# Invalid geometry at index 1345308: Ring Self-intersection[-96.8546725043072 28.2225276093783]
# Invalid geometry at index 1345327: Ring Self-intersection[-96.8338165687127 28.2352285437887]
# Invalid geometry at index 1345339: Ring Self-intersection[-96.8742467580553 28.2367295647328]
# Invalid geometry at index 1345375: Ring Self-intersection[-96.863430474681 28.2375264267937]
# Invalid geometry at index 1345393: Ring Self-intersection[-96.8523051424147 28.2318748318493]
# Invalid geometry at index 1345408: Ring Self-intersection[-96.8588089093175 28.2449616190816]
# Invalid geometry at index 1345847: Ring Self-intersection[-96.8441329849989 28.2486380136499]
# Invalid geometry at index 1345894: Ring Self-intersection[-96.8699833814102 28.2543763048098]
# Invalid geometry at index 1347014: Ring Self-intersection[-96.8117261530875 28.1483246023861]
# Invalid geometry at index 1347309: Ring Self-intersection[-96.8727026777041 28.1259141664502]
# Invalid geometry at index 1347378: Ring Self-intersection[-96.7677327352133 28.1544090997784]
# Invalid geometry at index 1347699: Ring Self-intersection[-96.8006913434877 28.1552582507782]
# Invalid geometry at index 1350150: Ring Self-intersection[-96.8638870165042 28.0972084181904]
# Invalid geometry at index 1350250: Ring Self-intersection[-96.9280002961233 28.0481998595963]
# Invalid geometry at index 1351554: Ring Self-intersection[-96.9306569461308 28.0130285850231]
# Invalid geometry at index 1351561: Ring Self-intersection[-96.9358513577647 28.022166778674]
# Invalid geometry at index 1370909: Ring Self-intersection[-97.324224017276 28.8752604036131]
# Invalid geometry at index 1422610: Ring Self-intersection[-98.7481813450776 29.9928516234918]
# Invalid geometry at index 1438074: Ring Self-intersection[-100.157962273971 35.2904198455726]
# Invalid geometry at index 1438168: Ring Self-intersection[-100.163527234671 35.2930619636162]
# Invalid geometry at index 1438668: Ring Self-intersection[-100.07255032063 35.6707146681877]
# Invalid geometry at index 1440060: Ring Self-intersection[-100.139298868619 35.2911683486138]
# Invalid geometry at index 1456881: Ring Self-intersection[-100.657587312852 35.9807128279528]
# Invalid geometry at index 1464637: Ring Self-intersection[-100.770901796477 35.9660325320451]
# Invalid geometry at index 1480688: Ring Self-intersection[-101.105373198783 34.935255321205]
# Invalid geometry at index 1497578: Ring Self-intersection[-102.536520579445 35.5318316412341]
# Invalid geometry at index 1503677: Ring Self-intersection[-99.1959487079834 34.2347467746196]
# Invalid geometry at index 1507182: Ring Self-intersection[-102.613235133267 34.6748275390678]
# Invalid geometry at index 1508164: Ring Self-intersection[-102.564829892773 35.1315959279224]
# Invalid geometry at index 1510730: Ring Self-intersection[-99.1383263057594 34.1534827770387]
# Invalid geometry at index 1510991: Ring Self-intersection[-99.2317890982642 34.2443771744677]
# Invalid geometry at index 1515601: Ring Self-intersection[-99.0383857776691 34.1967371027785]
# Invalid geometry at index 1517904: Ring Self-intersection[-99.5585392708575 34.0584547626289]
# Invalid geometry at index 1525940: Ring Self-intersection[-98.5374901885681 33.8436876238661]
# Invalid geometry at index 1541135: Ring Self-intersection[-98.9295561608011 33.4578638314768]
# Invalid geometry at index 1542165: Ring Self-intersection[-99.0682122258529 33.577542733464]
# Invalid geometry at index 1543394: Ring Self-intersection[-98.7634606639938 33.1589118884579]
# Invalid geometry at index 1543399: Ring Self-intersection[-98.7646121500273 33.154186048701]
# Invalid geometry at index 1567982: Ring Self-intersection[-99.0504665047176 33.3982136516219]
# Invalid geometry at index 1598174: Ring Self-intersection[-100.268712057661 33.0069971990033]
# Invalid geometry at index 1602304: Ring Self-intersection[-102.910628989266 35.3931417945601]
# Invalid geometry at index 1604701: Ring Self-intersection[-102.878776508623 34.7083503086755]
# Invalid geometry at index 1614397: Ring Self-intersection[-100.100357612561 33.4031929752535]
# Invalid geometry at index 1619148: Ring Self-intersection[-100.364485374325 34.2876645342591]
# Invalid geometry at index 1634169: Ring Self-intersection[-101.341565418891 34.2519929110516]
# Invalid geometry at index 1649016: Ring Self-intersection[-100.920188594087 32.940307037674]
# Invalid geometry at index 1653441: Ring Self-intersection[-101.347271462204 33.2183284486982]
# Invalid geometry at index 1659885: Ring Self-intersection[-102.124683128171 34.0245729950704]
# Invalid geometry at index 1678190: Ring Self-intersection[-98.4295638907735 32.9522817586588]
# Invalid geometry at index 1719496: Ring Self-intersection[-98.3749688681605 32.4163146972924]
# Invalid geometry at index 1770603: Ring Self-intersection[-97.1719995129277 31.1721614189038]
# Invalid geometry at index 1776887: Ring Self-intersection[-98.2264745582102 31.8162865014819]
# Invalid geometry at index 1777043: Ring Self-intersection[-98.4887729592885 31.8752942297016]
# Invalid geometry at index 1800522: Ring Self-intersection[-97.8114443024048 31.1234252309664]
# Invalid geometry at index 1803820: Ring Self-intersection[-97.7484379380269 31.2092261362359]
# Invalid geometry at index 1804033: Ring Self-intersection[-97.7123057910993 31.046900330921]
# Invalid geometry at index 1912563: Ring Self-intersection[-100.758586057815 32.2307560833474]
# Invalid geometry at index 1922995: Ring Self-intersection[-96.9271135521901 28.0546566006382]
# Invalid geometry at index 1922999: Ring Self-intersection[-96.931137837296 28.0564499079329]
# Invalid geometry at index 1923079: Ring Self-intersection[-96.9547025866244 28.0115207012315]
# Invalid geometry at index 1926579: Ring Self-intersection[-97.1615602319915 28.6163926900931]
# Invalid geometry at index 1932522: Ring Self-intersection[-96.9851743968522 27.9782928139735]
# Invalid geometry at index 1932629: Ring Self-intersection[-96.9656625143628 28.0137499336942]
# Invalid geometry at index 1932633: Ring Self-intersection[-97.1443348085296 28.0122684504496]
# Invalid geometry at index 1933160: Ring Self-intersection[-96.9658894775124 28.007625960689]
# Invalid geometry at index 1934961: Ring Self-intersection[-96.986102044351 27.9518835346153]
# Invalid geometry at index 1935003: Ring Self-intersection[-97.0836885935303 27.9824081436066]
# Invalid geometry at index 1935749: Ring Self-intersection[-96.9624714748461 27.9612275275659]
# Invalid geometry at index 1940121: Ring Self-intersection[-97.9623983363046 28.2502804010771]
# Invalid geometry at index 1940970: Ring Self-intersection[-97.5290371320473 28.6164683020207]
# Invalid geometry at index 1955115: Ring Self-intersection[-97.9032949465825 28.7813572155469]
# Invalid geometry at index 1955117: Ring Self-intersection[-96.8825676358093 28.1474206080286]
# Invalid geometry at index 1977750: Ring Self-intersection[-99.2687710269262 28.3082435757679]
# Invalid geometry at index 1996805: Ring Self-intersection[-99.4936685229104 27.4982732396707]
# Invalid geometry at index 1998154: Ring Self-intersection[-97.0815303831385 27.817822563753]
# Invalid geometry at index 2004483: Ring Self-intersection[-97.4849073971696 27.3877402317954]
# Invalid geometry at index 2005126: Ring Self-intersection[-97.3159959838012 27.4973191010261]
# Invalid geometry at index 2016433: Ring Self-intersection[-97.5211734092407 27.4633371532023]
# Invalid geometry at index 2016447: Ring Self-intersection[-97.5469929104217 27.408042364188]
# Invalid geometry at index 2016466: Ring Self-intersection[-97.333299282252 27.5378985236697]
# Invalid geometry at index 2029695: Ring Self-intersection[-97.4368737047493 27.1466292844956]
# Invalid geometry at index 2045699: Ring Self-intersection[-97.5872472863963 26.8500170712488]
# Invalid geometry at index 2056636: Ring Self-intersection[-97.1911564892059 26.0113967990765]
# Invalid geometry at index 2056855: Ring Self-intersection[-97.311677812278 26.1822266807347]
# Invalid geometry at index 2056903: Ring Self-intersection[-97.3685159174604 26.017533911826]
# Invalid geometry at index 2056924: Ring Self-intersection[-97.5002710695001 26.4459166641227]
# Invalid geometry at index 2057012: Ring Self-intersection[-97.178594635542 26.1666676759444]
# Invalid geometry at index 2057059: Ring Self-intersection[-97.4211752121813 26.3813017227398]
# Invalid geometry at index 2085771: Ring Self-intersection[-100.747742201175 32.9155995124066]
# Invalid geometry at index 2126650: Ring Self-intersection[-102.437750727979 31.0798252763789]
# Invalid geometry at index 2126687: Ring Self-intersection[-102.252220996329 30.0355647242576]
# Invalid geometry at index 2137630: Ring Self-intersection[-104.313145844953 32.0381472980131]
# Invalid geometry at index 2137698: Ring Self-intersection[-104.350337958057 32.0225321035989]
# Invalid geometry at index 2145000: Ring Self-intersection[-104.970443513279 30.6098074254701]
# Invalid geometry at index 2146161: Ring Self-intersection[-104.691501446905 30.183159262366]
# Invalid geometry at index 2149652: Ring Self-intersection[-105.560784286891 30.9962569341799]
# Invalid geometry at index 2186709: Ring Self-intersection[-99.3423437653573 29.6819029136984]
# Invalid geometry at index 2190885: Ring Self-intersection[-99.8772919892606 29.744960725631]
# Invalid geometry at index 2201700: Ring Self-intersection[-100.592817156977 29.7615050498864]
# Invalid geometry at index 2206954: Ring Self-intersection[-100.962775854309 29.3809377364409]
# Invalid geometry at index 2224737: Ring Self-intersection[-102.726595055947 29.7433969004802]
# Invalid geometry at index 2226069: Ring Self-intersection[-103.098775319076 29.6623514755539]
# Invalid geometry at index 2226180: Ring Self-intersection[-103.038961428202 29.2664344674646]
# Invalid geometry at index 2227530: Ring Self-intersection[-103.112122667614 29.0746783867005]
# Invalid geometry at index 2227532: Ring Self-intersection[-103.123026711625 29.0843006451182]
# Invalid geometry at index 2227939: Ring Self-intersection[-103.594352744474 29.3805651996867]
# Invalid geometry at index 2229345: Ring Self-intersection[-103.573629197485 29.256168803205]
# Invalid geometry at index 2229391: Ring Self-intersection[-103.488026043565 29.284962193536]
# Invalid geometry at index 2231224: Ring Self-intersection[-103.832055997813 29.3739033038858]
# Invalid geometry at index 2231272: Ring Self-intersection[-103.874778076136 29.5511111238549]
# Invalid geometry at index 2233157: Ring Self-intersection[-104.488826781278 29.7959555706461]
# Invalid geometry at index 2233158: Ring Self-intersection[-104.474972586541 29.6239221598998]
# Converted geometries to GeoJSON strings.
# Writing to log file logs\TX_wetlands_geo_clean_log_20250508_101529_814973.txt...
# TX_wetlands.parquet data cleaned and saved successfully!
# File TX_wetlands.parquet processed and saved.

# %% [markdown]
# #### 1.2 Uploading cleaned encumbrance parquets to GCS

# %%
# Function to upload locally saved parquet to GCS
def upload_parquet_to_gcs(
        bucket_name,
        bucket_folder,
        dataset,
        local_ingestion_path = PARQUET_INGESTION_PATH,
        state=None):
    """
    Uploads a local Parquet file to a GCS bucket using config structure.

    Args:
        bucket_name (str): Target GCS bucket.
        dataset (str): One of the encumbrances in EncumbranceType
        local_file_path (str): Local parquet file path.
        state (str, optional): State name for datasets that include it.
    """
    gcs_folder = f'{bucket_folder}/{dataset}'
    filename = f"{state}_{dataset}.parquet" if state else f"{dataset}.parquet"
    local_file_path = os.path.join(local_ingestion_path, filename)
    if not os.path.exists(local_file_path):
        raise FileNotFoundError(f"File {local_file_path} does not exist.")
    destination_blob_path = f"{gcs_folder}/{filename}"

    # GCS client upload
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(destination_blob_path)
    blob.upload_from_filename(local_file_path)

    print(f"Uploaded {filename} to gs://{bucket_name}/{destination_blob_path}")

# %%
# Loop over states and encumbrances to upload to GCS
# List of states and datasets
states = [
    #'PA',
    'GA',
    #'MO',
    'WI',
    'NM',
    'IL',
    'WA', 
    'TX'
    ]
datasets = [
    'wetlands',
    #'protected_lands'
    ] # To re-run all, replace this with ENCUMBRANCES

for dataset in datasets:
    if dataset in [
        'wetlands', 
        #'protected_lands'
        ]:
        for state in states:
            try:
                upload_parquet_to_gcs(
                    bucket_name=BUCKET,
                    bucket_folder=BUCKET_FOLDER, 
                    dataset=dataset, 
                    local_ingestion_path=PARQUET_INGESTION_PATH, 
                    state=state
                )
            except Exception as e:
                print(f"Failed to upload {dataset} for {state}: {e}")
    else:
        try:
            upload_parquet_to_gcs(
                bucket_name=BUCKET,
                bucket_folder=BUCKET_FOLDER,
                dataset=dataset, 
                local_ingestion_path=PARQUET_INGESTION_PATH
                # No state needed
            )
        except Exception as e:
            print(f"Failed to upload {dataset}: {e}")

# %% [markdown]
# #### 2. Convert county boundaries to geographic projection and upload to BQ

# %%
# Upload local parquet file to GCS bucket
# First, define constants
GIS_PROJECT = 'clgx-gis-app-dev-06e3'
POC_DATASET = 'encumbered_parcels'
CREDENTIALS_PATH =  r"C:\Users\eprashar\AppData\Roaming\gcloud\application_default_credentials.json"
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = str(CREDENTIALS_PATH)

# Verify credentials
utils.check_and_authenticate(CREDENTIALS_PATH)
# Out:
# Credentials file is valid.

# %%
# Upload county data in GCS bucket after converting CRS to EPSG:4326
def convert_upload_parquet_to_gcs_and_bigquery(
    source_folder,
    output_name,
    bucket_name,
    gcs_blob,
    project_id,
    dataset_id,
    table_name
):
    """
    Converts a Parquet file with EPSG:4269 geometries to EPSG:4326,
    uploads it to GCS, then loads it into BigQuery.

    Args:
    """
    # Load and convert CRS
    input_path = os.path.join(LOCAL_DATA_FOLDER, source_folder)
    gdf = gpd.read_file(input_path)
    print(f"Loaded {len(gdf)} features from {input_path}")

    # Convert geometries to WKT
    

    if gdf.crs is None or gdf.crs.to_epsg() != geo_crs:
        gdf = gdf.to_crs(geo_crs)
        print("CRS converted to EPSG:4326")
    else:
        print("CRS already in EPSG:4326")

    # Save converted file locally
    output_path = os.path.join(PARQUET_INGESTION_PATH, f'{output_name}')
    gdf.to_parquet(output_path)
    print(f"Saved converted file to {output_path}")

    # Upload to GCS
    gcs_blob_path = f'{gcs_blob}/{output_name}'
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(gcs_blob_path)
    blob.upload_from_filename(output_path)
    print(f"Uploaded to GCS: gs://{bucket_name}/{gcs_blob_path}")

    # Load into BigQuery
    client = bigquery.Client()
    table_id = f"{project_id}.{dataset_id}.{table_name}"

    job_config = bigquery.LoadJobConfig(
        source_format=bigquery.SourceFormat.PARQUET,
        autodetect=True,
        write_disposition=bigquery.WriteDisposition.WRITE_TRUNCATE
    )

    uri = f"gs://{bucket_name}/{gcs_blob_path}"
    load_job = client.load_table_from_uri(uri, table_id, job_config=job_config)
    load_job.result()  # Wait for job to complete

    print(f"Loaded data into BigQuery table: {table_id}")

# %%
# Executing the county data upload
convert_upload_parquet_to_gcs_and_bigquery(
    source_folder=COUNTY_DATA,
    output_name='county_bounds.parquet',
    bucket_name=BUCKET,
    gcs_blob= f'{BUCKET_FOLDER}/county_bounds',
    project_id=GIS_PROJECT,
    dataset_id=POC_DATASET,
    table_name="county_boundaries"
)
# Out:
# Loaded 3235 features from C:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\jan_25_proj_infra_parcels\data\counties\tl_2024_us_county\tl_2024_us_county.shp
# CRS converted to EPSG:4326
# Saved converted file to C:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\jan_25_proj_infra_parcels\data\ingestion_parquets\county_bounds.parquet
# Uploaded to GCS: gs://geospatial-projects/infra_parcels/county_bounds/county_bounds.parquet
# Loaded data into BigQuery table: clgx-gis-app-dev-06e3.encumbered_parcels.county_boundaries

# %% [markdown]
# #### 3.1 [Relevant for local development in python]: Get county-level encumbrance parquet files

# %%
# Function to load county boundary
def get_county_boundary(fips_code):
    """
    Load county boundary from shapefile and filter by FIPS code.
    """
    # Read the shapefile
    gdf_county = gpd.read_file(os.path.join(LOCAL_DATA_FOLDER, COUNTY_DATA))
    
    # Filter by FIPS code
    gdf_county = gdf_county[gdf_county['GEOID'] == fips_code]
    
    # Convert to EPSG:4326
    gdf_county = gdf_county.to_crs(geo_crs)
    
    return gdf_county

# %%
# Filter encumbrance data for county
def filter_gdf_using_boundary(gdf_encumbrance, county_boundary):
    """
    Load wetland attributes from a geodatabase and join them to the wetlands GeoDataFrame
    using the 'ATTRIBUTE' field as a key.

    Parameters:

    Returns:
        GeoDataFrame: 
    """

    # Convert both dataframes to the same projection system
    gdf_encumbrance = gdf_encumbrance.to_crs(county_boundary.crs)

    # Perform a spatial join
    filtered_encumbrance = gpd.sjoin(gdf_encumbrance, county_boundary, predicate='within')

    # Drop unnecessary columns from county database
    filtered_encumbrance.drop(columns=[
        'index_right',
        'STATEFP',
        'COUNTYFP',
        'COUNTYNS',
        'GEOID',
        'GEOIDFQ',
        'LSAD',
        'CLASSFP',
        'MTFCC',
        'CSAFP',
        'CBSAFP',
        'METDIVFP',
        'FUNCSTAT',
        'ALAND',
        'AWATER',
        'INTPTLAT',
        'INTPTLON'], inplace=True)

    # Convert epsg for filtered gdf to 4326
    filtered_encumbrance = filtered_encumbrance.set_geometry('geometry').to_crs(geo_crs)
    print(f'CRS of the filtered dataframe is {filtered_encumbrance.crs}')
    return filtered_encumbrance

# %%
# Load data for encumbrance type
def load_encumbrance_for_county(
        encumbrance_type: EncumbranceType,
        fips,
        state=None) -> gpd.GeoDataFrame:
    '''
    Load encumbrance data from <source> and return as GeoDataFrame.
    '''
    # Flag error if chosen encumbrance is not defined
    if encumbrance_type not in ENCUMBRANCES:
        raise ValueError(
            f"Invalid encumbrance type '{encumbrance_type}'. "
            f"Valid options are: {', '.join(ENCUMBRANCES)}."
        )
    # Obtain county boundary
    county_boundary = get_county_boundary(fips)

    # Read the parquet file for the encumbrance type
    try:
        file_path = os.path.join(PARQUET_INGESTION_PATH, f'{state}_{encumbrance_type}.parquet' if state else f'{encumbrance_type}.parquet')
        gdf = gpd.read_parquet(file_path)
    except Exception as e:
        raise FileNotFoundError(f"File {file_path} not found. Error: {e}")

    # Use spatial join to get encumbrance data for county
    county_gdf = filter_gdf_using_boundary(gdf, county_boundary)

    # save county_gdf as parquet file
    print(f"{encumbrance_type} data loaded for FIPS code: {fips}")
    
    # Convert to EPSG:4326
    county_gdf = county_gdf.to_crs(geo_crs)
    county_gdf.to_parquet(os.path.join(PARQUET_INGESTION_PATH,f'{fips}_{encumbrance_type}.parquet'))
    print(f'{encumbrance_type} parquet created for {fips}!')

# %%
# Mapping of county FIPS to state abbreviations
FIPS_TO_STATE = {
    '17031': 'IL',  # Cook County, IL
    '13121': 'GA',  # Fulton County, GA
    '53033': 'WA',  # King County, WA
    '48491': 'TX',  # Williamson County, TX
    '29181': 'MO',  # Warren County, MO
    '42011': 'PA',  # Berks County, PA
    '55107': 'WI',  # Rusk County, WI
    '35051': 'NM',  # Sierra County, NM
    '17127': 'IL',  # Massac County, IL
}

poc_fips = POC_FINALIZED_COUNTIES
encumbrances = ENCUMBRANCES

# Encumbrances that require state information
STATE_REQUIRED_TYPES = {'wetlands', 'protected_lands'}

for fips in poc_fips:
    for encumbrance in encumbrances:
        filename = f"{fips}_{encumbrance}.parquet"
        destination_file = os.path.join(PARQUET_INGESTION_PATH, filename)

        if not os.path.exists(destination_file):
            try:
                state = FIPS_TO_STATE.get(fips) if encumbrance in STATE_REQUIRED_TYPES else None

                load_encumbrance_for_county(
                    encumbrance_type=encumbrance,
                    fips=fips,
                    state=state
                )
                print(f"File {filename} processed and saved.")
            except Exception as e:
                print(f"Failed to process {filename}: {e}")
        else:
            print(f"File {filename} already exists. Skipping.")
# Out:
# File 17031_roadways.parquet already exists. Skipping.
# File 17031_railways.parquet already exists. Skipping.
# File 17031_protected_lands.parquet already exists. Skipping.
# File 17031_wetlands.parquet already exists. Skipping.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# transmission_lines data loaded for FIPS code: 17031
# transmission_lines parquet created for 17031!
# File 17031_transmission_lines.parquet processed and saved.
# File 13121_roadways.parquet already exists. Skipping.
# File 13121_railways.parquet already exists. Skipping.
# File 13121_protected_lands.parquet already exists. Skipping.
# File 13121_wetlands.parquet already exists. Skipping.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# transmission_lines data loaded for FIPS code: 13121
# transmission_lines parquet created for 13121!
# File 13121_transmission_lines.parquet processed and saved.
# File 53033_roadways.parquet already exists. Skipping.
# File 53033_railways.parquet already exists. Skipping.
# File 53033_protected_lands.parquet already exists. Skipping.
# File 53033_wetlands.parquet already exists. Skipping.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# transmission_lines data loaded for FIPS code: 53033
# transmission_lines parquet created for 53033!
# File 53033_transmission_lines.parquet processed and saved.
# File 48491_roadways.parquet already exists. Skipping.
# File 48491_railways.parquet already exists. Skipping.
# File 48491_protected_lands.parquet already exists. Skipping.
# File 48491_wetlands.parquet already exists. Skipping.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# transmission_lines data loaded for FIPS code: 48491
# transmission_lines parquet created for 48491!
# File 48491_transmission_lines.parquet processed and saved.
# File 29181_roadways.parquet already exists. Skipping.
# File 29181_railways.parquet already exists. Skipping.
# File 29181_protected_lands.parquet already exists. Skipping.
# File 29181_wetlands.parquet already exists. Skipping.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# transmission_lines data loaded for FIPS code: 29181
# transmission_lines parquet created for 29181!
# File 29181_transmission_lines.parquet processed and saved.
# File 42011_roadways.parquet already exists. Skipping.
# File 42011_railways.parquet already exists. Skipping.
# File 42011_protected_lands.parquet already exists. Skipping.
# File 42011_wetlands.parquet already exists. Skipping.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# transmission_lines data loaded for FIPS code: 42011
# transmission_lines parquet created for 42011!
# File 42011_transmission_lines.parquet processed and saved.
# File 55107_roadways.parquet already exists. Skipping.
# File 55107_railways.parquet already exists. Skipping.
# File 55107_protected_lands.parquet already exists. Skipping.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# wetlands data loaded for FIPS code: 55107
# wetlands parquet created for 55107!
# File 55107_wetlands.parquet processed and saved.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# transmission_lines data loaded for FIPS code: 55107
# transmission_lines parquet created for 55107!
# File 55107_transmission_lines.parquet processed and saved.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# roadways data loaded for FIPS code: 35051
# roadways parquet created for 35051!
# File 35051_roadways.parquet processed and saved.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# railways data loaded for FIPS code: 35051
# railways parquet created for 35051!
# File 35051_railways.parquet processed and saved.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# protected_lands data loaded for FIPS code: 35051
# protected_lands parquet created for 35051!
# File 35051_protected_lands.parquet processed and saved.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# wetlands data loaded for FIPS code: 35051
# wetlands parquet created for 35051!
# File 35051_wetlands.parquet processed and saved.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# transmission_lines data loaded for FIPS code: 35051
# transmission_lines parquet created for 35051!
# File 35051_transmission_lines.parquet processed and saved.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# roadways data loaded for FIPS code: 17127
# roadways parquet created for 17127!
# File 17127_roadways.parquet processed and saved.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# railways data loaded for FIPS code: 17127
# railways parquet created for 17127!
# File 17127_railways.parquet processed and saved.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# protected_lands data loaded for FIPS code: 17127
# protected_lands parquet created for 17127!
# File 17127_protected_lands.parquet processed and saved.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# wetlands data loaded for FIPS code: 17127
# wetlands parquet created for 17127!
# File 17127_wetlands.parquet processed and saved.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# transmission_lines data loaded for FIPS code: 17127
# transmission_lines parquet created for 17127!
# File 17127_transmission_lines.parquet processed and saved.

# %% [markdown]
# #### 3.2 [Relevant for local development in python]: Parcel data for POC counties from BigQ in parquet

# %%
# Define constants here
PROJECT = 'clgx-gis-app-dev-06e3'
DATASET = 'property'
POC_DATASET = 'encumbered_parcels'
POC_TABLE = 'parcels'
CREDENTIALS_PATH =  r"C:\Users\eprashar\AppData\Roaming\gcloud\application_default_credentials.json"
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = str(CREDENTIALS_PATH)

# Credentials verification
utils.check_and_authenticate(CREDENTIALS_PATH)
# Out:
# Credentials file is valid.

# %%
# Define function to get parcel data for the defined county
def fetch_and_save_county_parcels(fips_code: str) -> gpd.GeoDataFrame:
    """
    Load parcel data from BigQuery and filter by FIPS code.
    """
    # Define the SQL query to filter by FIPS code
    # TO-DO: Create a table in BQ with processed data
    query = f"""
        SELECT * 
        FROM `{PROJECT}.{POC_DATASET}.{POC_TABLE}`
        WHERE fips_code = '{fips_code}'
    """
    # Read the data into a GeoDataFrame
    gdf_parcel = utils.read_bigquery_to_gdf(project=PROJECT, dataset=POC_DATASET, table=POC_TABLE, query=query, output='gpd', geometry_col='geometry')
    
    # Convert to EPSG:4326
    gdf_parcel = gdf_parcel.to_crs(geo_crs)
    print(f'CRS of the parcel dataframe is {gdf_parcel.crs}')
    gdf_parcel.to_parquet(os.path.join(PARQUET_INGESTION_PATH,f'{fips_code}_parcels.parquet'))
    print(f'parcel parquet created for {fips_code}!')

# %%
# Save parcel parquets for all POC counties
for county_fips in POC_FINALIZED_COUNTIES:
    fetch_and_save_county_parcels(fips_code=county_fips)
