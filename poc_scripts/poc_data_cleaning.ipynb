# %%
# Importing required libraries
import os
import subprocess
from datetime import datetime, timedelta
import time
import logging
from typing import Literal
from collections import defaultdict

import pandas as pd
import numpy as np
import geopandas as gpd
from shapely.geometry import Polygon
from shapely import wkt
from shapely.geometry import shape
from shapely.validation import explain_validity, make_valid
from shapely.errors import TopologicalError
import fiona

from google.cloud import bigquery
from pandas_gbq import to_gbq
from google.cloud import storage

# Import utility constants and functions
import utils

# %%
# Initialize global constants here
POC_FINALIZED_COUNTIES = [
    # urban
    '17031',
    '13121',
    '53033',
    # sub-urban
    '48491',
    '29181',
    '42011',
    # rural 
    '55107',
    '35051',
    '17127',
]

# %%
# Define constants
#POC_DATASET = 'encumbered_parcels'
#POC_TABLE = 'parcels'
geo_crs = "EPSG:4326"
projected_crs = "EPSG:3857" 
ENCUMBRANCES = [
    'roadways',
    'railways',
    'protected_lands',
    'wetlands',
    'transmission_lines',
    ]
EncumbranceType = Literal[
    'roadways',
    'railways',
    'protected_lands',
    'wetlands',
    'transmission_lines',
]

LOCAL_DATA_FOLDER = r"C:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\jan_25_proj_infra_parcels\data"
COUNTY_DATA = r"counties\tl_2024_us_county\tl_2024_us_county.shp"
RAILWAYS_DATA = r"NTAD_North_American_Rail_Network_Lines\NARN.gdb" 
TRANSMISSION_LINES_DATA = r"transmission_lines\Transmission_Lines.shp"
ROADWAYS_DATA = r"NTAD_North_American_Roads\North_American_Roads.shp"
PROTECTED_LANDS = r"C:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\jan_25_proj_infra_parcels\data\Protected Lands"
WETLANDS = r"C:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\jan_25_proj_infra_parcels\data\Wetlands"
WETLAND_ATTRIBUTES = r"Wetlands\NWI-Code-Definitions\NWI-Code-Definitions\NWI_Code_Definitions.gdb"
PARQUET_INGESTION_PATH = r"C:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\jan_25_proj_infra_parcels\data\ingestion_parquets"

# %% [markdown]
# #### 1.1 Cleaning and saving source encumbrance data in parquet format

# %%
# Function to make valid geometries
def validate_and_fix_geometries(
        gdf,
        dataset,
        state=None):
    
    """
    """
    # Initialize summary stats for logging
    fixed_make_valid = 0
    fixed_buffer_count = 0
    dropped_count = 0

    for idx, row in gdf.iterrows():
        geom = row['geometry']
        if not geom.is_valid:
            print(f"Invalid geometry at index {idx}: {explain_validity(geom)}")
            try:
                # Attempt to fix with make_valid
                fixed = make_valid(geom)
                if fixed.is_valid and not fixed.is_empty:
                    gdf.at[idx, 'geometry'] = fixed
                    fixed_make_valid += 1
                else:
                    print(f"make_valid failed to fix geometry at index {idx}, falling back to buffer(0)")
                    fixed_w_buffer = geom.buffer(0)
                    if fixed_w_buffer.is_valid and not fixed_w_buffer.is_empty:
                        gdf.at[idx, 'geometry'] = fixed_w_buffer
                        fixed_buffer_count += 1
                    else:
                        print(f"Geometry at index {idx} is still invalid or empty after fixing. Dropping.")
                        gdf.at[idx, 'geometry'] = None
            except Exception as e:
                print(f"Exception while fixing geometry at index {idx}: {e}. Dropping.")
                gdf.at[idx, 'geometry'] = None
        else:
            gdf.at[idx, 'geometry'] = geom
    
    # Drop invalid geometries
    initial_len = len(gdf)
    gdf = gdf[gdf['geometry'].notnull()]
    dropped_count = initial_len - len(gdf) # gdf with dropped geometries

    # Enter summary stats into log file
    os.makedirs('logs', exist_ok=True)
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S_%f")
    timestamp = timestamp.replace('.', '_')  # replace any dots with underscores
    log_filename = os.path.join('logs', f"{state or 'no_state'}_{dataset}_geo_clean_log_{timestamp}.txt")

    print(f'Writing to log file {log_filename}...')

    with open(log_filename, "w") as log_file:
        log_file.write(f"Dataset: {dataset}\n")
        log_file.write(f"State: {state}\n")
        log_file.write(f"Timestamp: {timestamp}\n")
        log_file.write(f"Geometries fixed using make valid: {fixed_make_valid}\n")
        log_file.write(f"Geometries fixed using buffer zero: {fixed_buffer_count}\n")
        log_file.write(f"Geometries dropped after failed fix: {dropped_count}\n")

    return gdf

# %%
# Function to add wetland attributes
def add_wetland_attributes(gdf_wetland):
    """
    Load wetland attributes from a geodatabase and return as a GeoDataFrame.
    """
    # Read the geodatabase
    gdf_wetland_attributes = gpd.read_file(os.path.join(LOCAL_DATA_FOLDER, WETLAND_ATTRIBUTES))
    
    # Drop unnecessary columns
    columns_to_drop = [
        'SYSTEM', 'SYSTEM_NAME', 'SYSTEM_DEFINITION',
        'SUBSYSTEM', 'SUBSYSTEM_DEFINITION',
        'CLASS', 'CLASS_DEFINITION',
        'SUBCLASS', 'SUBCLASS_DEFINITION',
        'SPLIT_CLASS', 'SPLIT_CLASS_DEFINITION',
        'SPLIT_SUBCLASS', 'SPLIT_SUBCLASS_NAME', 'SPLIT_SUBCLASS_DEFINITION',
        'WATER_REGIME', 'WATER_REGIME_DEFINITION',
        'MODIFIER1', 'MODIFIER1_NAME', 'MODIFIER1_GROUP', 'MODIFIER1_SUBGROUP', 'MODIFIER1_DEFINITION',
        'MODIFIER2', 'MODIFIER2_NAME', 'MODIFIER2_GROUP', 'MODIFIER2_SUBGROUP', 'MODIFIER2_DEFINITION',
        'geometry'
    ]
    gdf_wetland_attributes = gdf_wetland_attributes.drop(
        columns=[col for col in columns_to_drop if col in gdf_wetland_attributes.columns])

    # Join datasets using the 'ATTRIBUTE' column
    wetlands_with_attributes = gdf_wetland.merge(
        gdf_wetland_attributes,
        how='left',
        on='ATTRIBUTE'
    )

    return wetlands_with_attributes

# %%
# Define global config variable to store dataset configurations
# Config includes paths, read arguments, and cleanup functions for each dataset
DATASET_CONFIG = {
    'transmission_lines': {
        'path': TRANSMISSION_LINES_DATA,
        'read_kwargs': {},
        'requires_state': False,
        'cleanup': lambda gdf: gdf
            .drop(columns=[
                'OBJECTID', 'SOURCE', 'SOURCEDATE', 'VAL_METHOD', 'VOLTAGE',
                'INFERRED', 'SUB_1', 'SUB_2'
            ])
            .assign(Shape__Len=gdf['Shape__Len'].round(2))
    },
    'railways': {
        'path': RAILWAYS_DATA,
        'read_kwargs': {'layer': 'North_American_Rail_Network_Lines'},
        'requires_state': False,
        'cleanup': lambda gdf: gdf
            .drop(columns=[
                'FRFRANODE', 'TOFRANODE', 'STFIPS', 'CNTYFIPS', 'STATEAB', 'COUNTRY',
                'FRADISTRCT', 'RROWNER1', 'RROWNER2', 'RROWNER3',
                'TRKRGHTS1', 'TRKRGHTS2', 'TRKRGHTS3', 'TRKRGHTS4', 'TRKRGHTS5',
                'TRKRGHTS6', 'TRKRGHTS7', 'TRKRGHTS8', 'TRKRGHTS9', 'DIVISION',
                'SUBDIV', 'BRANCH', 'YARDNAME', 'PASSNGR', 'STRACNET', 'TRACKS',
                'NET', 'MILES', 'TIMEZONE', 'SHAPE_Length'
            ], errors='ignore')
            .assign(KM=gdf['KM'].round(2))
    },
    'roadways': {
        'path': ROADWAYS_DATA,
        'read_kwargs': {},
        'requires_state': False,
        'cleanup': lambda gdf: gdf[gdf['COUNTRY'] == 2]
            .drop(columns=['DIR', 'LINKID', 'JURISCODE', 'ROADNUM', 'CLASS', 'NHS'], errors='ignore')
    },
    'wetlands': {
        'gdb_config': lambda state: {
            'folder': WETLANDS,
            'subfolder': f"{state}_geodatabase_wetlands",
            'gdb_name': f"{state}_geodatabase_wetlands.gdb"
        },
        'requires_state': True,
        'cleanup':  lambda gdf: gdf.drop(columns=['NWI_ID'], errors='ignore'),
        'postprocess': lambda gdf: add_wetland_attributes(gdf)
    },
    'protected_lands': {
        'gdb_config': lambda state: {
            'folder': PROTECTED_LANDS,
            'subfolder': f"PADUS4_1_State_{state}_GDB_KMZ",
            'gdb_name': f"PADUS4_1_State{state}.gdb"
        },
        'requires_state': True,
        'cleanup':  lambda gdf: gdf.drop(columns=[
                'FeatClass',
                'Category',
                'Own_Name',
                'Mang_Type',
                'Mang_Name',
                'Des_Tp',
                'Agg_Src',
                'GIS_Src',
                'Src_Date',
                'GIS_Acres',
                'Source_PAID',
                'Pub_Access',
                'Access_Src',
                'GAP_Sts',
                'IUCN_Cat',
                'Date_Est',
                'Comments',
                'Term',
                'Duration',
        ], errors='ignore'),
    }
}

# %%
# Function to clean and save dataset
def clean_and_save_dataset(
    dataset='railways',
    output_format='parquet',
    destination_path=PARQUET_INGESTION_PATH,
    state=None
):
    config = DATASET_CONFIG.get(dataset)
    if not config:
        raise ValueError(f"Unsupported dataset: {dataset}")

    if config.get('requires_state') and not state:
        raise ValueError(f"State must be provided for {dataset}")

    # Determine path
    if 'path' in config:
        full_path = os.path.join(LOCAL_DATA_FOLDER, config['path'])
        gdf = gpd.read_file(full_path, **config.get('read_kwargs', {}))
    else:
        # Handle GDB datasets
        gdb_info = config['gdb_config'](state)
        gdb_path = os.path.join(LOCAL_DATA_FOLDER, gdb_info['folder'], gdb_info['subfolder'], gdb_info['gdb_name'])

        # Find largest layer
        largest_layer = max(
            fiona.listlayers(gdb_path),
            key=lambda layer: len(fiona.open(gdb_path, layer=layer))
        )

        gdf = gpd.read_file(gdb_path, layer=largest_layer)
        print(f"Loaded {dataset} data from layer: {largest_layer} with {len(gdf)} features")

    # Optional post-processing
    if 'cleanup' in config:
        gdf = config['cleanup'](gdf)

    if 'postprocess' in config:
        gdf = config['postprocess'](gdf)
        print(f"Postprocessed {dataset} data")

    # Check that geometries are valid
    print(f'State name is {state}')
    gdf = validate_and_fix_geometries(
        gdf,
        dataset,
        state=state)

    # Set CRS
    gdf = gdf.to_crs(crs=geo_crs)
    print(f"CRS of data is {gdf.crs}")

    # Save output
    if output_format == 'parquet':
        filename = f"{state}_{dataset}.parquet" if state else f"{dataset}.parquet"
        filepath = os.path.join(destination_path, filename)
        gdf.to_parquet(filepath)
        print(f"{filename} data cleaned and saved successfully!")

# %%
# Upload local parquet file to GCS bucket
# First, define constants
BUCKET = 'geospatial-projects'
BUCKET_FOLDER = 'infra_parcels'
CREDENTIALS_PATH =  r"C:\Users\eprashar\AppData\Roaming\gcloud\application_default_credentials.json"
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = str(CREDENTIALS_PATH)

# Verify credentials
utils.check_and_authenticate(CREDENTIALS_PATH)
# Out:
# Credentials file is older than 24 hours. Re-authenticating...
# Trying reauthentication on gcloud server using shell command...
# Login window opened...please complete authentication
# Waiting for credentials file to update...
# Authentication confirmed! Credentials file updated.

# %%
# Loop through all states and datasets to save cleaned parquet files
# List of states and datasets
OVERWRITE_EXISTING = True
states = ['PA', 'GA', 'MO', 'WI', 'NM', 'IL','WA','TX']
datasets = [
    #'wetlands', 
    'protected_lands']

# Iterate through states and datasets
for state in states:
    for dataset in datasets:
        # Construct the filename
        filename = f"{state}_{dataset}.parquet" if state else f"{dataset}.parquet"
        destination_file = os.path.join(PARQUET_INGESTION_PATH, filename)

       # Check if the file already exists
        if OVERWRITE_EXISTING or not os.path.exists(destination_file):
            try:
                # Attempt to run the function
                # Print the reason for running the function
                print(f'Running the function because over-write status: {OVERWRITE_EXISTING} and file existence status: {os.path.exists(destination_file)}...') 
                clean_and_save_dataset(
                    dataset=dataset,
                    output_format='parquet',
                    destination_path=PARQUET_INGESTION_PATH,
                    state=state
                )
                print(f"File {filename} processed and saved.")
            except Exception as e:
                # Log the error and continue
                print(f"Failed to process {filename}: {e}")
        else:
            print(f"File {filename} already exists. Skipping.")
# Out:
# Running the function because over-write status: True and file existence status: True...
# Loaded protected_lands data from layer: PADUS4_1Comb_DOD_Trib_NGP_Fee_Desig_Ease_State_PA with 59936 features
# State name is PA
# Invalid geometry at index 38: Ring Self-intersection[1724645.1457 2084565.9513]
# Invalid geometry at index 42: Ring Self-intersection[1580941.3273 2018409.6207]
# Invalid geometry at index 44: Ring Self-intersection[1583191.626 2076904.1223]
# Invalid geometry at index 51: Ring Self-intersection[1713558.4983 2169603.028]
# Invalid geometry at index 119: Ring Self-intersection[1695300.5889 2056792.5287]
# Invalid geometry at index 126: Ring Self-intersection[1719971.5243 2081060.7246]
# Invalid geometry at index 134: Ring Self-intersection[1422398.3605 2172579.5684]
# Invalid geometry at index 159: Ring Self-intersection[1716988.3423 2170150.2183]
# Invalid geometry at index 671: Ring Self-intersection[1705673.7963 2092575.9283]
# Invalid geometry at index 2579: Ring Self-intersection[1358918.742 2038916.1169]
# Invalid geometry at index 2606: Ring Self-intersection[1716772.1765 2057645.6705]
# Invalid geometry at index 2621: Ring Self-intersection[1658667.8936 2196392.2333]
# Invalid geometry at index 2628: Ring Self-intersection[1697102.4816 2083556.1883]
# Invalid geometry at index 2660: Ring Self-intersection[1654058.7651 2043479.8687]
# Invalid geometry at index 2661: Ring Self-intersection[1620651.2867 2064298.1917]
# Invalid geometry at index 2745: Ring Self-intersection[1395608.5025 1999479.9114]
# Invalid geometry at index 2763: Ring Self-intersection[1298870.2844 2181625.2951]
# Invalid geometry at index 2764: Ring Self-intersection[1305789.7657 2090555.6176]
# Invalid geometry at index 2768: Ring Self-intersection[1736333.8978 2098394.9604]
# Invalid geometry at index 3693: Ring Self-intersection[1399449.209 2041980.0257]
# Invalid geometry at index 3707: Ring Self-intersection[1645850.9133 2276146.6643]
# Invalid geometry at index 3741: Ring Self-intersection[1545090.3583 2132288.9859]
# Invalid geometry at index 3751: Ring Self-intersection[1567053.6616 2019059.3835]
# Invalid geometry at index 3752: Ring Self-intersection[1466268.8408 2160905.2813]
# Invalid geometry at index 3754: Ring Self-intersection[1685018.0365 2206844.0317]
# Invalid geometry at index 3819: Ring Self-intersection[1697065.7774 2158828.3488]
# Invalid geometry at index 3824: Ring Self-intersection[1600416.5703 2093452.6851]
# Invalid geometry at index 3834: Ring Self-intersection[1271656.1463 2213965.3481]
# Invalid geometry at index 3850: Ring Self-intersection[1699127.0349 2037741.4733]
# Invalid geometry at index 3854: Ring Self-intersection[1764990.3522 2117904.7542]
# Invalid geometry at index 3920: Ring Self-intersection[1571383.0369 2054136.103]
# Invalid geometry at index 4113: Ring Self-intersection[1716791.9075 2057454.0026]
# Invalid geometry at index 4117: Ring Self-intersection[1701608.6394 2071842.7223]
# Invalid geometry at index 4119: Ring Self-intersection[1699376.498 2061059.0423]
# Invalid geometry at index 4126: Ring Self-intersection[1405597.8663 2025560.5489]
# Invalid geometry at index 4145: Ring Self-intersection[1745531.5568 2231793.1318]
# Invalid geometry at index 4148: Ring Self-intersection[1752833.3155 2071924.2038]
# Invalid geometry at index 4172: Ring Self-intersection[1705388.8851 2084021.102]
# Invalid geometry at index 4176: Ring Self-intersection[1697985.5158 2080203.6825]
# Invalid geometry at index 4250: Ring Self-intersection[1714137.554 2135818.9318]
# Invalid geometry at index 4263: Ring Self-intersection[1727159.4807 2124805.8179]
# Invalid geometry at index 4317: Ring Self-intersection[1658275.6011 2037756.0362]
# Invalid geometry at index 4325: Ring Self-intersection[1654417.6792 2047471.4691]
# Invalid geometry at index 4336: Ring Self-intersection[1655769.8946 2040475.5632]
# Invalid geometry at index 4339: Ring Self-intersection[1678703.4627 2036230.9259]
# Invalid geometry at index 4415: Ring Self-intersection[1606851.6447 2103038.5526]
# Invalid geometry at index 4446: Ring Self-intersection[1695418.57 2090685.6929]
# Invalid geometry at index 4452: Ring Self-intersection[1734575.1523 2098430.8484]
# Invalid geometry at index 4463: Ring Self-intersection[1568076.6366 2073119.6701]
# Invalid geometry at index 4473: Ring Self-intersection[1719111.9058 2073472.6327]
# Invalid geometry at index 4559: Ring Self-intersection[1720394.169 2081374.1591]
# Invalid geometry at index 4572: Ring Self-intersection[1723799.7462 2185968.5657]
# Invalid geometry at index 4618: Ring Self-intersection[1429451.3438 2203864.0135]
# Invalid geometry at index 4638: Ring Self-intersection[1691264.9831 2036028.0013]
# Invalid geometry at index 4714: Ring Self-intersection[1422398.3605 2172579.5684]
# Invalid geometry at index 4839: Ring Self-intersection[1724752.0715 2073758.3674]
# Invalid geometry at index 4841: Ring Self-intersection[1723148.8001 2070247.8142]
# Invalid geometry at index 4842: Ring Self-intersection[1722968.3408 2072315.4093]
# Invalid geometry at index 4850: Ring Self-intersection[1734575.1523 2098430.8484]
# Invalid geometry at index 4902: Ring Self-intersection[1715743.1657 2203677.7444]
# Invalid geometry at index 4923: Ring Self-intersection[1725471.6577 2179887.2486]
# Invalid geometry at index 4970: Ring Self-intersection[1704210.5284 2040214.6907]
# Invalid geometry at index 5066: Ring Self-intersection[1696036.944 2038980.316]
# Invalid geometry at index 5372: Ring Self-intersection[1675533.0995 2032192.1869]
# Invalid geometry at index 5932: Ring Self-intersection[1699473.6834 2039532.0921]
# Invalid geometry at index 5991: Ring Self-intersection[1691304.525 2036108.1947]
# Invalid geometry at index 5993: Ring Self-intersection[1590822.6829 2086304.4076]
# Invalid geometry at index 5994: Ring Self-intersection[1679279.3189 2034220.5575]
# Invalid geometry at index 5995: Ring Self-intersection[1672214.5949 2190686.2168]
# Invalid geometry at index 6021: Ring Self-intersection[1716440.8635 2189690.2592]
# Invalid geometry at index 6036: Ring Self-intersection[1686863.1272 2193894.9239]
# Invalid geometry at index 6775: Ring Self-intersection[1510890.3892 2122031.218]
# Invalid geometry at index 8082: Ring Self-intersection[1723854.4843 2143862.7721]
# Invalid geometry at index 9792: Ring Self-intersection[1583496.7475 2060507.637]
# Invalid geometry at index 13610: Ring Self-intersection[1355996.0727 2062679.6138]
# Invalid geometry at index 13717: Ring Self-intersection[1358568.7124 2086239.9559]
# Invalid geometry at index 13748: Ring Self-intersection[1701608.6394 2071842.7223]
# Invalid geometry at index 13751: Ring Self-intersection[1698844.1478 2058368.352]
# Invalid geometry at index 13845: Ring Self-intersection[1637467.1024 2279369.5058]
# Invalid geometry at index 13865: Ring Self-intersection[1349032.1115 2190792.364]
# Invalid geometry at index 13872: Ring Self-intersection[1697817.2342 2080332.0212]
# Invalid geometry at index 14066: Ring Self-intersection[1654417.6776 2047471.4638]
# Invalid geometry at index 14083: Ring Self-intersection[1675537.1382 2032192.8245]
# Invalid geometry at index 14122: Ring Self-intersection[1637168.7857 2057060.0438]
# Invalid geometry at index 14207: Ring Self-intersection[1396054.7044 2010803.2358]
# Invalid geometry at index 14217: Ring Self-intersection[1678973.4346 2194610.6086]
# Invalid geometry at index 14221: Ring Self-intersection[1708407.7394 2084840.645]
# Invalid geometry at index 14238: Ring Self-intersection[1734575.1523 2098430.8484]
# Invalid geometry at index 14256: Ring Self-intersection[1710651.14 2066162.8736]
# Invalid geometry at index 14257: Ring Self-intersection[1726759.961 2072651.5651]
# Invalid geometry at index 14259: Ring Self-intersection[1719083.1526 2073828.6161]
# Invalid geometry at index 14363: Ring Self-intersection[1669382.737 2183262.7]
# Invalid geometry at index 14379: Ring Self-intersection[1718933.4447 2080221.888]
# Invalid geometry at index 14396: Ring Self-intersection[1752097.5597 2096165.0966]
# Invalid geometry at index 14413: Ring Self-intersection[1704222.3443 2193006.7901]
# Invalid geometry at index 14416: Ring Self-intersection[1723799.7446 2185968.5604]
# Invalid geometry at index 14491: Ring Self-intersection[1691304.7548 2036107.3021]
# Invalid geometry at index 14554: Ring Self-intersection[1421386.4737 2171659.9984]
# Invalid geometry at index 14700: Ring Self-intersection[1714487.4608 2137893.9773]
# Invalid geometry at index 14716: Ring Self-intersection[1709968.8772 2134072.032]
# Invalid geometry at index 14750: Ring Self-intersection[1735285.349 2097868.4978]
# Invalid geometry at index 14867: Ring Self-intersection[1546091.1414 2167527.7003]
# Invalid geometry at index 14874: Ring Self-intersection[1728801.8163 2214752.2544]
# Invalid geometry at index 14875: Ring Self-intersection[1438008.2133 2208771.2253]
# Invalid geometry at index 14877: Ring Self-intersection[1405144.6741 2025813.1003]
# Invalid geometry at index 14884: Ring Self-intersection[1575018.7509 2200335.6227]
# Invalid geometry at index 14893: Ring Self-intersection[1671197.4269 2217580.7782]
# Invalid geometry at index 14898: Ring Self-intersection[1484759.453 2189360.1145]
# Invalid geometry at index 14899: Ring Self-intersection[1567053.2829 2019060.2169]
# Invalid geometry at index 14900: Ring Self-intersection[1501294.7115 2199482.8047]
# Invalid geometry at index 14902: Ring Self-intersection[1576021.366 2181858.7132]
# Invalid geometry at index 14903: Ring Self-intersection[1557778.4913 2230322.6257]
# Invalid geometry at index 14904: Ring Self-intersection[1536886.5514 2065572.9073]
# Invalid geometry at index 14917: Ring Self-intersection[1545089.9727 2132289.8402]
# Invalid geometry at index 14920: Ring Self-intersection[1466268.4389 2160906.1386]
# Invalid geometry at index 15153: Ring Self-intersection[1589415.2817 2230957.6274]
# Invalid geometry at index 15154: Ring Self-intersection[1614243.2966 2206851.2469]
# Invalid geometry at index 15157: Ring Self-intersection[1441324.8444 2192504.9217]
# Invalid geometry at index 15163: Ring Self-intersection[1478566.0183 2114259.6113]
# Invalid geometry at index 15166: Ring Self-intersection[1603022.9573 2239609.9762]
# Invalid geometry at index 15169: Ring Self-intersection[1327188.2925 2148243.4913]
# Invalid geometry at index 15174: Ring Self-intersection[1431474.3389 2174335.0737]
# Invalid geometry at index 15187: Ring Self-intersection[1634909.61 2211415.3917]
# Invalid geometry at index 15193: Ring Self-intersection[1366401.7977 2148500.17]
# Invalid geometry at index 15209: Ring Self-intersection[1428090.7086 2069382.1074]
# Invalid geometry at index 15210: Ring Self-intersection[1630750.038 2111825.5558]
# Invalid geometry at index 15216: Ring Self-intersection[1365570.1378 2197907.9897]
# Invalid geometry at index 15225: Ring Self-intersection[1337609.2647 2125984.286]
# Invalid geometry at index 15238: Ring Self-intersection[1459385.8573 2096130.7034]
# Invalid geometry at index 15240: Ring Self-intersection[1657281.0145 2121947.5813]
# Invalid geometry at index 15243: Ring Self-intersection[1527350.3646 2095978.5688]
# Invalid geometry at index 15259: Ring Self-intersection[1317779.5445 2147597.0097]
# Invalid geometry at index 15270: Ring Self-intersection[1678665.7389 2172953.4036]
# Invalid geometry at index 15272: Ring Self-intersection[1358079.976 2209593.1399]
# Invalid geometry at index 15287: Ring Self-intersection[1469620.1102 2104103.1623]
# Invalid geometry at index 15297: Ring Self-intersection[1697164.0131 2158890.9706]
# Invalid geometry at index 15306: Ring Self-intersection[1500216.3883 2114490.4796]
# Invalid geometry at index 15327: Ring Self-intersection[1457422.9474 2067694.9076]
# Invalid geometry at index 15340: Ring Self-intersection[1600416.1966 2093453.5337]
# Invalid geometry at index 15343: Ring Self-intersection[1283879.177 2176888.5359]
# Invalid geometry at index 15347: Ring Self-intersection[1316091.9269 2226266.7546]
# Invalid geometry at index 15350: Ring Self-intersection[1710684.3861 2201327.5485]
# Invalid geometry at index 15369: Ring Self-intersection[1599075.7409 2058674.2225]
# Invalid geometry at index 15376: Ring Self-intersection[1588533.5388 2041571.818]
# Invalid geometry at index 15391: Ring Self-intersection[1614472.0219 2120490.9932]
# Invalid geometry at index 15404: Ring Self-intersection[1309990.0113 2199755.037]
# Invalid geometry at index 15414: Ring Self-intersection[1375071.6559 2108849.0379]
# Invalid geometry at index 15427: Ring Self-intersection[1440296.5889 2240961.6715]
# Invalid geometry at index 15428: Ring Self-intersection[1305500.4265 1989127.1545]
# Invalid geometry at index 15440: Ring Self-intersection[1273202.6514 2211305.5843]
# Invalid geometry at index 15459: Ring Self-intersection[1512572.3944 2128914.9635]
# Writing to log file logs\PA_protected_lands_geo_clean_log_20250502_180954_395982.txt...
# CRS of data is EPSG:4326
# PA_protected_lands.parquet data cleaned and saved successfully!
# File PA_protected_lands.parquet processed and saved.
# Running the function because over-write status: True and file existence status: True...
# Loaded protected_lands data from layer: PADUS4_1Comb_DOD_Trib_NGP_Fee_Desig_Ease_State_GA with 7429 features
# State name is GA
# Invalid geometry at index 57: Ring Self-intersection[1154222.3047 1152718.6652]
# Invalid geometry at index 60: Ring Self-intersection[1317157.8452 935918.6541]
# Invalid geometry at index 61: Ring Self-intersection[1142062.7693 1189388.1343]
# Invalid geometry at index 69: Ring Self-intersection[1153705.0824 1152142.2997]
# Invalid geometry at index 72: Ring Self-intersection[1317157.3459 935919.4554]
# Invalid geometry at index 73: Ring Self-intersection[1138953.8253 1194791.8223]
# Invalid geometry at index 3384: Ring Self-intersection[1094768.8477 1362264.3828]
# Invalid geometry at index 3385: Ring Self-intersection[1021052.6257 1381388.6632]
# Invalid geometry at index 3386: Ring Self-intersection[1084530.0127 1363859.0286]
# Invalid geometry at index 3882: Ring Self-intersection[1067436.7181 1112127.4964]
# Invalid geometry at index 4082: Ring Self-intersection[1351371.9211 1047960.3203]
# Invalid geometry at index 4260: Ring Self-intersection[1021052.6592 1381388.4063]
# Invalid geometry at index 4337: Ring Self-intersection[1313908.0568 929612.9089]
# Invalid geometry at index 4341: Ring Self-intersection[1026809.6274 1061265.9384]
# Writing to log file logs\GA_protected_lands_geo_clean_log_20250502_181004_367961.txt...
# CRS of data is EPSG:4326
# GA_protected_lands.parquet data cleaned and saved successfully!
# File GA_protected_lands.parquet processed and saved.
# Running the function because over-write status: True and file existence status: True...
# Loaded protected_lands data from layer: PADUS4_1Comb_DOD_Trib_NGP_Fee_Desig_Ease_State_MO with 5778 features
# State name is MO
# Invalid geometry at index 2593: Ring Self-intersection[161413.725200001 1943064.6513]
# Invalid geometry at index 2844: Ring Self-intersection[181455.1175 1798757.8128]
# Invalid geometry at index 2903: Ring Self-intersection[358703.890099999 1835432.4863]
# Invalid geometry at index 2947: Ring Self-intersection[397186.818999998 1585382.2055]
# Invalid geometry at index 3088: Ring Self-intersection[529173.935899999 1583421.928]
# Invalid geometry at index 3093: Ring Self-intersection[304181.352600001 1766718.8457]
# Invalid geometry at index 3185: Ring Self-intersection[316603.5913 1929717.0309]
# Invalid geometry at index 3350: Ring Self-intersection[421313.636399999 1584728.3127]
# Invalid geometry at index 3407: Ring Self-intersection[385635.297600001 1592723.7268]
# Writing to log file logs\MO_protected_lands_geo_clean_log_20250502_181008_514618.txt...
# CRS of data is EPSG:4326
# MO_protected_lands.parquet data cleaned and saved successfully!
# File MO_protected_lands.parquet processed and saved.
# Running the function because over-write status: True and file existence status: True...
# Loaded protected_lands data from layer: PADUS4_1Comb_DOD_Trib_NGP_Fee_Desig_Ease_State_WI with 21614 features
# State name is WI
# Invalid geometry at index 31: Ring Self-intersection[374598.3334 2521678.8589]
# Invalid geometry at index 44: Ring Self-intersection[543828.1094 2234313.86]
# Invalid geometry at index 58: Ring Self-intersection[468168.963 2362032.1369]
# Invalid geometry at index 59: Ring Self-intersection[454078.428300001 2357565.3299]
# Invalid geometry at index 66: Ring Self-intersection[357957.772399999 2348644.9039]
# Invalid geometry at index 67: Ring Self-intersection[381261.388500001 2314859.0137]
# Invalid geometry at index 73: Ring Self-intersection[543827.523699999 2234314.6824]
# Invalid geometry at index 87: Ring Self-intersection[468168.345400002 2362032.9403]
# Invalid geometry at index 88: Ring Self-intersection[454077.8125 2357566.1322]
# Invalid geometry at index 97: Ring Self-intersection[357957.205600001 2348645.4764]
# Invalid geometry at index 98: Ring Self-intersection[381260.745700002 2314859.6957]
# Invalid geometry at index 186: Ring Self-intersection[427550.750300001 2585694.5065]
# Invalid geometry at index 188: Ring Self-intersection[388475.4879 2652667.9696]
# Invalid geometry at index 193: Ring Self-intersection[370444.055 2484184.129]
# Invalid geometry at index 194: Ring Self-intersection[404210.177700002 2429298.9116]
# Invalid geometry at index 204: Ring Self-intersection[298093.4122 2633191.1442]
# Invalid geometry at index 205: Ring Self-intersection[393212.124299999 2427676.0014]
# Invalid geometry at index 206: Ring Self-intersection[597692.219000001 2569542.7026]
# Invalid geometry at index 207: Ring Self-intersection[561157.6822 2531397.9352]
# Invalid geometry at index 209: Ring Self-intersection[430071.9542 2599377.2808]
# Invalid geometry at index 211: Ring Self-intersection[408999.249600001 2400572.2014]
# Invalid geometry at index 222: Ring Self-intersection[542786.890999999 2509377.1809]
# Invalid geometry at index 223: Ring Self-intersection[505403.6494 2514079.8469]
# Invalid geometry at index 236: Ring Self-intersection[632714.040800001 2547005.2798]
# Invalid geometry at index 240: Ring Self-intersection[609713.795499999 2490061.6542]
# Invalid geometry at index 241: Ring Self-intersection[500760.343499999 2540022.9686]
# Invalid geometry at index 250: Ring Self-intersection[246687.4749 2519000.6829]
# Invalid geometry at index 251: Ring Self-intersection[439478.3792 2544167.5854]
# Invalid geometry at index 255: Ring Self-intersection[400939.944899999 2516808.9037]
# Invalid geometry at index 257: Ring Self-intersection[387409.144299999 2528459.6468]
# Invalid geometry at index 266: Ring Self-intersection[521499.9747 2577810.4568]
# Invalid geometry at index 267: Ring Self-intersection[341821.574200001 2571465.7618]
# Invalid geometry at index 335: Ring Self-intersection[352920.3354 2568633.9579]
# Invalid geometry at index 338: Ring Self-intersection[585794.5803 2552504.2137]
# Invalid geometry at index 398: Ring Self-intersection[586769.077500001 2562303.843]
# Invalid geometry at index 401: Ring Self-intersection[586894.267000001 2345809.5473]
# Invalid geometry at index 469: Ring Self-intersection[481620.478300001 2543205.9269]
# Invalid geometry at index 578: Ring Self-intersection[566516.831700001 2385904.3123]
# Invalid geometry at index 594: Ring Self-intersection[454974.707600001 2432489.9513]
# Invalid geometry at index 598: Ring Self-intersection[392334.085200001 2655691.2809]
# Invalid geometry at index 599: Ring Self-intersection[384028.491300002 2283349.4011]
# Invalid geometry at index 600: Ring Self-intersection[281023.844300002 2478290.1628]
# Invalid geometry at index 761: Ring Self-intersection[325076.0167 2444396.5392]
# Invalid geometry at index 4465: Nested shells[649125.522500001 2236820.378]
# Invalid geometry at index 4635: Nested shells[652722.847800002 2249208.822]
# Invalid geometry at index 5054: Ring Self-intersection[701183.610599998 2489230.5193]
# Invalid geometry at index 5055: Ring Self-intersection[366565.909400001 2661246.3476]
# Invalid geometry at index 5064: Ring Self-intersection[376152.711300001 2612494.3589]
# Invalid geometry at index 5065: Ring Self-intersection[714562.763599999 2521702.3068]
# Invalid geometry at index 5074: Ring Self-intersection[667126.014800001 2201875.7748]
# Invalid geometry at index 5117: Ring Self-intersection[372213.924800001 2660556.023]
# Invalid geometry at index 5119: Ring Self-intersection[328623.368299998 2421436.5135]
# Invalid geometry at index 5121: Ring Self-intersection[612660.823199999 2229866.6551]
# Invalid geometry at index 5155: Ring Self-intersection[492745.103300001 2334885.1545]
# Invalid geometry at index 5174: Ring Self-intersection[612926.897599999 2565075.4492]
# Invalid geometry at index 5197: Ring Self-intersection[373984.670699999 2560335.8735]
# Invalid geometry at index 5199: Ring Self-intersection[501711.7971 2265999.5273]
# Invalid geometry at index 5201: Ring Self-intersection[625049.388999999 2527345.0305]
# Invalid geometry at index 5202: Ring Self-intersection[317438.4877 2581208.3353]
# Invalid geometry at index 5203: Ring Self-intersection[459088.9419 2577181.2077]
# Invalid geometry at index 5204: Ring Self-intersection[478533.7542 2540186.538]
# Invalid geometry at index 5206: Nested shells[679862.585000001 2454585.9621]
# Invalid geometry at index 5211: Ring Self-intersection[487220.210900001 2557116.3431]
# Invalid geometry at index 5217: Ring Self-intersection[497461.629099999 2242734.416]
# Invalid geometry at index 5226: Ring Self-intersection[359377.802099999 2479680.8846]
# Invalid geometry at index 5227: Ring Self-intersection[334758.1204 2425234.2346]
# Invalid geometry at index 5232: Ring Self-intersection[412386.9164 2607243.4306]
# Invalid geometry at index 5243: Ring Self-intersection[584764.752700001 2249709.5096]
# Invalid geometry at index 5254: Ring Self-intersection[614101.064100001 2377019.7774]
# Invalid geometry at index 5258: Ring Self-intersection[523261.143300001 2365701.2659]
# Invalid geometry at index 5262: Ring Self-intersection[523131.1545 2457284.7292]
# Invalid geometry at index 5263: Ring Self-intersection[262862.161699999 2494179.5569]
# Invalid geometry at index 5267: Ring Self-intersection[391732.181299999 2332156.429]
# Invalid geometry at index 5273: Ring Self-intersection[634090.025600001 2553486.3211]
# Invalid geometry at index 5275: Ring Self-intersection[490391.929299999 2239793.1792]
# Invalid geometry at index 5278: Ring Self-intersection[495545.619800001 2301889.122]
# Invalid geometry at index 5279: Ring Self-intersection[457776.156300001 2207432.7674]
# Invalid geometry at index 5280: Ring Self-intersection[534928.943799999 2451637.1055]
# Invalid geometry at index 5297: Ring Self-intersection[595133.119199999 2567164.979]
# Invalid geometry at index 5321: Ring Self-intersection[331978.5099 2512957.5702]
# Invalid geometry at index 5323: Ring Self-intersection[258111.217799999 2450616.4074]
# Invalid geometry at index 5324: Ring Self-intersection[539347.6842 2445036.5543]
# Invalid geometry at index 5342: Ring Self-intersection[546915.196600001 2187410.6183]
# Invalid geometry at index 5385: Ring Self-intersection[528009.3127 2225545.0244]
# Invalid geometry at index 5400: Ring Self-intersection[511079.888099998 2388180.9979]
# Invalid geometry at index 5415: Ring Self-intersection[640635.572000001 2372021.374]
# Invalid geometry at index 5416: Ring Self-intersection[614413.306400001 2203720.7201]
# Invalid geometry at index 5427: Ring Self-intersection[287131.2984 2469625.5739]
# Invalid geometry at index 5459: Ring Self-intersection[564603.678199999 2486179.2068]
# Invalid geometry at index 5464: Ring Self-intersection[316736.700599998 2409496.7684]
# Invalid geometry at index 5505: Ring Self-intersection[637795.971000001 2286324.659]
# Invalid geometry at index 5513: Ring Self-intersection[416768.195999999 2264645.0152]
# Invalid geometry at index 5553: Ring Self-intersection[521127.421500001 2272809.9854]
# Invalid geometry at index 5574: Ring Self-intersection[454709.785300002 2430877.6221]
# Invalid geometry at index 5575: Ring Self-intersection[480986.3281 2426027.1334]
# Invalid geometry at index 5577: Ring Self-intersection[529151.652899999 2356074.4814]
# Invalid geometry at index 5589: Ring Self-intersection[334262.584199999 2437247.0852]
# Invalid geometry at index 5597: Ring Self-intersection[590400.530499998 2433482.5965]
# Invalid geometry at index 5603: Ring Self-intersection[474425.432700001 2497240.0853]
# Invalid geometry at index 5624: Ring Self-intersection[588972.572700001 2411858.0938]
# Invalid geometry at index 5629: Ring Self-intersection[281420.045899998 2478306.0539]
# Invalid geometry at index 5636: Ring Self-intersection[408350.6851 2483810.9871]
# Invalid geometry at index 5639: Ring Self-intersection[542165.4866 2301516.4879]
# Invalid geometry at index 5655: Ring Self-intersection[562617.339499999 2368566.9956]
# Invalid geometry at index 5657: Ring Self-intersection[506211.855900001 2495613.938]
# Invalid geometry at index 5661: Ring Self-intersection[544302.625599999 2387025.0973]
# Invalid geometry at index 5662: Ring Self-intersection[583969.953499999 2383086.4765]
# Invalid geometry at index 5768: Ring Self-intersection[466817.407600001 2383789.2603]
# Invalid geometry at index 5806: Ring Self-intersection[352316.898400001 2652112.9452]
# Invalid geometry at index 5808: Ring Self-intersection[391953.530900002 2655278.1166]
# Invalid geometry at index 5818: Ring Self-intersection[257340.5715 2466689.445]
# Invalid geometry at index 5826: Ring Self-intersection[295083.6708 2401096.8693]
# Invalid geometry at index 5843: Ring Self-intersection[383992.401000001 2283282.5783]
# Invalid geometry at index 5861: Ring Self-intersection[608266.5515 2308866.3469]
# Invalid geometry at index 5865: Ring Self-intersection[313024.773200002 2393635.3691]
# Invalid geometry at index 5894: Ring Self-intersection[558554.2377 2502796.842]
# Invalid geometry at index 5895: Ring Self-intersection[374478.1395 2345839.2436]
# Invalid geometry at index 5896: Ring Self-intersection[626049.41 2241559.7398]
# Invalid geometry at index 5904: Ring Self-intersection[368663.761100002 2533578.1894]
# Invalid geometry at index 5907: Ring Self-intersection[369141.507300001 2614181.1725]
# Invalid geometry at index 5909: Ring Self-intersection[530970.809900001 2361669.0571]
# Invalid geometry at index 5910: Ring Self-intersection[554320.215799998 2350149.0516]
# Invalid geometry at index 5915: Ring Self-intersection[537476.584399998 2371983.6553]
# Invalid geometry at index 5916: Ring Self-intersection[462888.369399998 2279180.832]
# Invalid geometry at index 5917: Ring Self-intersection[267630.490899999 2454474.6909]
# Invalid geometry at index 5934: Ring Self-intersection[487971.8094 2213023.8701]
# Invalid geometry at index 5937: Ring Self-intersection[517213.1787 2562116.5614]
# Invalid geometry at index 5939: Ring Self-intersection[417632.829100002 2389656.0854]
# Invalid geometry at index 5940: Ring Self-intersection[337013.7467 2647264.0264]
# Invalid geometry at index 5944: Ring Self-intersection[429465.675500002 2250855.0882]
# Invalid geometry at index 5945: Ring Self-intersection[413767.018599998 2548287.769]
# Invalid geometry at index 5947: Nested shells[614142.082199998 2502960.1148]
# Invalid geometry at index 5948: Ring Self-intersection[252453.4564 2515091.653]
# Invalid geometry at index 5959: Ring Self-intersection[625430.750500001 2314276.9193]
# Invalid geometry at index 5961: Ring Self-intersection[602004.921700001 2227891.5522]
# Invalid geometry at index 5962: Ring Self-intersection[469917.5473 2595217.8413]
# Invalid geometry at index 5965: Ring Self-intersection[673867.928599998 2388240.1741]
# Invalid geometry at index 6100: Ring Self-intersection[290115.0449 2563180.3922]
# Writing to log file logs\WI_protected_lands_geo_clean_log_20250502_181021_788742.txt...
# CRS of data is EPSG:4326
# WI_protected_lands.parquet data cleaned and saved successfully!
# File WI_protected_lands.parquet processed and saved.
# Running the function because over-write status: True and file existence status: True...
# Loaded protected_lands data from layer: PADUS4_1Comb_DOD_Trib_NGP_Fee_Desig_Ease_State_NM with 2352 features
# State name is NM
# Invalid geometry at index 52: Ring Self-intersection[-1007045.929 1128408.4072]
# Invalid geometry at index 58: Ring Self-intersection[-831641.9498 1154828.7918]
# Invalid geometry at index 59: Ring Self-intersection[-1073451.1637 1616311.3705]
# Invalid geometry at index 61: Ring Self-intersection[-1043235.081 1209131.4346]
# Invalid geometry at index 63: Ring Self-intersection[-1014487.1826 1457199.1338]
# Invalid geometry at index 64: Ring Self-intersection[-833846.251700001 1269530.8652]
# Invalid geometry at index 65: Ring Self-intersection[-1175582.0428 1342808.1845]
# Invalid geometry at index 66: Ring Self-intersection[-879930.3992 1505912.8829]
# Invalid geometry at index 95: Ring Self-intersection[-1093138.5853 1396041.9464]
# Invalid geometry at index 108: Ring Self-intersection[-820823.8356 1424883.9364]
# Invalid geometry at index 109: Ring Self-intersection[-760579.0625 1538992.3615]
# Invalid geometry at index 120: Ring Self-intersection[-761883.9102 1536638.8876]
# Invalid geometry at index 242: Self-intersection[-969252.247280607 1393231.83036464]
# Invalid geometry at index 246: Self-intersection[-955994.893906826 1397218.35989969]
# Invalid geometry at index 259: Self-intersection[-962105.402098314 1406142.44259949]
# Invalid geometry at index 279: Self-intersection[-944457.336247292 1399729.37725234]
# Invalid geometry at index 290: Self-intersection[-965470.111578386 1393458.15575956]
# Invalid geometry at index 297: Self-intersection[-950504.265155835 1400428.27031972]
# Invalid geometry at index 311: Nested shells[-957167.429 1393290.5614]
# Invalid geometry at index 315: Self-intersection[-956702.136578747 1397239.52361447]
# Invalid geometry at index 320: Self-intersection[-949310.154920158 1391219.99764806]
# Invalid geometry at index 324: Self-intersection[-966605.420882096 1402606.55082177]
# Invalid geometry at index 329: Self-intersection[-967181.072436125 1404219.40705137]
# Invalid geometry at index 352: Self-intersection[-967094.558345939 1399416.33846039]
# Invalid geometry at index 902: Ring Self-intersection[-773891.209000001 1123330.8213]
# Invalid geometry at index 984: Self-intersection[-750483.4932 1461727.2934]
# Invalid geometry at index 1407: Ring Self-intersection[-1003656.3133 1602042.7215]
# Invalid geometry at index 1410: Ring Self-intersection[-1162963.9473 1026541.0922]
# Invalid geometry at index 1417: Ring Self-intersection[-1218157.0139 1050373.8958]
# Invalid geometry at index 1434: Ring Self-intersection[-1086046.2458 1066702.6391]
# Invalid geometry at index 1450: Ring Self-intersection[-1024351.6191 1321272.449]
# Invalid geometry at index 1478: Ring Self-intersection[-1017810.7292 1098264.5584]
# Invalid geometry at index 1491: Ring Self-intersection[-885344.3254 1593106.7491]
# Invalid geometry at index 1503: Ring Self-intersection[-1069986.2921 1378656.4871]
# Invalid geometry at index 1506: Ring Self-intersection[-1020208.2572 1105085.0745]
# Invalid geometry at index 1646: Ring Self-intersection[-840985.735400001 1040288.0922]
# Invalid geometry at index 1649: Ring Self-intersection[-916516.288699999 1223899.9683]
# Invalid geometry at index 1654: Ring Self-intersection[-1089837.7867 1117757.2296]
# Invalid geometry at index 1661: Ring Self-intersection[-1096259.6412 1389040.7779]
# Invalid geometry at index 1664: Ring Self-intersection[-1195536.3133 1143226.7229]
# Invalid geometry at index 1670: Ring Self-intersection[-994952.6161 1212988.8072]
# Invalid geometry at index 1671: Ring Self-intersection[-1004594.8939 1459268.6467]
# Invalid geometry at index 1681: Ring Self-intersection[-1045055.6613 1364010.9407]
# Invalid geometry at index 1686: Ring Self-intersection[-967080.478599999 1288165.2326]
# Invalid geometry at index 1749: Ring Self-intersection[-1041973.7245 1042619.0002]
# Invalid geometry at index 1752: Ring Self-intersection[-764680.827299999 1433695.1198]
# Invalid geometry at index 1791: Ring Self-intersection[-853113.7443 1558297.6041]
# Writing to log file logs\NM_protected_lands_geo_clean_log_20250502_181037_862846.txt...
# CRS of data is EPSG:4326
# NM_protected_lands.parquet data cleaned and saved successfully!
# File NM_protected_lands.parquet processed and saved.
# Running the function because over-write status: True and file existence status: True...
# Loaded protected_lands data from layer: PADUS4_1Comb_DOD_Trib_NGP_Fee_Desig_Ease_State_IL with 14768 features
# State name is IL
# Invalid geometry at index 33: Ring Self-intersection[504117.440900002 1943900.8434]
# Invalid geometry at index 34: Ring Self-intersection[601983.217799999 1646054.3912]
# Invalid geometry at index 35: Ring Self-intersection[610019.896699999 1609011.8706]
# Invalid geometry at index 45: Ring Self-intersection[477171.558899999 2140741.2167]
# Invalid geometry at index 48: Ring Self-intersection[601982.590500001 1646055.4778]
# Invalid geometry at index 49: Ring Self-intersection[610019.271200001 1609012.8853]
# Invalid geometry at index 59: Ring Self-intersection[477170.947900001 2140742.0926]
# Invalid geometry at index 215: Ring Self-intersection[593208.094500002 1889232.8336]
# Invalid geometry at index 2250: Ring Self-intersection[664732.4395 2092183.0244]
# Invalid geometry at index 2665: Ring Self-intersection[520268.774500001 1947713.2887]
# Invalid geometry at index 2743: Ring Self-intersection[502583.2896 1904688.3918]
# Invalid geometry at index 2744: Ring Self-intersection[527261.045899998 1691878.058]
# Invalid geometry at index 2761: Ring Self-intersection[477032.320700001 1909875.4684]
# Invalid geometry at index 2895: Nested shells[587168.7513 2056450.1605]
# Invalid geometry at index 3343: Ring Self-intersection[614976.649 2187031.1404]
# Invalid geometry at index 10585: Ring Self-intersection[649318.111200001 2192688.9287]
# Invalid geometry at index 10643: Ring Self-intersection[686964.4947 2096519.2381]
# Invalid geometry at index 10647: Ring Self-intersection[685168.1098 2098194.8684]
# Invalid geometry at index 10753: Ring Self-intersection[606347.780900002 1639811.1122]
# Invalid geometry at index 10997: Ring Self-intersection[629757.053599998 2145429.8823]
# Writing to log file logs\IL_protected_lands_geo_clean_log_20250502_181046_008902.txt...
# CRS of data is EPSG:4326
# IL_protected_lands.parquet data cleaned and saved successfully!
# File IL_protected_lands.parquet processed and saved.
# Running the function because over-write status: True and file existence status: True...
# Loaded protected_lands data from layer: PADUS4_1Comb_DOD_Trib_NGP_Fee_Desig_Ease_State_WA with 11584 features
# State name is WA
# Invalid geometry at index 71: Ring Self-intersection[-1573508.7991 3052054.7907]
# Invalid geometry at index 72: Ring Self-intersection[-1740231.1093 3101503.4518]
# Invalid geometry at index 73: Ring Self-intersection[-1644716.3681 2742449.3009]
# Invalid geometry at index 118: Ring Self-intersection[-2084372.8977 3029165.6653]
# Invalid geometry at index 123: Ring Self-intersection[-2010488.1775 2962785.7764]
# Invalid geometry at index 125: Ring Self-intersection[-1794038.3198 2873328.027]
# Invalid geometry at index 137: Ring Self-intersection[-1597340.5361 3011653.0055]
# Invalid geometry at index 141: Ring Self-intersection[-1754619.9246 2776656.3032]
# Invalid geometry at index 156: Ring Self-intersection[-1860225.5836 2830545.8149]
# Invalid geometry at index 158: Ring Self-intersection[-1622815.7354 2896528.8905]
# Invalid geometry at index 164: Ring Self-intersection[-2010489.3634 2962786.6403]
# Invalid geometry at index 167: Ring Self-intersection[-1770968.6077 2865469.6311]
# Invalid geometry at index 182: Ring Self-intersection[-1597341.3656 3011653.9781]
# Invalid geometry at index 186: Ring Self-intersection[-1754620.6273 2776657.3453]
# Invalid geometry at index 195: Ring Self-intersection[-1990646.3075 3135522.3394]
# Invalid geometry at index 201: Ring Self-intersection[-1860226.1674 2830546.9397]
# Invalid geometry at index 203: Ring Self-intersection[-1622214.9352 2895582.0222]
# Invalid geometry at index 205: Ring Self-intersection[-2129061.8395 2911838.4103]
# Invalid geometry at index 328: Ring Self-intersection[-1719815.2348 3001820.8549]
# Invalid geometry at index 1053: Nested shells[-1944445.1113 3128219.2503]
# Invalid geometry at index 4227: Ring Self-intersection[-1986403.9456 2924437.0947]
# Invalid geometry at index 4309: Ring Self-intersection[-1772549.1849 3002640.0218]
# Invalid geometry at index 4319: Ring Self-intersection[-1888065.769 2875756.8879]
# Invalid geometry at index 4323: Ring Self-intersection[-1937646.9606 3100104.6606]
# Invalid geometry at index 4324: Ring Self-intersection[-1781939.1851 2888203.5616]
# Invalid geometry at index 4370: Ring Self-intersection[-1779040.5247 2871451.7559]
# Invalid geometry at index 4387: Ring Self-intersection[-1779988.732 3011184.7379]
# Invalid geometry at index 4393: Ring Self-intersection[-1833886.0407 2908695.6766]
# Invalid geometry at index 4394: Ring Self-intersection[-1808239.5278 2916396.8426]
# Invalid geometry at index 4407: Ring Self-intersection[-1887089.93 2793819.9346]
# Invalid geometry at index 4909: Ring Self-intersection[-2101371.0702 2983618.7134]
# Invalid geometry at index 5059: Ring Self-intersection[-1998422.5371 3008434.3654]
# Invalid geometry at index 5750: Nested shells[-1955320.5013 2984494.2152]
# Invalid geometry at index 6058: Ring Self-intersection[-1931770.8931 3122322.245]
# Invalid geometry at index 6166: Ring Self-intersection[-1947203.3144 2782916.6057]
# Invalid geometry at index 6199: Ring Self-intersection[-1791351.9488 2930516.5755]
# Invalid geometry at index 6203: Ring Self-intersection[-2110401.2655 3049430.0526]
# Invalid geometry at index 6204: Ring Self-intersection[-2103877.9828 3053799.2809]
# Invalid geometry at index 6212: Ring Self-intersection[-2123219.7658 2914095.8541]
# Invalid geometry at index 6232: Ring Self-intersection[-2099019.6832 3070710.3809]
# Invalid geometry at index 6239: Ring Self-intersection[-1884537.8886 3086666.342]
# Invalid geometry at index 6240: Ring Self-intersection[-1779944.1827 2949253.7116]
# Invalid geometry at index 6243: Ring Self-intersection[-1773433.0084 2961145.3201]
# Invalid geometry at index 6304: Ring Self-intersection[-2114202.2109 2970411.1662]
# Invalid geometry at index 6321: Ring Self-intersection[-1844397.381 2959208.7333]
# Invalid geometry at index 6325: Nested shells[-2088193.2959 2969902.6669]
# Invalid geometry at index 6383: Ring Self-intersection[-1919871.2431 2978208.2255]
# Invalid geometry at index 6384: Ring Self-intersection[-1896705.1662 3035258.0495]
# Invalid geometry at index 6391: Ring Self-intersection[-2010294.4822 3019835.6507]
# Invalid geometry at index 6399: Ring Self-intersection[-1908302.345 3100513.712]
# Invalid geometry at index 6400: Ring Self-intersection[-2107491.9455 3101748.0414]
# Invalid geometry at index 6403: Ring Self-intersection[-1812223.7182 2920697.6865]
# Invalid geometry at index 6404: Ring Self-intersection[-1806165.7567 2878816.9353]
# Invalid geometry at index 6406: Ring Self-intersection[-1924397.7634 2801545.3312]
# Invalid geometry at index 6407: Ring Self-intersection[-1873338.0709 2918209.21]
# Invalid geometry at index 6408: Ring Self-intersection[-1790107.9535 3051366.4573]
# Invalid geometry at index 6409: Ring Self-intersection[-2045686.7096 2828097.1972]
# Invalid geometry at index 6410: Ring Self-intersection[-1880804.47 2887248.8374]
# Invalid geometry at index 6411: Ring Self-intersection[-2007043.4586 2973327.6064]
# Invalid geometry at index 6412: Ring Self-intersection[-1748247.1995 3056970.9]
# Invalid geometry at index 6417: Ring Self-intersection[-1779989.3965 3011185.7272]
# Invalid geometry at index 6418: Ring Self-intersection[-1866155.1611 2891636.7008]
# Invalid geometry at index 6420: Ring Self-intersection[-2120689.4512 2952050.7333]
# Invalid geometry at index 6495: Ring Self-intersection[-1905718.0684 2967059.5954]
# Invalid geometry at index 6550: Ring Self-intersection[-1612412.868 2930046.8376]
# Invalid geometry at index 6608: Ring Self-intersection[-1647791.8181 2886696.1798]
# Invalid geometry at index 6622: Ring Self-intersection[-1644716.3681 2742449.3009]
# Invalid geometry at index 6636: Ring Self-intersection[-1746240.0577 2812324.9188]
# Invalid geometry at index 7013: Ring Self-intersection[-2118097.7946 3073298.6408]
# Invalid geometry at index 7014: Ring Self-intersection[-1947612.3362 2913973.8846]
# Invalid geometry at index 7101: Ring Self-intersection[-1796120.3645 2833483.8784]
# Invalid geometry at index 7108: Ring Self-intersection[-1796120.3645 2833483.8784]
# Invalid geometry at index 7141: Ring Self-intersection[-1854253.6647 2893368.2514]
# Invalid geometry at index 7227: Ring Self-intersection[-1957045.1608 2984585.3658]
# Writing to log file logs\WA_protected_lands_geo_clean_log_20250502_181107_926145.txt...
# CRS of data is EPSG:4326
# WA_protected_lands.parquet data cleaned and saved successfully!
# File WA_protected_lands.parquet processed and saved.
# Running the function because over-write status: True and file existence status: True...
# Loaded protected_lands data from layer: PADUS4_1Comb_DOD_Trib_NGP_Fee_Desig_Ease_State_TX with 24831 features
# State name is TX
# Invalid geometry at index 102: Ring Self-intersection[-76969.4475999996 574278.2483]
# Invalid geometry at index 107: Ring Self-intersection[-554023.1909 1331623.3985]
# Invalid geometry at index 113: Ring Self-intersection[-140567.3313 372370.0119]
# Invalid geometry at index 114: Ring Self-intersection[-192889.295499999 387644.7505]
# Invalid geometry at index 117: Ring Self-intersection[-615747.0572 1235352.9023]
# Invalid geometry at index 120: Ring Self-intersection[49753.1895999983 642667.9713]
# Invalid geometry at index 126: Ring Self-intersection[115270.608600002 792110.4915]
# Invalid geometry at index 129: Ring Self-intersection[149304.1833 724978.7788]
# Invalid geometry at index 134: Ring Self-intersection[71478.0522000007 656992.8813]
# Invalid geometry at index 141: Ring Self-intersection[-137433.555199999 354454.4367]
# Invalid geometry at index 142: Ring Self-intersection[-192546.1435 387584.1904]
# Invalid geometry at index 143: Ring Self-intersection[181522.102400001 744489.0683]
# Invalid geometry at index 146: Ring Self-intersection[54637.3170999996 973489.8122]
# Invalid geometry at index 148: Ring Self-intersection[44483.5417000018 678874.4952]
# Invalid geometry at index 153: Ring Self-intersection[112275.5876 784778.1818]
# Invalid geometry at index 4227: Ring Self-intersection[-333469.044 717598.8279]
# Invalid geometry at index 4334: Ring Self-intersection[123962.773899999 892130.6182]
# Invalid geometry at index 4564: Ring Self-intersection[-657538.3796 906577.5036]
# Invalid geometry at index 4781: Self-intersection[21587.3805550501 1016292.73218314]
# Invalid geometry at index 4885: Ring Self-intersection[-66694.1037999988 1113729.142]
# Invalid geometry at index 5972: Ring Self-intersection[-68916.3123999983 1070346.8392]
# Invalid geometry at index 10085: Ring Self-intersection[110634.261300001 691475.0803]
# Invalid geometry at index 10134: Ring Self-intersection[-661675.2524 962701.2317]
# Invalid geometry at index 10138: Ring Self-intersection[-675134.055400001 737471.5374]
# Invalid geometry at index 10194: Ring Self-intersection[194479.193599999 905813.7024]
# Invalid geometry at index 11456: Ring Self-intersection[-252077.225400001 727670.1004]
# Invalid geometry at index 11457: Nested shells[-234791.123 716850.4815]
# Invalid geometry at index 11470: Nested shells[-241023.157299999 692993.716]
# Invalid geometry at index 11794: Ring Self-intersection[-152926.694499999 363323.8039]
# Invalid geometry at index 11812: Ring Self-intersection[208206.210000001 770071.9119]
# Invalid geometry at index 11867: Ring Self-intersection[-166286.463500001 792201.7011]
# Writing to log file logs\TX_protected_lands_geo_clean_log_20250502_181121_472073.txt...
# CRS of data is EPSG:4326
# TX_protected_lands.parquet data cleaned and saved successfully!
# File TX_protected_lands.parquet processed and saved.

# %% [markdown]
# #### 1.2 Uploading cleaned encumbrance parquets to GCS

# %%
# Function to upload locally saved parquet to GCS
def upload_parquet_to_gcs(
        bucket_name,
        bucket_folder,
        dataset,
        local_ingestion_path = PARQUET_INGESTION_PATH,
        state=None):
    """
    Uploads a local Parquet file to a GCS bucket using config structure.

    Args:
        bucket_name (str): Target GCS bucket.
        dataset (str): One of the encumbrances in EncumbranceType
        local_file_path (str): Local parquet file path.
        state (str, optional): State name for datasets that include it.
    """
    gcs_folder = f'{bucket_folder}/{dataset}'
    filename = f"{state}_{dataset}.parquet" if state else f"{dataset}.parquet"
    local_file_path = os.path.join(local_ingestion_path, filename)
    if not os.path.exists(local_file_path):
        raise FileNotFoundError(f"File {local_file_path} does not exist.")
    destination_blob_path = f"{gcs_folder}/{filename}"

    # GCS client upload
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(destination_blob_path)
    blob.upload_from_filename(local_file_path)

    print(f"Uploaded {filename} to gs://{bucket_name}/{destination_blob_path}")

# %%
# Loop over states and encumbrances to upload to GCS
# List of states and datasets
states = [
    'PA',
    'GA',
    'MO',
    'WI',
    'NM',
    'IL',
    'WA', 
    'TX'
    ]
datasets = [
    #'wetlands',
    'protected_lands'] # To re-run all, replace this with ENCUMBRANCES

for dataset in datasets:
    if dataset in [
        #'wetlands', 
        'protected_lands']:
        for state in states:
            try:
                upload_parquet_to_gcs(
                    bucket_name=BUCKET,
                    bucket_folder=BUCKET_FOLDER, 
                    dataset=dataset, 
                    local_ingestion_path=PARQUET_INGESTION_PATH, 
                    state=state
                )
            except Exception as e:
                print(f"Failed to upload {dataset} for {state}: {e}")
    else:
        try:
            upload_parquet_to_gcs(
                bucket_name=BUCKET,
                bucket_folder=BUCKET_FOLDER,
                dataset=dataset, 
                local_ingestion_path=PARQUET_INGESTION_PATH
                # No state needed
            )
        except Exception as e:
            print(f"Failed to upload {dataset}: {e}")
# Out:
# Uploaded PA_protected_lands.parquet to gs://geospatial-projects/infra_parcels/protected_lands/PA_protected_lands.parquet
# Uploaded GA_protected_lands.parquet to gs://geospatial-projects/infra_parcels/protected_lands/GA_protected_lands.parquet
# Uploaded MO_protected_lands.parquet to gs://geospatial-projects/infra_parcels/protected_lands/MO_protected_lands.parquet
# Uploaded WI_protected_lands.parquet to gs://geospatial-projects/infra_parcels/protected_lands/WI_protected_lands.parquet
# Uploaded NM_protected_lands.parquet to gs://geospatial-projects/infra_parcels/protected_lands/NM_protected_lands.parquet
# Uploaded IL_protected_lands.parquet to gs://geospatial-projects/infra_parcels/protected_lands/IL_protected_lands.parquet
# Uploaded WA_protected_lands.parquet to gs://geospatial-projects/infra_parcels/protected_lands/WA_protected_lands.parquet
# Uploaded TX_protected_lands.parquet to gs://geospatial-projects/infra_parcels/protected_lands/TX_protected_lands.parquet

# %% [markdown]
# #### 2. Convert county boundaries to geographic projection and upload to BQ

# %%
# Upload local parquet file to GCS bucket
# First, define constants
GIS_PROJECT = 'clgx-gis-app-dev-06e3'
POC_DATASET = 'encumbered_parcels'
CREDENTIALS_PATH =  r"C:\Users\eprashar\AppData\Roaming\gcloud\application_default_credentials.json"
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = str(CREDENTIALS_PATH)

# Verify credentials
utils.check_and_authenticate(CREDENTIALS_PATH)
# Out:
# Credentials file is valid.

# %%
# Upload county data in GCS bucket after converting CRS to EPSG:4326
def convert_upload_parquet_to_gcs_and_bigquery(
    source_folder,
    output_name,
    bucket_name,
    gcs_blob,
    project_id,
    dataset_id,
    table_name
):
    """
    Converts a Parquet file with EPSG:4269 geometries to EPSG:4326,
    uploads it to GCS, then loads it into BigQuery.

    Args:
    """
    # Load and convert CRS
    input_path = os.path.join(LOCAL_DATA_FOLDER, source_folder)
    gdf = gpd.read_file(input_path)
    print(f"Loaded {len(gdf)} features from {input_path}")

    if gdf.crs is None or gdf.crs.to_epsg() != geo_crs:
        gdf = gdf.to_crs(geo_crs)
        print("CRS converted to EPSG:4326")
    else:
        print("CRS already in EPSG:4326")

    # Save converted file locally
    output_path = os.path.join(PARQUET_INGESTION_PATH, f'{output_name}')
    gdf.to_parquet(output_path)
    print(f"Saved converted file to {output_path}")

    # Upload to GCS
    gcs_blob_path = f'{gcs_blob}/{output_name}'
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(gcs_blob_path)
    blob.upload_from_filename(output_path)
    print(f"Uploaded to GCS: gs://{bucket_name}/{gcs_blob_path}")

    # Load into BigQuery
    client = bigquery.Client()
    table_id = f"{project_id}.{dataset_id}.{table_name}"

    job_config = bigquery.LoadJobConfig(
        source_format=bigquery.SourceFormat.PARQUET,
        autodetect=True,
        write_disposition=bigquery.WriteDisposition.WRITE_TRUNCATE
    )

    uri = f"gs://{bucket_name}/{gcs_blob_path}"
    load_job = client.load_table_from_uri(uri, table_id, job_config=job_config)
    load_job.result()  # Wait for job to complete

    print(f"Loaded data into BigQuery table: {table_id}")

# %%
# Executing the county data upload
convert_upload_parquet_to_gcs_and_bigquery(
    source_folder=COUNTY_DATA,
    output_name='county_bounds.parquet',
    bucket_name=BUCKET,
    gcs_blob= f'{BUCKET_FOLDER}/county_bounds',
    project_id=GIS_PROJECT,
    dataset_id=POC_DATASET,
    table_name="county_boundaries"
)
# Out:
# Loaded 3235 features from C:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\jan_25_proj_infra_parcels\data\counties\tl_2024_us_county\tl_2024_us_county.shp
# CRS converted to EPSG:4326
# Saved converted file to C:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\jan_25_proj_infra_parcels\data\ingestion_parquets\county_bounds.parquet
# Uploaded to GCS: gs://geospatial-projects/infra_parcels/county_bounds/county_bounds.parquet
# Loaded data into BigQuery table: clgx-gis-app-dev-06e3.encumbered_parcels.county_boundaries

# %% [markdown]
# #### 3.1 [Relevant for local development in python]: Get county-level encumbrance parquet files

# %%
# Function to load county boundary
def get_county_boundary(fips_code):
    """
    Load county boundary from shapefile and filter by FIPS code.
    """
    # Read the shapefile
    gdf_county = gpd.read_file(os.path.join(LOCAL_DATA_FOLDER, COUNTY_DATA))
    
    # Filter by FIPS code
    gdf_county = gdf_county[gdf_county['GEOID'] == fips_code]
    
    # Convert to EPSG:4326
    gdf_county = gdf_county.to_crs(geo_crs)
    
    return gdf_county

# %%
# Filter encumbrance data for county
def filter_gdf_using_boundary(gdf_encumbrance, county_boundary):
    """
    Load wetland attributes from a geodatabase and join them to the wetlands GeoDataFrame
    using the 'ATTRIBUTE' field as a key.

    Parameters:

    Returns:
        GeoDataFrame: 
    """

    # Convert both dataframes to the same projection system
    gdf_encumbrance = gdf_encumbrance.to_crs(county_boundary.crs)

    # Perform a spatial join
    filtered_encumbrance = gpd.sjoin(gdf_encumbrance, county_boundary, predicate='within')

    # Drop unnecessary columns from county database
    filtered_encumbrance.drop(columns=[
        'index_right',
        'STATEFP',
        'COUNTYFP',
        'COUNTYNS',
        'GEOID',
        'GEOIDFQ',
        'LSAD',
        'CLASSFP',
        'MTFCC',
        'CSAFP',
        'CBSAFP',
        'METDIVFP',
        'FUNCSTAT',
        'ALAND',
        'AWATER',
        'INTPTLAT',
        'INTPTLON'], inplace=True)

    # Convert epsg for filtered gdf to 4326
    filtered_encumbrance = filtered_encumbrance.set_geometry('geometry').to_crs(geo_crs)
    print(f'CRS of the filtered dataframe is {filtered_encumbrance.crs}')
    return filtered_encumbrance

# %%
# Load data for encumbrance type
def load_encumbrance_for_county(
        encumbrance_type: EncumbranceType,
        fips,
        state=None) -> gpd.GeoDataFrame:
    '''
    Load encumbrance data from <source> and return as GeoDataFrame.
    '''
    # Flag error if chosen encumbrance is not defined
    if encumbrance_type not in ENCUMBRANCES:
        raise ValueError(
            f"Invalid encumbrance type '{encumbrance_type}'. "
            f"Valid options are: {', '.join(ENCUMBRANCES)}."
        )
    # Obtain county boundary
    county_boundary = get_county_boundary(fips)

    # Read the parquet file for the encumbrance type
    try:
        file_path = os.path.join(PARQUET_INGESTION_PATH, f'{state}_{encumbrance_type}.parquet' if state else f'{encumbrance_type}.parquet')
        gdf = gpd.read_parquet(file_path)
    except Exception as e:
        raise FileNotFoundError(f"File {file_path} not found. Error: {e}")

    # Use spatial join to get encumbrance data for county
    county_gdf = filter_gdf_using_boundary(gdf, county_boundary)

    # save county_gdf as parquet file
    print(f"{encumbrance_type} data loaded for FIPS code: {fips}")
    
    # Convert to EPSG:4326
    county_gdf = county_gdf.to_crs(geo_crs)
    county_gdf.to_parquet(os.path.join(PARQUET_INGESTION_PATH,f'{fips}_{encumbrance_type}.parquet'))
    print(f'{encumbrance_type} parquet created for {fips}!')

# %%
# Mapping of county FIPS to state abbreviations
FIPS_TO_STATE = {
    '17031': 'IL',  # Cook County, IL
    '13121': 'GA',  # Fulton County, GA
    '53033': 'WA',  # King County, WA
    '48491': 'TX',  # Williamson County, TX
    '29181': 'MO',  # Warren County, MO
    '42011': 'PA',  # Berks County, PA
    '55107': 'WI',  # Rusk County, WI
    '35051': 'NM',  # Sierra County, NM
    '17127': 'IL',  # Massac County, IL
}

poc_fips = POC_FINALIZED_COUNTIES
encumbrances = ENCUMBRANCES

# Encumbrances that require state information
STATE_REQUIRED_TYPES = {'wetlands', 'protected_lands'}

for fips in poc_fips:
    for encumbrance in encumbrances:
        filename = f"{fips}_{encumbrance}.parquet"
        destination_file = os.path.join(PARQUET_INGESTION_PATH, filename)

        if not os.path.exists(destination_file):
            try:
                state = FIPS_TO_STATE.get(fips) if encumbrance in STATE_REQUIRED_TYPES else None

                load_encumbrance_for_county(
                    encumbrance_type=encumbrance,
                    fips=fips,
                    state=state
                )
                print(f"File {filename} processed and saved.")
            except Exception as e:
                print(f"Failed to process {filename}: {e}")
        else:
            print(f"File {filename} already exists. Skipping.")
# Out:
# File 17031_roadways.parquet already exists. Skipping.
# File 17031_railways.parquet already exists. Skipping.
# File 17031_protected_lands.parquet already exists. Skipping.
# File 17031_wetlands.parquet already exists. Skipping.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# transmission_lines data loaded for FIPS code: 17031
# transmission_lines parquet created for 17031!
# File 17031_transmission_lines.parquet processed and saved.
# File 13121_roadways.parquet already exists. Skipping.
# File 13121_railways.parquet already exists. Skipping.
# File 13121_protected_lands.parquet already exists. Skipping.
# File 13121_wetlands.parquet already exists. Skipping.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# transmission_lines data loaded for FIPS code: 13121
# transmission_lines parquet created for 13121!
# File 13121_transmission_lines.parquet processed and saved.
# File 53033_roadways.parquet already exists. Skipping.
# File 53033_railways.parquet already exists. Skipping.
# File 53033_protected_lands.parquet already exists. Skipping.
# File 53033_wetlands.parquet already exists. Skipping.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# transmission_lines data loaded for FIPS code: 53033
# transmission_lines parquet created for 53033!
# File 53033_transmission_lines.parquet processed and saved.
# File 48491_roadways.parquet already exists. Skipping.
# File 48491_railways.parquet already exists. Skipping.
# File 48491_protected_lands.parquet already exists. Skipping.
# File 48491_wetlands.parquet already exists. Skipping.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# transmission_lines data loaded for FIPS code: 48491
# transmission_lines parquet created for 48491!
# File 48491_transmission_lines.parquet processed and saved.
# File 29181_roadways.parquet already exists. Skipping.
# File 29181_railways.parquet already exists. Skipping.
# File 29181_protected_lands.parquet already exists. Skipping.
# File 29181_wetlands.parquet already exists. Skipping.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# transmission_lines data loaded for FIPS code: 29181
# transmission_lines parquet created for 29181!
# File 29181_transmission_lines.parquet processed and saved.
# File 42011_roadways.parquet already exists. Skipping.
# File 42011_railways.parquet already exists. Skipping.
# File 42011_protected_lands.parquet already exists. Skipping.
# File 42011_wetlands.parquet already exists. Skipping.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# transmission_lines data loaded for FIPS code: 42011
# transmission_lines parquet created for 42011!
# File 42011_transmission_lines.parquet processed and saved.
# File 55107_roadways.parquet already exists. Skipping.
# File 55107_railways.parquet already exists. Skipping.
# File 55107_protected_lands.parquet already exists. Skipping.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# wetlands data loaded for FIPS code: 55107
# wetlands parquet created for 55107!
# File 55107_wetlands.parquet processed and saved.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# transmission_lines data loaded for FIPS code: 55107
# transmission_lines parquet created for 55107!
# File 55107_transmission_lines.parquet processed and saved.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# roadways data loaded for FIPS code: 35051
# roadways parquet created for 35051!
# File 35051_roadways.parquet processed and saved.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# railways data loaded for FIPS code: 35051
# railways parquet created for 35051!
# File 35051_railways.parquet processed and saved.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# protected_lands data loaded for FIPS code: 35051
# protected_lands parquet created for 35051!
# File 35051_protected_lands.parquet processed and saved.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# wetlands data loaded for FIPS code: 35051
# wetlands parquet created for 35051!
# File 35051_wetlands.parquet processed and saved.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# transmission_lines data loaded for FIPS code: 35051
# transmission_lines parquet created for 35051!
# File 35051_transmission_lines.parquet processed and saved.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# roadways data loaded for FIPS code: 17127
# roadways parquet created for 17127!
# File 17127_roadways.parquet processed and saved.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# railways data loaded for FIPS code: 17127
# railways parquet created for 17127!
# File 17127_railways.parquet processed and saved.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# protected_lands data loaded for FIPS code: 17127
# protected_lands parquet created for 17127!
# File 17127_protected_lands.parquet processed and saved.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# wetlands data loaded for FIPS code: 17127
# wetlands parquet created for 17127!
# File 17127_wetlands.parquet processed and saved.
# CRS of the filtered dataframe is {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum_ensemble": {"name": "World Geodetic System 1984 ensemble", "members": [{"name": "World Geodetic System 1984 (Transit)"}, {"name": "World Geodetic System 1984 (G730)"}, {"name": "World Geodetic System 1984 (G873)"}, {"name": "World Geodetic System 1984 (G1150)"}, {"name": "World Geodetic System 1984 (G1674)"}, {"name": "World Geodetic System 1984 (G1762)"}, {"name": "World Geodetic System 1984 (G2139)"}], "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "accuracy": "2.0", "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Geodetic latitude", "abbreviation": "Lat", "direction": "north", "unit": "degree"}, {"name": "Geodetic longitude", "abbreviation": "Lon", "direction": "east", "unit": "degree"}]}, "scope": "Horizontal component of 3D system.", "area": "World.", "bbox": {"south_latitude": -90, "west_longitude": -180, "north_latitude": 90, "east_longitude": 180}, "id": {"authority": "EPSG", "code": 4326}}
# transmission_lines data loaded for FIPS code: 17127
# transmission_lines parquet created for 17127!
# File 17127_transmission_lines.parquet processed and saved.

# %% [markdown]
# #### 3.2 [Relevant for local development in python]: Parcel data for POC counties from BigQ in parquet

# %%
# Define constants here
PROJECT = 'clgx-gis-app-dev-06e3'
DATASET = 'property'
POC_DATASET = 'encumbered_parcels'
POC_TABLE = 'parcels'
CREDENTIALS_PATH =  r"C:\Users\eprashar\AppData\Roaming\gcloud\application_default_credentials.json"
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = str(CREDENTIALS_PATH)

# Credentials verification
utils.check_and_authenticate(CREDENTIALS_PATH)
# Out:
# Credentials file is valid.

# %%
# Define function to get parcel data for the defined county
def fetch_and_save_county_parcels(fips_code: str) -> gpd.GeoDataFrame:
    """
    Load parcel data from BigQuery and filter by FIPS code.
    """
    # Define the SQL query to filter by FIPS code
    # TO-DO: Create a table in BQ with processed data
    query = f"""
        SELECT * 
        FROM `{PROJECT}.{POC_DATASET}.{POC_TABLE}`
        WHERE fips_code = '{fips_code}'
    """
    # Read the data into a GeoDataFrame
    gdf_parcel = utils.read_bigquery_to_gdf(project=PROJECT, dataset=POC_DATASET, table=POC_TABLE, query=query, output='gpd', geometry_col='geometry')
    
    # Convert to EPSG:4326
    gdf_parcel = gdf_parcel.to_crs(geo_crs)
    print(f'CRS of the parcel dataframe is {gdf_parcel.crs}')
    gdf_parcel.to_parquet(os.path.join(PARQUET_INGESTION_PATH,f'{fips_code}_parcels.parquet'))
    print(f'parcel parquet created for {fips_code}!')

# %%
# Save parcel parquets for all POC counties
for county_fips in POC_FINALIZED_COUNTIES:
    fetch_and_save_county_parcels(fips_code=county_fips)
